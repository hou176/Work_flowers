# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns',None)
from sklearn.feature_extraction.text import CountVectorizer
import jieba # 导入关键字提取库
import pandas as pd  # 导入pandas

# %%
def improt_data(lujing,code):
    data = pd.read_csv(lujing,encoding =code)
    return data

def wenzi(data,z,a):
    list_2 = []
    list_3 = []
    lis = []
    
    for row,data_ in data.iterrows():
        name = data_['接单时间']
        list_3.append(name)
        y = data_[a]
        tr = y.find(z)
        if tr > -1 :
            list_2.append(y)
    print('关于' + '“' + z + '”' + '的订单数量是：',len(list_2))  
    lis.append(list_2)
    lis.append(list_3)
    return lis

def jiebe(data):    
    text_list = []
    for line in data:
        hou = ",".join(jieba.cut(line))
        strlist = hou.split(',') 
        text_list.append(strlist)
    return text_list

def clean(list_name_,stopwords_):    
    clean_line = []
    for line in list_name_:
        haha = []
        for word in line:
            if word in stopwords_:
                continue
            haha.append(word)
        haha = ','.join(haha)
        clean_line.append(haha)

    return clean_line

def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    dict_ = {}
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['订单编号'].count()
        if sum_ > 1 :
            list__.append(b)
            dict_[b] = sum_
        else:
            list_sum.append(b)
    k = [list__,dict_,list_sum]
    return k

# %%
lujing = r'C:\Users\Administrator\datas\艾尚花语\活动&单门店\七夕\七夕订单.csv'
code = 'gbk'
data = improt_data(lujing,code)

# %%
lujing = r'C:\Users\Administrator\datas\艾尚花语\活动&单门店\七夕\问题订单.csv'
code = 'gbk'
wrong = improt_data(lujing,code)

# %% [markdown]
# # data   wrong下单时间类型转换

# %%
data['下单时间'] = pd.to_datetime(data['下单时间'],format='%Y-%m-%d %H:%M:%S')

# %%
wrong['下单时间'] = pd.to_datetime(wrong['下单时间'],format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# # wrong用户催单  485

# %%
wrong['订单编号'].count()
wrong[wrong['商家服务问题']=='用户催单；\t']['订单编号'].count()
# Out:
# 485

# %%
wrong.head()
# Out:
#                 订单编号                下单时间                        店铺名称     店铺ID  \
# 0  92953251165886577 2020-08-25 17:46:31    美家鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9295325
# 1  90433172718691708 2020-08-25 12:00:09    花坞鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9043317
# 2  93520763982058332 2020-08-25 11:40:32   花仙子鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9352076
# 3  92238720408368023 2020-08-25 08:26:34  天天花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9223872
# 4  92953250678856768 2020-08-25 18:24:03    美家鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9295325
#
#   店铺所在城市  订单总金额（元）  退款金额（元） 退款商品   商家服务问题
# 0   岳阳\t     259.0      0.0  NaN  用户催单；\t
# 1   福州\t     259.0      0.0  NaN  用户催单；\t
# 2   西安\t     329.0      0.0  NaN  用户催单；\t
# 3   郴州\t     259.0      0.0  NaN  用户催单；\t
# 4   岳阳\t    1319.0      0.0  NaN  用户催单；\t

# %% [markdown]
# # 三种订单数量

# %%
data.drop_duplicates(subset='订单状态',keep='last',inplace=False)['订单状态']
# Out:
# 4514    订单已处理
# 4526     订单完成
# 4527     订单取消
# Name: 订单状态, dtype: object

# %%
data_quxiao = data[data['订单状态'] == '订单取消']
data_quxiao.head()
# Out:
#                      日期               订单编号                下单时间 接单时长  \
# 7   \t20200824-20200826  90242781269807160 2020-08-24 03:49:22   0秒
# 24  \t20200824-20200826  90242784235444324 2020-08-24 22:01:11   0秒
# 26  \t20200824-20200826  90242783892506751 2020-08-25 09:09:13   0秒
# 27  \t20200824-20200826  90242783892506751 2020-08-25 09:09:13   0秒
# 30  \t20200824-20200826  90242783152492135 2020-08-25 18:08:11   0秒
#
#                          店铺名称     店铺ID 店铺所在城市 订单支付类型  订单状态  订单配送状态 是否预订单  \
# 7   友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     是
# 24  友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     是
# 26  友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
# 27  友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
# 30  友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
#
#     订单总金额  订单折扣后金额  平台承担活动金额  商家承担活动金额    商品分类                       商品名称  \
# 7   547.0   331.00       0.0    221.00  约惠七夕\t   【心心相惜】36枝粉玫瑰鲜花礼盒-七夕节表白鲜花
# 24  259.0   126.00       0.0    138.00  约惠七夕\t   【花开相爱】11枝红玫瑰鲜花花束-七夕节表白鲜花
# 26  357.0   206.99       0.0    155.01  约惠七夕\t    【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色）
# 27  357.0   206.99       0.0    155.01  购买须知\t            【许愿灯】点亮人生  单拍不送
# 30  259.0   189.00       0.0     75.00  约惠七夕\t  【清新海歌】11枝香槟玫瑰鲜花花束-七夕节表白鲜花
#
#     UPC码      商品SKU码  商品销售数量  商品原价销售额  商品实付销售额  商品总补贴金额  商品商家补贴金额  商品平台补贴金额  \
# 7    NaN    as0059\t       1    519.0   306.00   213.00    213.00       0.0
# 24   NaN    as0022\t       1    259.0   126.00   133.00    133.00       0.0
# 26   NaN    as0026\t       1    329.0   196.08   132.92    132.92       0.0
# 27   NaN  ashy0383\t       1     20.0     5.91    14.09     14.09       0.0
# 30   NaN  ashy0402\t       1    259.0   189.00    70.00     70.00       0.0
#
#    是否部分退款商品  部分退款商品数量  部分退款商品金额  订单小额付款   配送费 是否活动订单  \
# 7         否         0       0.0     0.0  28.0      是
# 24        否         0       0.0     0.0   0.0      是
# 26        否         0       0.0     0.0   8.0      是
# 27        否         0       0.0     0.0   8.0      是
# 30        否         0       0.0     0.0   0.0      是
#
#                                                  优惠活动 是否催单 回复状态 商家回复内容   配送时长  \
# 7   满69.0元赠精美贺卡下单备注贺卡内容*1/购买【心心相惜】36枝粉玫瑰鲜花礼盒-七夕节表白...    否  未回复    NaN  0.00分
# 24  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【花开相爱】11枝红玫瑰鲜花花束-七夕节表白...    否  未回复    NaN  0.00分
# 26  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色...    否  未回复    NaN  0.00分
# 27  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色...    否  未回复    NaN  0.00分
# 30  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【清新海歌】11枝香槟玫瑰鲜花花束-七夕节表...    否  未回复    NaN  0.00分
#
#     打包袋费 订单完成时间 订单取消原因（仅取消订单）
# 7    0.0    NaN          其他\t
# 24   0.0    NaN          其他\t
# 26   0.0    NaN          其他\t
# 27   0.0    NaN          其他\t
# 30   0.0    NaN          其他\t

# %% [markdown]
# # 合并 136

# %%
data_quxiao_wrong = pd.merge(data_quxiao,wrong,on= ['订单编号'])
data_quxiao_wrong['订单编号'].count()
# data_quxiao_wrong
# Out:
# 136

# %%
data_quxiao_wrong_list = list(data_quxiao_wrong['商家服务问题'])
# data_quxiao_wrong_list

# %%
from collections import Counter  
a = len(data_quxiao_wrong_list)
collection_a = Counter(data_quxiao_wrong_list)
print('一共 %d 条数据' % a)
print(collection_a)
# Out:
# 一共 136 条数据
# Counter({'商家拒单；\t': 61, '商家超时未接单；\t': 35, '缺货导致退款；\t': 17, '用户催单；\t': 15, '商家少送错送；\t': 5, '缺货导致退款；用户催单；\t': 1, '质量问题导致退款；用户催单；\t': 1, '商家拒单；用户催单；\t': 1})

# %%
data_quxiao_list = list(data_quxiao['订单取消原因（仅取消订单）'])
a = len(data_quxiao_list)
collection_c= Counter(data_quxiao_list)
print('一共 %d 条数据' % a)
print(collection_c)
# Out:
# 一共 501 条数据
# Counter({'其他\t': 501})

# %% [markdown]
# # quxiao  wrong  是否预定单

# %%
drop_du(data_quxiao_wrong,'是否预订单')
# Out:
# [['是', '否'], {'是': 14, '否': 122}, []]

# %%
# 预订单的  取消  问题 单 
data_quxiao_wrong_yuding  = data_quxiao_wrong[data_quxiao_wrong['是否预订单'] == '是']
data_quxiao_wrong_yuding_list = list(data_quxiao_wrong_yuding['店铺名称_x'])
b = len(data_quxiao_wrong_yuding_list)
collection_b = Counter(data_quxiao_wrong_yuding_list)
print(collection_b)
# Out:
# Counter({'八度花艺(七夕节预定,生日鲜花，表白鲜花)\t': 2, '浪漫花都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, 'MINE FUN鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '锦上添花·七夕节鲜花,表白鲜花\t': 2, '元寳花店鲜花礼品鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '圣格花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '木子花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '依依花语鲜花礼品鲜花店\t': 1, '一花一木鲜花礼品鲜花店\t': 1, '遇见花艺·七夕节鲜花,表白鲜花\t': 1})

# %%
# 非预订单  取消  问题  单
data_quxiao_wrong_yuding_list = list(data_quxiao_wrong['店铺名称_x'])
b = len(data_quxiao_wrong_yuding_list)
collection_b = Counter(data_quxiao_wrong_yuding_list)
print(collection_b)
# Out:
# Counter({'梦真花卉鲜花礼品鲜花店\t': 6, '君之吻花坊\t': 6, '海霞花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 5, '99花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 4, '天长地久鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 4, '永恒花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 4, 'MINE FUN鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 4, '依依花语鲜花礼品鲜花店\t': 4, '牵手花艺鲜花礼品鲜花店\t': 4, '颜汇永丰鲜花(七夕节预定,生日鲜花，表白鲜花)\t': 4, '锦上添花·七夕节鲜花,表白鲜花\t': 4, '友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t': 3, '流星花園鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 3, '长华花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 3, '如意鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 3, '浪漫花都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 3, '馨梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 3, '兰心阁花坊·七夕节鲜花,表白鲜花\t': 3, '八度花艺(七夕节预定,生日鲜花，表白鲜花)\t': 2, '柔怡鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '大拇指婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '芳香缘鲜花批发(七夕节预定,生日鲜花，表白鲜花)\t': 2, '拾花间鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '先花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '爱美鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '鲜花朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '品茗鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '木子花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '芳源鲜花礼品鲜花店\t': 2, '心语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 2, '遇见花艺·七夕节鲜花,表白鲜花\t': 2, '元寳花店鲜花礼品鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '浪漫主题花艺(七夕节预定,生日鲜花，表白鲜花)\t': 1, '茗蔓花艺(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花坞鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花仙子\t': 1, '都市花乡鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花语鲜鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花开相爱鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '英皇鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '欣然鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花间集鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '恒海鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '绿之园花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花仙子鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花香时刻鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '百卉鲜花婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '芳雅花艺生活馆\t': 1, '圣格花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花之恋果之园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '玉花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '珊珊家鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '俊萍花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '一花一叶花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '爱尚馨缘鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '蝶恋花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花儿朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '胖子花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花千谷(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花语花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '花艺鲜花店\t': 1, '一花一木鲜花礼品鲜花店\t': 1, '百艳花居\t': 1, '初见花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t': 1, '遇见花艺\t': 1, '鲜花小站·七夕节鲜花,表白鲜花\t': 1, '晨花飞扬·七夕节鲜花,表白鲜花\t': 1, '花旺·七夕节鲜花,表白鲜花\t': 1, '欢聚缘婚礼·七夕节鲜花,表白鲜花\t': 1, 'FLOWER意达·七夕节鲜花,表白鲜花\t': 1})

# %%
print(data_quxiao_wrong['订单编号'].count())
print(wrong['订单编号'].count())
# Out:
# 136
# 634

# %%
data_quxiao['接单时间'] = data_quxiao['接单时长'].str.split('秒',expand=True)[0]
data['接单时间'] = data_quxiao['接单时长'].str.split('秒',expand=True)[0]
# Out:
# <ipython-input-132-5f371c9bc4a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_quxiao['接单时间'] = data_quxiao['接单时长'].str.split('秒',expand=True)[0]

# %%
# data_quxiao.to_csv('取消订单.csv')
# data.to_csv('data.csv')

# %%
data_quxiao
# Out:
#                        日期               订单编号                下单时间  接单时长  \
# 7     \t20200824-20200826  90242781269807160 2020-08-24 03:49:22    0秒
# 24    \t20200824-20200826  90242784235444324 2020-08-24 22:01:11    0秒
# 26    \t20200824-20200826  90242783892506751 2020-08-25 09:09:13    0秒
# 27    \t20200824-20200826  90242783892506751 2020-08-25 09:09:13    0秒
# 30    \t20200824-20200826  90242783152492135 2020-08-25 18:08:11    0秒
# ...                   ...                ...                 ...   ...
# 4495  \t20200824-20200826  97972872620144691 2020-08-24 22:09:39  455秒
# 4499  \t20200824-20200826  97989173966510833 2020-08-24 23:49:27  230秒
# 4506  \t20200824-20200826  97989172141837702 2020-08-25 10:56:27  202秒
# 4520  \t20200824-20200826  98110693470084206 2020-08-25 14:28:24    0秒
# 4527  \t20200824-20200826  98113453382704585 2020-08-25 18:47:39  234秒
#
#                            店铺名称     店铺ID 店铺所在城市 订单支付类型  订单状态  订单配送状态 是否预订单  \
# 7     友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     是
# 24    友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     是
# 26    友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
# 27    友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
# 30    友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付  订单取消  用户提交订单     否
# ...                         ...      ...    ...    ...   ...     ...   ...
# 4495          盈瑞鲜花·七夕节鲜花,表白鲜花\t  9797287   沈阳\t   在线支付  订单取消  用户提交订单     否
# 4499      FLOWER意达·七夕节鲜花,表白鲜花\t  9798917   辽阳\t   在线支付  订单取消  用户提交订单     否
# 4506      FLOWER意达·七夕节鲜花,表白鲜花\t  9798917   辽阳\t   在线支付  订单取消  用户提交订单     否
# 4520                   girl花坊\t  9811069   南京\t   在线支付  订单取消  用户提交订单     否
# 4527                     玫瑰花店\t  9811345   怀化\t   在线支付  订单取消  用户提交订单     否
#
#       订单总金额  订单折扣后金额  平台承担活动金额  商家承担活动金额    商品分类                        商品名称  \
# 7     547.0   331.00       0.0    221.00  约惠七夕\t    【心心相惜】36枝粉玫瑰鲜花礼盒-七夕节表白鲜花
# 24    259.0   126.00       0.0    138.00  约惠七夕\t    【花开相爱】11枝红玫瑰鲜花花束-七夕节表白鲜花
# 26    357.0   206.99       0.0    155.01  约惠七夕\t     【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色）
# 27    357.0   206.99       0.0    155.01  购买须知\t             【许愿灯】点亮人生  单拍不送
# 30    259.0   189.00       0.0     75.00  约惠七夕\t   【清新海歌】11枝香槟玫瑰鲜花花束-七夕节表白鲜花
# ...     ...      ...       ...       ...     ...                         ...
# 4495  259.0   133.00       0.0    131.00  约惠七夕\t  【怦然心动】11枝粉玫瑰鲜花网红礼盒-七夕节表白鲜花
# 4499  259.0   126.00       0.0    138.00  约惠七夕\t    【花开相爱】11枝红玫瑰鲜花花束-七夕节表白鲜花
# 4506  509.0   236.00       0.0    278.00  爱意表达\t          【怦然心动】33枝红玫瑰黑纱鲜花花束
# 4520  279.0   146.00       0.0    138.00   毕业季\t  【明眸】11枝香槟玫瑰+1枝向日葵鲜花花束毕业季花礼
# 4527  329.0   156.00       0.0    178.00  约惠七夕\t    【绯色诱惑】19枝粉玫瑰鲜花礼盒-七夕节表白鲜花
#
#       UPC码      商品SKU码  商品销售数量  商品原价销售额  商品实付销售额  商品总补贴金额  商品商家补贴金额  商品平台补贴金额  \
# 7      NaN    as0059\t       1    519.0   306.00   213.00    213.00       0.0
# 24     NaN    as0022\t       1    259.0   126.00   133.00    133.00       0.0
# 26     NaN    as0026\t       1    329.0   196.08   132.92    132.92       0.0
# 27     NaN  ashy0383\t       1     20.0     5.91    14.09     14.09       0.0
# 30     NaN  ashy0402\t       1    259.0   189.00    70.00     70.00       0.0
# ...    ...         ...     ...      ...      ...      ...       ...       ...
# 4495   NaN  ashy0399\t       1    259.0   133.00   126.00    126.00       0.0
# 4499   NaN    as0022\t       1    259.0   126.00   133.00    133.00       0.0
# 4506   NaN    as0047\t       1    509.0   236.00   273.00    273.00       0.0
# 4520   NaN    as0280\t       1    279.0   146.00   133.00    133.00       0.0
# 4527   NaN  ashy0393\t       1    329.0   156.00   173.00    173.00       0.0
#
#      是否部分退款商品  部分退款商品数量  部分退款商品金额  订单小额付款   配送费 是否活动订单  \
# 7           否         0       0.0     0.0  28.0      是
# 24          否         0       0.0     0.0   0.0      是
# 26          否         0       0.0     0.0   8.0      是
# 27          否         0       0.0     0.0   8.0      是
# 30          否         0       0.0     0.0   0.0      是
# ...       ...       ...       ...     ...   ...    ...
# 4495        否         0       0.0     0.0   0.0      是
# 4499        否         0       0.0     0.0   0.0      是
# 4506        否         0       0.0     0.0   0.0      是
# 4520        否         0       0.0     0.0   0.0      是
# 4527        否         0       0.0     0.0   0.0      是
#
#                                                    优惠活动 是否催单 回复状态 商家回复内容  \
# 7     满69.0元赠精美贺卡下单备注贺卡内容*1/购买【心心相惜】36枝粉玫瑰鲜花礼盒-七夕节表白...    否  未回复    NaN
# 24    满69.0元赠精美贺卡下单备注贺卡内容*1/购买【花开相爱】11枝红玫瑰鲜花花束-七夕节表白...    否  未回复    NaN
# 26    满69.0元赠精美贺卡下单备注贺卡内容*1/购买【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色...    否  未回复    NaN
# 27    满69.0元赠精美贺卡下单备注贺卡内容*1/购买【此情不渝】11枝蓝色妖姬鲜花礼盒（真花上色...    否  未回复    NaN
# 30    满69.0元赠精美贺卡下单备注贺卡内容*1/购买【清新海歌】11枝香槟玫瑰鲜花花束-七夕节表...    否  未回复    NaN
# ...                                                 ...  ...  ...    ...
# 4495  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【怦然心动】11枝粉玫瑰鲜花网红礼盒-七夕节...    否  未回复    NaN
# 4499  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【花开相爱】11枝红玫瑰鲜花花束-七夕节表白...    否  未回复    NaN
# 4506  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【怦然心动】33枝红玫瑰黑纱鲜花花束原价50...    是  未回复    NaN
# 4520  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【明眸】11枝香槟玫瑰+1枝向日葵鲜花花束毕...    否  未回复    NaN
# 4527  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【绯色诱惑】19枝粉玫瑰鲜花礼盒-七夕节表白...    否  未回复    NaN
#
#        配送时长  打包袋费 订单完成时间 订单取消原因（仅取消订单） 接单时间
# 7     0.00分   0.0    NaN          其他\t    0
# 24    0.00分   0.0    NaN          其他\t    0
# 26    0.00分   0.0    NaN          其他\t    0
# 27    0.00分   0.0    NaN          其他\t    0
# 30    0.00分   0.0    NaN          其他\t    0
# ...     ...   ...    ...           ...  ...
# 4495  0.00分   0.0    NaN          其他\t  455
# 4499  0.00分   0.0    NaN          其他\t  230
# 4506  0.00分   0.0    NaN          其他\t  202
# 4520  0.00分   0.0    NaN          其他\t    0
# 4527  0.00分   0.0    NaN          其他\t  234
#
# [501 rows x 40 columns]

# %%
a = wenzi(data,'订单完成','订单状态')
from numpy import *
list_time = []
for i in a[1]:
    a = type(i)
    a = str(a)
    if a == "<class 'float'>":
        i = 0
#     print(i)
    j = int(i)
    list_time.append(j)
print('data平均接单时间%f秒' %mean(list_time))
# Out:
# 关于“订单完成”的订单数量是： 3493
# data平均接单时间4.228357秒

# %%
a = wenzi(data_quxiao,'订单取消','订单状态')
from numpy import *
list_time = []
for i in a[1]:
#     print(i)
    j = int(i)
    list_time.append(j)
print('取消平均接单时间%f秒' %mean(list_time))
# Out:
# 关于“订单取消”的订单数量是： 501
# 取消平均接单时间38.215569秒

# %%
data_quxiao['接单时间'] = data_quxiao['接单时间'].astype(int)

data.fillna(0,inplace=True)
data['接单时间'] = data['接单时间'].astype(int)
# Out:
# <ipython-input-137-980234e06e23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_quxiao['接单时间'] = data_quxiao['接单时间'].astype(int)

# %%
data_quxiao.boxplot('接单时间')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 21333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25509 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 21333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data.boxplot('接单时间')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 21333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25509 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 21333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Q1 = np.percentile(data_quxiao['接单时间'], 25)
Q3 = np.percentile(data_quxiao['接单时间'], 75)
Q2 = np.percentile(data_quxiao['接单时间'], 50)
IQ = Q3 - Q1

# %%
Q4 = Q3 + 1.5*IQ
print(Q4)
# Out:
# 50.0

# %%
print(Q3)
# Out:
# 20.0

# %%
print(Q2)
# Out:
# 0.0

# %%
data_quxiao['接单时间'].mean()
# Out:
# 38.21556886227545

# %% [markdown]
# # 查看三种店铺情况

# %%
data
# Out:
#                        日期               订单编号                下单时间  接单时长  \
# 0     \t20200824-20200826  90242751795091754 2020-08-25 21:50:30  172秒
# 1     \t20200824-20200826  90242750408368023 2020-08-25 10:55:55  166秒
# 2     \t20200824-20200826  90242753470084206 2020-08-25 11:16:26  142秒
# 3     \t20200824-20200826  90242752386186755 2020-08-25 17:56:05  167秒
# 4     \t20200824-20200826  90242782800320932 2020-08-24 17:22:22   54秒
# ...                   ...                ...                 ...   ...
# 4523  \t20200824-20200826  98113453470084206 2020-08-25 09:55:35   40秒
# 4524  \t20200824-20200826  98113452386186755 2020-08-25 09:58:17   41秒
# 4525  \t20200824-20200826  98113451795091754 2020-08-25 17:07:55  140秒
# 4526  \t20200824-20200826  98113451677285159 2020-08-25 17:19:50  140秒
# 4527  \t20200824-20200826  98113453382704585 2020-08-25 18:47:39  234秒
#
#                              店铺名称     店铺ID 店铺所在城市 订单支付类型   订单状态  订单配送状态 是否预订单  \
# 0     花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9024275   郑州\t   在线支付  订单已处理     配送中     否
# 1     花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9024275   郑州\t   在线支付   订单完成     配送中     否
# 2     花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9024275   郑州\t   在线支付   订单完成     配送中     否
# 3     花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9024275   郑州\t   在线支付   订单完成  用户提交订单     否
# 4       友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278   西安\t   在线支付   订单完成     配送中     否
# ...                           ...      ...    ...    ...    ...     ...   ...
# 4523                       玫瑰花店\t  9811345   怀化\t   在线支付   订单完成     配送中     否
# 4524                       玫瑰花店\t  9811345   怀化\t   在线支付   订单完成     配送中     否
# 4525                       玫瑰花店\t  9811345   怀化\t   在线支付   订单完成  用户提交订单     否
# 4526                       玫瑰花店\t  9811345   怀化\t   在线支付   订单完成  用户提交订单     否
# 4527                       玫瑰花店\t  9811345   怀化\t   在线支付   订单取消  用户提交订单     否
#
#       订单总金额  订单折扣后金额  平台承担活动金额  商家承担活动金额     商品分类                        商品名称  \
# 0     259.0    140.0       0.0     124.0   约惠七夕\t   【未来可期】11枝香槟玫瑰鲜花礼盒-七夕节表白鲜花
# 1     299.0    190.0       0.0     114.0  向日葵花语\t   【绝代佳人】3枝向日葵+11枝香槟玫瑰韩式鲜花花束
# 2     259.0    170.0       0.0      94.0   约惠七夕\t   【青春不悔】19枝香槟玫瑰鲜花花束-七夕节表白鲜花
# 3     329.0    160.0       0.0     174.0    毕业季\t         【盛夏】19枝粉玫瑰鲜花花束毕业季花礼
# 4     318.0    179.0       0.0     144.0    毕业季\t  【明眸】11枝香槟玫瑰+1枝向日葵鲜花花束毕业季花礼
# ...     ...      ...       ...       ...      ...                         ...
# 4523  259.0    126.0       0.0     138.0   约惠七夕\t    【春风十里】11枝红玫瑰鲜花礼盒-七夕节表白鲜花
# 4524  259.0    126.0       0.0     138.0   约惠七夕\t    【粉色公主】11枝粉玫瑰鲜花礼盒-七夕节表白鲜花
# 4525  259.0    136.0       0.0     128.0   约惠七夕\t  【怦然心动】11枝红玫瑰鲜花网红礼盒-七夕节表白鲜花
# 4526  329.0    146.0       0.0     188.0   约惠七夕\t      【如梦】19枝红玫瑰鲜花花束-七夕节表白鲜花
# 4527  329.0    156.0       0.0     178.0   约惠七夕\t    【绯色诱惑】19枝粉玫瑰鲜花礼盒-七夕节表白鲜花
#
#       UPC码      商品SKU码  商品销售数量  商品原价销售额  商品实付销售额  商品总补贴金额  商品商家补贴金额  商品平台补贴金额  \
# 0      0.0  ashy0417\t       1    259.0    140.0    119.0     119.0       0.0
# 1      0.0    as0102\t       1    299.0    190.0    109.0     109.0       0.0
# 2      0.0  ashy0425\t       1    259.0    170.0     89.0      89.0       0.0
# 3      0.0    as0283\t       1    329.0    160.0    169.0     169.0       0.0
# 4      0.0    as0280\t       1    279.0    143.0    136.0     136.0       0.0
# ...    ...         ...     ...      ...      ...      ...       ...       ...
# 4523   0.0  ashy0390\t       1    259.0    126.0    133.0     133.0       0.0
# 4524   0.0  ashy0394\t       1    259.0    126.0    133.0     133.0       0.0
# 4525   0.0  ashy0400\t       1    259.0    136.0    123.0     123.0       0.0
# 4526   0.0  ashy0403\t       1    329.0    146.0    183.0     183.0       0.0
# 4527   0.0  ashy0393\t       1    329.0    156.0    173.0     173.0       0.0
#
#      是否部分退款商品  部分退款商品数量  部分退款商品金额  订单小额付款   配送费 是否活动订单  \
# 0           否         0       0.0     0.0   0.0      是
# 1           否         0       0.0     0.0   0.0      是
# 2           否         0       0.0     0.0   0.0      是
# 3           否         0       0.0     0.0   0.0      是
# 4           否         0       0.0     0.0  39.0      是
# ...       ...       ...       ...     ...   ...    ...
# 4523        否         0       0.0     0.0   0.0      是
# 4524        否         0       0.0     0.0   0.0      是
# 4525        否         0       0.0     0.0   0.0      是
# 4526        否         0       0.0     0.0   0.0      是
# 4527        否         0       0.0     0.0   0.0      是
#
#                                                    优惠活动 是否催单 回复状态 商家回复内容  \
# 0     满69.0元赠精美贺卡下单备注贺卡内容*1/购买【未来可期】11枝香槟玫瑰鲜花礼盒-七夕节表...    否  未回复      0
# 1     满200.0元减100.0元/满69.0元赠精美贺卡下单备注贺卡内容*1/门店新客立减9.0...    否  未回复      0
# 2     满69.0元赠精美贺卡下单备注贺卡内容*1/购买【青春不悔】19枝香槟玫瑰鲜花花束-七夕节表...    否  未回复      0
# 3     满69.0元赠精美贺卡下单备注贺卡内容*1/购买【盛夏】19枝粉玫瑰鲜花花束毕业季花礼原价3...    否  已回复      0
# 4     满69.0元赠精美贺卡下单备注贺卡内容*1/购买【明眸】11枝香槟玫瑰+1枝向日葵鲜花花束毕...    否  未回复      0
# ...                                                 ...  ...  ...    ...
# 4523  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【春风十里】11枝红玫瑰鲜花礼盒-七夕节表白...    否  未回复      0
# 4524  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【粉色公主】11枝粉玫瑰鲜花礼盒-七夕节表白...    否  未回复      0
# 4525  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【怦然心动】11枝红玫瑰鲜花网红礼盒-七夕节...    否  未回复      0
# 4526  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【如梦】19枝红玫瑰鲜花花束-七夕节表白鲜花...    否  未回复      0
# 4527  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【绯色诱惑】19枝粉玫瑰鲜花礼盒-七夕节表白...    否  未回复      0
#
#        配送时长  打包袋费                 订单完成时间 订单取消原因（仅取消订单）  接单时间  下单时间1  下单时间2  \
# 0     0.00分   0.0                      0             0     0     25     21
# 1     0.00分   0.0  2020-08-25 15:49:22\t             0     0     25     10
# 2     0.00分   0.0  2020-08-25 15:57:17\t             0     0     25     11
# 3     0.00分   0.0  2020-08-25 18:43:35\t             0     0     25     17
# 4     0.00分   0.0  2020-08-24 23:46:31\t             0     0     24     17
# ...     ...   ...                    ...           ...   ...    ...    ...
# 4523  0.00分   0.0  2020-08-25 15:04:32\t             0     0     25      9
# 4524  0.00分   0.0  2020-08-25 15:11:15\t             0     0     25      9
# 4525  0.00分   0.0  2020-08-25 23:37:16\t             0     0     25     17
# 4526  0.00分   0.0  2020-08-25 23:35:01\t             0     0     25     17
# 4527  0.00分   0.0                      0          其他\t   234     25     18
#
#      下单时间3
# 0     2521
# 1     2510
# 2     2511
# 3     2517
# 4     2417
# ...    ...
# 4523   259
# 4524   259
# 4525  2517
# 4526  2517
# 4527  2518
#
# [4528 rows x 43 columns]

# %%
a = drop_du(data,'店铺名称')
temp = sorted(a[1].items(), key=lambda x: x[1], reverse=True)
temp
# Out:
# [('群芳鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 70),
#  ('花仙子鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 69),
#  ('花开相爱鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 66),
#  ('千千惠鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 65),
#  ('雨桐鲜花\t', 64),
#  ('一花一木花艺生活馆(七夕节预定,生日鲜花，表白鲜花)\t', 63),
#  ('姐妹鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 60),
#  ('锦上添花·七夕节鲜花,表白鲜花\t', 60),
#  ('友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t', 57),
#  ('八度花艺(七夕节预定,生日鲜花，表白鲜花)\t', 56),
#  ('海霞花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 56),
#  ('牵手花艺鲜花礼品鲜花店\t', 56),
#  ('馨语花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 55),
#  ('花王花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 55),
#  ('花间集鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 54),
#  ('花坞鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 53),
#  ('花无缺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 53),
#  ('娜娜花屋鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 53),
#  ('花满庭花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 50),
#  ('小周鲜花屋·七夕节鲜花,表白鲜花\t', 50),
#  ('唯美花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 49),
#  ('花间密码鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 49),
#  ('利群鲜花批发鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 48),
#  ('花间时光(七夕节预定,生日鲜花，表白鲜花)\t', 47),
#  ('美家鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 47),
#  ('花言草语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 45),
#  ('柳柳花舍鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 45),
#  ('花儿朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 45),
#  ('茂业花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 44),
#  ('俊萍花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 44),
#  ('玫瑰之约（艾尚花语鲜花店）\t', 43),
#  ('花鲜阁鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 42),
#  ('婉苑鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 42),
#  ('情缘婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 41),
#  ('欣然鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 41),
#  ('爱尚馨缘鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 41),
#  ('君之吻花坊\t', 40),
#  ('幸福花园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 39),
#  ('锦上添花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 38),
#  ('邂逅花店鲜花礼品鲜花店\t', 38),
#  ('红玫瑰鲜花礼品鲜花店\t', 38),
#  ('浪漫主题花艺(七夕节预定,生日鲜花，表白鲜花)\t', 36),
#  ('花知语婚典鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 36),
#  ('南园鲜花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 35),
#  ('玉花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 35),
#  ('丰颖花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 34),
#  ('绿之园花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 34),
#  ('上辰花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 34),
#  ('繁花花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 34),
#  ('花旺·七夕节鲜花,表白鲜花\t', 34),
#  ('大拇指婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 33),
#  ('梦真花卉鲜花礼品鲜花店\t', 32),
#  ('拾花间鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 31),
#  ('木子花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 31),
#  ('馨悦花店鲜花店\t', 31),
#  ('花之恋果之园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 30),
#  ('花语花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 30),
#  ('鲜花绿植·七夕节鲜花,表白鲜花\t', 30),
#  ('晶晶花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 29),
#  ('微妮初花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 28),
#  ('天天花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 27),
#  ('花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 27),
#  ('鲜花朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 27),
#  ('品茗鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 27),
#  ('依依花语鲜花礼品鲜花店\t', 27),
#  ('百花庄花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 26),
#  ('花幻之境鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 26),
#  ('1°花艺礼品(七夕节预定,生日鲜花，表白鲜花)\t', 25),
#  ('花语鲜鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 25),
#  ('蝶恋花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 25),
#  ('伊人鲜花礼品鲜花店\t', 25),
#  ('花企网婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 24),
#  ('都市花乡鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 24),
#  ('MINE FUN鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 24),
#  ('兰心阁花坊·七夕节鲜花,表白鲜花\t', 24),
#  ('一花一木鲜花礼品鲜花店\t', 23),
#  ('拾贰花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('一花一叶花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('倾城鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('浪漫花屋鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('陌上花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('小姐姐花店鲜花礼品鲜花店\t', 22),
#  ('斌华鲜花美妆店(七夕节预定,生日鲜花，表白鲜花)\t', 22),
#  ('喜福来鲜花（白家沟市场店）\t', 22),
#  ('朵朵鲜花店·七夕节鲜花,表白鲜花\t', 22),
#  ('鲜花绿植鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 21),
#  ('尚品花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 21),
#  ('元寳花店鲜花礼品鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 20),
#  ('爱美鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 20),
#  ('遇见花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 20),
#  ('花仙子\t', 19),
#  ('木子花开鲜花店\t', 19),
#  ('恒海鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('花香时刻鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('简单花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('百卉鲜花婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('依家花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('99花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('花之坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 19),
#  ('FLOWER意达·七夕节鲜花,表白鲜花\t', 19),
#  ('花之都创意鲜花馆(七夕节预定,生日鲜花，表白鲜花)\t', 18),
#  ('如意花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 18),
#  ('众里寻Ta花舍鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 18),
#  ('伊人花艺·七夕节鲜花,表白鲜花\t', 18),
#  ('珍馨花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 17),
#  ('喜乐四季花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 17),
#  ('百合鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 17),
#  ('茗蔓花艺(七夕节预定,生日鲜花，表白鲜花)\t', 16),
#  ('印象花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 16),
#  ('先花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 16),
#  ('半亩花田鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 16),
#  ('浪漫花都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 16),
#  ('流星花園鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 15),
#  ('凤鲜婚庆花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 15),
#  ('花世界迷尔鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 15),
#  ('花仙谷鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 15),
#  ('天长地久鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 14),
#  ('永恒花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 14),
#  ('长华花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 13),
#  ('郁花缘鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 13),
#  ('唯一鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 13),
#  ('玫瑰之约鲜花礼品鲜花店\t', 13),
#  ('甜蜜花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 13),
#  ('花满缘花坊鲜花礼品鲜花店\t', 13),
#  ('情艺鲜花礼品鲜花店\t', 13),
#  ('颜汇永丰鲜花(七夕节预定,生日鲜花，表白鲜花)\t', 13),
#  ('欢聚缘婚礼·七夕节鲜花,表白鲜花\t', 13),
#  ('柔怡鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('开封市玺花诚园艺有限公司鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('花戒鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('维罗纳花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('花之语鲜花店\t', 12),
#  ('青青花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('年年红鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('鑫鑫花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('麦萌花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('爱神鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('梦梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('小慧花坊（金泰园店）\t', 11),
#  ('壹见钟情(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('永恒鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 10),
#  ('亿米阳光鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 10),
#  ('珊珊家鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 10),
#  ('浪漫花都·七夕节鲜花,表白鲜花\t', 10),
#  ('阳光鲜花·七夕节鲜花,表白鲜花\t', 10),
#  ('芳香缘鲜花批发(七夕节预定,生日鲜花，表白鲜花)\t', 9),
#  ('惜缘花业鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 9),
#  ('Mr.K的花店(七夕节预定,生日鲜花，表白鲜花)\t', 9),
#  ('馨梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 9),
#  ('玫瑰花坊鲜花店\t', 9),
#  ('梦幻花坊·七夕节鲜花,表白鲜花\t', 9),
#  ('红枫林·七夕节鲜花,表白鲜花\t', 9),
#  ('鲜花婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 8),
#  ('爱尚花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 8),
#  ('旺斯花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 8),
#  ('百艳花居\t', 8),
#  ('最恋花坊·七夕节鲜花,表白鲜花\t', 8),
#  ('阳光鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('乐都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('如意鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('締玖鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('相约玫瑰鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('南焉花镇鲜花礼品鲜花店\t', 7),
#  ('玫瑰花店\t', 7),
#  ('专爱花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('伯爵婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('初见花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('品尚花店\t', 6),
#  ('心语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('girl花坊\t', 6),
#  ('时初花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('喜洋洋鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('婷旭花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('花之舞庆典鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('诗情花艺（桃花坞新村店）\t', 5),
#  ('美俪汇花艺婚庆·七夕节鲜花,表白鲜花\t', 5),
#  ('遇见花艺·七夕节鲜花,表白鲜花\t', 5),
#  ('花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('等你花舍鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('馨悦花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('博文花艺行鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('清香园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('尚品花坊（艾尚花语鲜花店）\t', 4),
#  ('圣格花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('馨悦花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('紫藤鲜花婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('鲜花谷花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('遇见花艺\t', 4),
#  ('晨花飞扬·七夕节鲜花,表白鲜花\t', 4),
#  ('七彩花卉·七夕节鲜花,表白鲜花\t', 4),
#  ('馨露鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('英皇鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('九月花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('小浣熊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('花之韵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('爱都花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('陌上花开\t', 3),
#  ('胖子花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('馨语花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('芳源鲜花礼品鲜花店\t', 3),
#  ('鲜花小站·七夕节鲜花,表白鲜花\t', 3),
#  ('镜花缘花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('四季花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花开半夏鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('金百合花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('爱尚花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('江东花卉市场鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2)]

# %%
b = drop_du(data_quxiao,'店铺名称')
temp = sorted(b[1].items(), key=lambda x: x[1], reverse=True)
temp
# Out:
# [('友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t', 12),
#  ('海霞花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 11),
#  ('锦上添花·七夕节鲜花,表白鲜花\t', 11),
#  ('MINE FUN鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 10),
#  ('依依花语鲜花礼品鲜花店\t', 9),
#  ('梦真花卉鲜花礼品鲜花店\t', 9),
#  ('颜汇永丰鲜花(七夕节预定,生日鲜花，表白鲜花)\t', 9),
#  ('花间密码鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 8),
#  ('牵手花艺鲜花礼品鲜花店\t', 8),
#  ('君之吻花坊\t', 8),
#  ('八度花艺(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('倾城鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('馨梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 7),
#  ('花间时光(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('欣然鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('拾花间鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('花王花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 6),
#  ('兰心阁花坊·七夕节鲜花,表白鲜花\t', 6),
#  ('柔怡鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('花仙子\t', 5),
#  ('姐妹鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('流星花園鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('长华花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('花开相爱鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('茂业花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('千千惠鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('花仙子鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('繁花花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('俊萍花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('爱美鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('鲜花朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('品茗鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('蝶恋花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('浪漫花都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('馨语花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('木子花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('元寳花店鲜花礼品鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('浪漫主题花艺(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('花企网婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('花鲜阁鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('花知语婚典鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('大拇指婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('锦上添花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('恒海鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('玫瑰之约（艾尚花语鲜花店）\t', 4),
#  ('利群鲜花批发鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('如意鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('99花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('幸福花园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('爱尚馨缘鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('天长地久鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('永恒花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('邂逅花店鲜花礼品鲜花店\t', 4),
#  ('一花一木鲜花礼品鲜花店\t', 4),
#  ('初见花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('朵朵鲜花店·七夕节鲜花,表白鲜花\t', 4),
#  ('花之都创意鲜花馆(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('花坞鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('丰颖花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('芳香缘鲜花批发(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('花无缺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('绿之园花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('维罗纳花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('花仙谷鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('百卉鲜花婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('一花一叶花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('先花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('青青花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('梦梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('胖子花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('壹见钟情(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('红玫瑰鲜花礼品鲜花店\t', 3),
#  ('花语花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('百艳花居\t', 3),
#  ('鲜花小站·七夕节鲜花,表白鲜花\t', 3),
#  ('花旺·七夕节鲜花,表白鲜花\t', 3),
#  ('欢聚缘婚礼·七夕节鲜花,表白鲜花\t', 3),
#  ('时初花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('茗蔓花艺(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('情缘婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('都市花乡鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('群芳鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('凤鲜婚庆花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('鑫鑫花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('英皇鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('如意花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('爱神鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花世界迷尔鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花香时刻鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('惜缘花业鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('鲜花绿植鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('娜娜花屋鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花言草语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('一花一木花艺生活馆(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花之恋果之园鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('上辰花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('玉花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花之坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('众里寻Ta花舍鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('微妮初花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('花儿朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('唯美花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('浪漫花屋鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('陌上花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('芳源鲜花礼品鲜花店\t', 2),
#  ('玫瑰花坊鲜花店\t', 2),
#  ('心语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('遇见花艺\t', 2),
#  ('伊人花艺·七夕节鲜花,表白鲜花\t', 2),
#  ('鲜花绿植·七夕节鲜花,表白鲜花\t', 2),
#  ('晨花飞扬·七夕节鲜花,表白鲜花\t', 2),
#  ('遇见花艺·七夕节鲜花,表白鲜花\t', 2),
#  ('FLOWER意达·七夕节鲜花,表白鲜花\t', 2)]

# %%
c = drop_du(data_quxiao_wrong,'店铺名称_x')
temp = sorted(c[1].items(), key=lambda x: x[1], reverse=True)
temp
# Out:
# [('梦真花卉鲜花礼品鲜花店\t', 6),
#  ('君之吻花坊\t', 6),
#  ('海霞花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 5),
#  ('99花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('天长地久鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('永恒花艺生活馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('MINE FUN鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('依依花语鲜花礼品鲜花店\t', 4),
#  ('牵手花艺鲜花礼品鲜花店\t', 4),
#  ('颜汇永丰鲜花(七夕节预定,生日鲜花，表白鲜花)\t', 4),
#  ('锦上添花·七夕节鲜花,表白鲜花\t', 4),
#  ('友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('流星花園鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('长华花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('如意鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('浪漫花都鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('馨梦鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 3),
#  ('兰心阁花坊·七夕节鲜花,表白鲜花\t', 3),
#  ('八度花艺(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('柔怡鲜花鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('大拇指婚庆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('芳香缘鲜花批发(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('拾花间鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('先花店鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('爱美鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('鲜花朵朵鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('品茗鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('木子花开鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('芳源鲜花礼品鲜花店\t', 2),
#  ('心语鲜花店(七夕节预定,生日鲜花，表白鲜花)\t', 2),
#  ('遇见花艺·七夕节鲜花,表白鲜花\t', 2)]

# %% [markdown]
# # 七夕订单上涨幅度

# %%
data['下单时间1'] = data['下单时间'].dt.day
data['下单时间2'] = data['下单时间'].dt.hour

# %%
data_day_24 = data[data['下单时间1'] == 24]
data_day_25 = data[data['下单时间1'] == 25]

# %%
a = drop_du(data_day_24,'下单时间2')
collection_d = Counter(a[1])
print(collection_d)
# Out:
# Counter({23: 98, 22: 93, 21: 88, 19: 71, 15: 66, 17: 65, 16: 61, 18: 56, 20: 56, 14: 45, 11: 43, 12: 42, 13: 42, 10: 33, 9: 23, 8: 17, 7: 7, 6: 7, 1: 4, 5: 4, 2: 3, 3: 3})

# %%
b = drop_du(data_day_25,'下单时间2')
collection_e = Counter(b[1])
print(collection_e)
# Out:
# Counter({9: 375, 10: 340, 11: 324, 12: 315, 13: 291, 8: 269, 15: 251, 14: 241, 16: 227, 17: 185, 18: 166, 19: 146, 7: 110, 20: 82, 21: 60, 0: 56, 6: 44, 22: 43, 1: 18, 5: 15, 2: 14, 3: 14, 4: 11, 23: 3})

# %%
df24 = pd.DataFrame(pd.Series(a[1]), columns=['count'])
df24 = df24.reset_index().rename(columns={'index':'time'})
df24.sort_values("time",inplace=True)
df24['time'] = df24['time'].apply(str)

# %%
df25 = pd.DataFrame(pd.Series(b[1]), columns=['count'])
df25 = df25.reset_index().rename(columns={'index':'time'})
df25.sort_values("time",inplace=True)
df25['time'] = df25['time'].apply(str)

# %%
plt.plot(df24['time'],df24['count'])

# %%
plt.plot(df25['time'],df25['count'])

# %%
lujing = r'C:\Users\Administrator\datas\艾尚花语\活动&单门店\七夕\七夕门店.csv'
code = 'gbk'
df = improt_data(lujing,code)

# %%
df1 = df[df['开始日期']  == 20200824]
df2 = df[df['开始日期']  == 20200825]

# %%
df1.sort_values('曝光人数',ascending=False)
# Out:
#          开始日期      结束日期     商家ID                      商家名称  运营组        省份  \
# 296  20200824  20200824  9529764   花之坊鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组  新疆维吾尔自治区
# 24   20200824  20200824  9043996     花间时光(七夕节预定,生日鲜花，表白鲜花)  鲜花组       河南省
# 36   20200824  20200824  9221240  印象花坊鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       山东省
# 170  20200824  20200824  9385115   千千惠鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       山东省
# 396  20200824  20200824  9685750  花语花卉鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       湖北省
# ..        ...       ...      ...                       ...  ...       ...
# 158  20200824  20200824  9370710               戴氏花艺鲜花礼品鲜花店  鲜花组       山东省
# 466  20200824  20200824  9774419           锦缘花艺·七夕节鲜花,表白鲜花  鲜花组       浙江省
# 118  20200824  20200824  9338707  月月花屋鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       湖南省
# 66   20200824  20200824  9284178    金缘鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       辽宁省
# 152  20200824  20200824  9364823  花颜花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组       山东省
#
#        城市 是否新增商家    首次上线日期 门店在线状态  （日均）预设营业时长（h）  （日均）在线营业时长（h）  曝光人数  入店人数  \
# 296  哈密地区      否  20200717     在线           11.0           10.7  4137   351
# 24     许昌      否  20200508     在线           24.0           24.0  2190   151
# 36     潍坊      否  20200602     在线           18.0           18.0  1918   162
# 170    临沂      否  20200623     在线           23.0           23.0  1855   191
# 396    襄阳      否  20200812     在线           17.0           17.0  1710    76
# ..    ...    ...       ...    ...            ...            ...   ...   ...
# 158    临沂      否  20200708     在线            0.0            0.0    27     2
# 466    杭州      否  20200819     在线            0.0            0.0    27     3
# 118    邵阳      否  20200617     在线            0.0            0.0    20     0
# 66     锦州      否  20200619     在线            0.0            0.0    18     0
# 152    青岛      否  20200619     在线            0.0            0.0    17     0
#
#      下单人数  下单新客人数  入店转化率  下单转化率  推单数  有效订单数   原价交易额    实付交易额   商家补贴金额  \
# 296    17      16   8.48  4.84%   18     16  5244.0  4370.01   868.99
# 24     12      11   6.89  7.95%   13     11  3249.0  1800.00  1504.00
# 36     10      10   8.45  6.17%   10     10  3970.0  2091.00  1929.00
# 170    12      12  10.30  6.28%   12     11  4629.0  2289.03  2506.97
# 396     2       2   4.44  2.63%    2      2   578.0   317.00   271.00
# ..    ...     ...    ...    ...  ...    ...     ...      ...      ...
# 158     0       0   7.41     0%    0      0     0.0     0.00     0.00
# 466     0       0  11.11     0%    0      0     0.0     0.00     0.00
# 118     0       0   0.00     0%    0      0     0.0     0.00     0.00
# 66      0       0   0.00     0%    0      0     0.0     0.00     0.00
# 152     0       0   0.00     0%    0      0     0.0     0.00     0.00
#
#      商家原因取消订单数  商家拒单数  商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  \
# 296          0      0         0             0          0                0
# 24           0      0         0             0          0                0
# 36           0      0         0             0          0                0
# 170          0      0         0             0          0                0
# 396          0      0         0             0          0                0
# ..         ...    ...       ...           ...        ...              ...
# 158          0      0         0             0          0                0
# 466          0      0         0             0          0                0
# 118          0      0         0             0          0                0
# 66           0      0         0             0          0                0
# 152          0      0         0             0          0                0
#
#      商家质量问题导致用户退款订单数  配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  平均骑手到店等待时间（min）  \
# 296                0          0        0           18                0
# 24                 0          0        0           12                0
# 36                 0          0        0           10                0
# 170                0          0        0           12                0
# 396                0          0        0            2                0
# ..               ...        ...      ...          ...              ...
# 158                0          0        0            0                0
# 466                0          0        0            0                0
# 118                0          0        0            0                0
# 66                 0          0        0            0                0
# 152                0          0        0            0                0
#
#      平均骑手送货时长（min）  IM会话数  IM回复数   IM回复率  IM1分钟回复数  差评订单数  投诉订单数  平均商家评分  \
# 296              0     18     15   83.33        13      0      0     5.0
# 24               0      4      4  100.00         4      0      0     5.0
# 36               0      4      4  100.00         4      0      0     5.0
# 170              0      6      6  100.00         3      0      0     4.9
# 396              0      4      4  100.00         2      0      0     5.0
# ..             ...    ...    ...     ...       ...    ...    ...     ...
# 158              0      0      0    0.00         0      0      0     0.0
# 466              0      0      0    0.00         0      0      0     0.0
# 118              0      0      0    0.00         0      0      0     0.0
# 66               0      0      0    0.00         0      0      0     0.0
# 152              0      0      0    0.00         0      0      0     0.0
#
#      平均商品评分  平均配送评分  平均配送时长（min）  资质类型（仅药品）  资质有效期（仅药品）
# 296     5.0     5.0          0.0        NaN         NaN
# 24      5.0     5.0          0.0        NaN         NaN
# 36      5.0     5.0          0.0        NaN         NaN
# 170     4.9     5.0          0.0        NaN         NaN
# 396     5.0     5.0          0.0        NaN         NaN
# ..      ...     ...          ...        ...         ...
# 158     0.0     0.0          0.0        NaN         NaN
# 466     0.0     0.0          0.0        NaN         NaN
# 118     0.0     0.0          0.0        NaN         NaN
# 66      0.0     0.0          0.0        NaN         NaN
# 152     0.0     0.0          0.0        NaN         NaN
#
# [244 rows x 47 columns]

# %%
Q1 = np.percentile(df2['有效订单数'], 25)
Q3 = np.percentile(df2['有效订单数'], 75)
Q2 = np.percentile(df2['有效订单数'], 50)
Q4 = Q3 + 1.5*IQ
IQ = Q3 - Q1

# %%
print(Q1)
print(Q2)
print(Q3)
print(Q4)
# Out:
# 2.0
# 9.0
# 20.0
# 47.0

# %%
df2[df2['有效订单数'] > 47]
# Out:
#         开始日期      结束日期     商家ID                    商家名称  运营组   省份  城市 是否新增商家  \
# 57  20200825  20200825  9266337  群芳鲜花店(七夕节预定,生日鲜花，表白鲜花)  鲜花组  江苏省  泰州      否
#
#       首次上线日期 门店在线状态  （日均）预设营业时长（h）  （日均）在线营业时长（h）  曝光人数  入店人数  下单人数  下单新客人数  \
# 57  20200606     在线           15.0           12.9  1478   608    53      49
#
#     入店转化率  下单转化率  推单数  有效订单数    原价交易额    实付交易额   商家补贴金额  商家原因取消订单数  商家拒单数  \
# 57  41.14  8.72%   52     50  15229.0  9377.99  6093.01          0      0
#
#     商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  商家质量问题导致用户退款订单数  \
# 57         0             0          0                0                0
#
#     配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  平均骑手到店等待时间（min）  平均骑手送货时长（min）  IM会话数  \
# 57          0        0           52                0              0     28
#
#     IM回复数  IM回复率  IM1分钟回复数  差评订单数  投诉订单数  平均商家评分  平均商品评分  平均配送评分  平均配送时长（min）  \
# 57     12  42.86         4      0      0     5.0     5.0     5.0          0.0
#
#     资质类型（仅药品）  资质有效期（仅药品）
# 57        NaN         NaN

# %%
df1.corr()
# Out:
#                  开始日期  结束日期      商家ID    首次上线日期  （日均）预设营业时长（h）  （日均）在线营业时长（h）  \
# 开始日期              NaN   NaN       NaN       NaN            NaN            NaN
# 结束日期              NaN   NaN       NaN       NaN            NaN            NaN
# 商家ID              NaN   NaN  1.000000  0.961186       0.015442      -0.005423
# 首次上线日期            NaN   NaN  0.961186  1.000000       0.007349      -0.011875
# （日均）预设营业时长（h）     NaN   NaN  0.015442  0.007349       1.000000       0.997405
# （日均）在线营业时长（h）     NaN   NaN -0.005423 -0.011875       0.997405       1.000000
# 曝光人数              NaN   NaN  0.030305  0.052342       0.231019       0.229649
# 入店人数              NaN   NaN -0.136481 -0.111879       0.247164       0.246389
# 下单人数              NaN   NaN -0.154571 -0.146150       0.194843       0.193122
# 下单新客人数            NaN   NaN -0.161180 -0.157449       0.186313       0.185923
# 入店转化率             NaN   NaN -0.163206 -0.159968       0.127895       0.125938
# 推单数               NaN   NaN -0.163581 -0.157733       0.186624       0.185623
# 有效订单数             NaN   NaN -0.171643 -0.165549       0.183092       0.182465
# 原价交易额             NaN   NaN -0.178862 -0.171128       0.176354       0.175884
# 实付交易额             NaN   NaN -0.172281 -0.165563       0.168182       0.167328
# 商家补贴金额            NaN   NaN -0.178297 -0.169614       0.180975       0.181074
# 商家原因取消订单数         NaN   NaN  0.078486  0.073491       0.012649       0.007080
# 商家拒单数             NaN   NaN  0.164110  0.165255      -0.069405      -0.081250
# 商家超时未接单数          NaN   NaN -0.053518 -0.052353       0.060796       0.062621
# 商家取消不告知用户订单数      NaN   NaN       NaN       NaN            NaN            NaN
# 缺货导致退款订单数         NaN   NaN -0.002739 -0.018036       0.065327       0.068248
# 商家少送错送导致用户退款订单数   NaN   NaN       NaN       NaN            NaN            NaN
# 商家质量问题导致用户退款订单数   NaN   NaN       NaN       NaN            NaN            NaN
# 配送原因取消订单数         NaN   NaN       NaN       NaN            NaN            NaN
# 拣货超时订单数           NaN   NaN       NaN       NaN            NaN            NaN
# 使用间或完成按钮订单数       NaN   NaN -0.161402 -0.156030       0.184961       0.184127
# 平均骑手到店等待时间（min）   NaN   NaN       NaN       NaN            NaN            NaN
# 平均骑手送货时长（min）     NaN   NaN -0.017962 -0.042866       0.112951       0.114455
# IM会话数             NaN   NaN -0.193890 -0.176012       0.128532       0.129713
# IM回复数             NaN   NaN -0.201638 -0.185761       0.132841       0.134566
# IM回复率             NaN   NaN -0.074670 -0.063961       0.149382       0.148239
# IM1分钟回复数          NaN   NaN -0.202157 -0.187901       0.143677       0.146268
# 差评订单数             NaN   NaN  0.044514  0.039679       0.050728       0.051057
# 投诉订单数             NaN   NaN       NaN       NaN            NaN            NaN
# 平均商家评分            NaN   NaN -0.076408 -0.065604       0.228846       0.235927
# 平均商品评分            NaN   NaN -0.076408 -0.065604       0.228846       0.235927
# 平均配送评分            NaN   NaN -0.061240 -0.049559       0.232461       0.238338
# 平均配送时长（min）       NaN   NaN -0.127662 -0.127705       0.156400       0.158483
# 资质类型（仅药品）         NaN   NaN       NaN       NaN            NaN            NaN
# 资质有效期（仅药品）        NaN   NaN       NaN       NaN            NaN            NaN
#
#                      曝光人数      入店人数      下单人数    下单新客人数     入店转化率       推单数  \
# 开始日期                  NaN       NaN       NaN       NaN       NaN       NaN
# 结束日期                  NaN       NaN       NaN       NaN       NaN       NaN
# 商家ID             0.030305 -0.136481 -0.154571 -0.161180 -0.163206 -0.163581
# 首次上线日期           0.052342 -0.111879 -0.146150 -0.157449 -0.159968 -0.157733
# （日均）预设营业时长（h）    0.231019  0.247164  0.194843  0.186313  0.127895  0.186624
# （日均）在线营业时长（h）    0.229649  0.246389  0.193122  0.185923  0.125938  0.185623
# 曝光人数             1.000000  0.711055  0.464444  0.464438  0.023069  0.477796
# 入店人数             0.711055  1.000000  0.840566  0.830753  0.626627  0.839083
# 下单人数             0.464444  0.840566  1.000000  0.987861  0.682006  0.992436
# 下单新客人数           0.464438  0.830753  0.987861  1.000000  0.676452  0.991560
# 入店转化率            0.023069  0.626627  0.682006  0.676452  1.000000  0.669971
# 推单数              0.477796  0.839083  0.992436  0.991560  0.669971  1.000000
# 有效订单数            0.457469  0.830585  0.989757  0.997425  0.677350  0.993511
# 原价交易额            0.470421  0.813993  0.967882  0.973190  0.626174  0.972329
# 实付交易额            0.544750  0.841485  0.949764  0.955308  0.591172  0.954699
# 商家补贴金额           0.363722  0.747877  0.947206  0.952075  0.641108  0.950669
# 商家原因取消订单数        0.115592  0.107611  0.182799  0.137584  0.070672  0.196406
# 商家拒单数            0.093041  0.094475  0.184669  0.140730  0.105168  0.189341
# 商家超时未接单数         0.005722 -0.021913 -0.004843 -0.013499 -0.039293  0.005008
# 商家取消不告知用户订单数          NaN       NaN       NaN       NaN       NaN       NaN
# 缺货导致退款订单数        0.126222  0.138453  0.157612  0.127939  0.053603  0.171123
# 商家少送错送导致用户退款订单数       NaN       NaN       NaN       NaN       NaN       NaN
# 商家质量问题导致用户退款订单数       NaN       NaN       NaN       NaN       NaN       NaN
# 配送原因取消订单数             NaN       NaN       NaN       NaN       NaN       NaN
# 拣货超时订单数               NaN       NaN       NaN       NaN       NaN       NaN
# 使用间或完成按钮订单数      0.473534  0.838166  0.991956  0.993922  0.670784  0.998089
# 平均骑手到店等待时间（min）       NaN       NaN       NaN       NaN       NaN       NaN
# 平均骑手送货时长（min）    0.105730  0.108906  0.160078  0.183162  0.012288  0.163187
# IM会话数            0.532929  0.822586  0.861640  0.842789  0.564633  0.852665
# IM回复数            0.510107  0.814322  0.862235  0.842059  0.568857  0.851546
# IM回复率            0.269261  0.475846  0.504370  0.512088  0.487373  0.500338
# IM1分钟回复数         0.501630  0.802242  0.844433  0.824059  0.554048  0.833906
# 差评订单数            0.066185  0.200771  0.209777  0.212840  0.179324  0.200311
# 投诉订单数                 NaN       NaN       NaN       NaN       NaN       NaN
# 平均商家评分           0.415863  0.566317  0.487083  0.493763  0.387069  0.495485
# 平均商品评分           0.415863  0.566317  0.487083  0.493763  0.387069  0.495485
# 平均配送评分           0.433853  0.557785  0.474393  0.478341  0.326478  0.482088
# 平均配送时长（min）      0.001136  0.028654  0.040388  0.049629  0.049949  0.039568
# 资质类型（仅药品）             NaN       NaN       NaN       NaN       NaN       NaN
# 资质有效期（仅药品）            NaN       NaN       NaN       NaN       NaN       NaN
#
#                     有效订单数     原价交易额     实付交易额    商家补贴金额  商家原因取消订单数     商家拒单数  \
# 开始日期                  NaN       NaN       NaN       NaN        NaN       NaN
# 结束日期                  NaN       NaN       NaN       NaN        NaN       NaN
# 商家ID            -0.171643 -0.178862 -0.172281 -0.178297   0.078486  0.164110
# 首次上线日期          -0.165549 -0.171128 -0.165563 -0.169614   0.073491  0.165255
# （日均）预设营业时长（h）    0.183092  0.176354  0.168182  0.180975   0.012649 -0.069405
# （日均）在线营业时长（h）    0.182465  0.175884  0.167328  0.181074   0.007080 -0.081250
# 曝光人数             0.457469  0.470421  0.544750  0.363722   0.115592  0.093041
# 入店人数             0.830585  0.813993  0.841485  0.747877   0.107611  0.094475
# 下单人数             0.989757  0.967882  0.949764  0.947206   0.182799  0.184669
# 下单新客人数           0.997425  0.973190  0.955308  0.952075   0.137584  0.140730
# 入店转化率            0.677350  0.626174  0.591172  0.641108   0.070672  0.105168
# 推单数              0.993511  0.972329  0.954699  0.950669   0.196406  0.189341
# 有效订单数            1.000000  0.979784  0.961708  0.958177   0.131444  0.135092
# 原价交易额            0.979784  1.000000  0.983020  0.975943   0.114185  0.123180
# 实付交易额            0.961708  0.983020  1.000000  0.919501   0.094202  0.101125
# 商家补贴金额           0.958177  0.975943  0.919501  1.000000   0.132522  0.143213
# 商家原因取消订单数        0.131444  0.114185  0.094202  0.132522   1.000000  0.769176
# 商家拒单数            0.135092  0.123180  0.101125  0.143213   0.769176  1.000000
# 商家超时未接单数        -0.014649 -0.017117 -0.013604 -0.020170   0.490940 -0.016138
# 商家取消不告知用户订单数          NaN       NaN       NaN       NaN        NaN       NaN
# 缺货导致退款订单数        0.123362  0.103378  0.085435  0.119955   0.608580  0.307687
# 商家少送错送导致用户退款订单数       NaN       NaN       NaN       NaN        NaN       NaN
# 商家质量问题导致用户退款订单数       NaN       NaN       NaN       NaN        NaN       NaN
# 配送原因取消订单数             NaN       NaN       NaN       NaN        NaN       NaN
# 拣货超时订单数               NaN       NaN       NaN       NaN        NaN       NaN
# 使用间或完成按钮订单数      0.995996  0.975652  0.958016  0.953786   0.158400  0.160454
# 平均骑手到店等待时间（min）       NaN       NaN       NaN       NaN        NaN       NaN
# 平均骑手送货时长（min）    0.177499  0.141783  0.185006  0.079289  -0.012063 -0.009279
# IM会话数            0.851491  0.848786  0.866912  0.790225   0.157015  0.129964
# IM回复数            0.851969  0.847822  0.860997  0.795393   0.151506  0.121338
# IM回复率            0.508541  0.478533  0.463364  0.477384   0.097909  0.088098
# IM1分钟回复数         0.833645  0.832156  0.852843  0.770894   0.162687  0.108033
# 差评订单数            0.213107  0.195596  0.167047  0.220707  -0.024276 -0.018673
# 投诉订单数                 NaN       NaN       NaN       NaN        NaN       NaN
# 平均商家评分           0.492919  0.482452  0.476751  0.470218   0.109339  0.055229
# 平均商品评分           0.492919  0.482452  0.476751  0.470218   0.109339  0.055229
# 平均配送评分           0.476503  0.467483  0.465423  0.451508   0.116218  0.059837
# 平均配送时长（min）      0.047131  0.035623  0.046516  0.020144  -0.016703 -0.012848
# 资质类型（仅药品）             NaN       NaN       NaN       NaN        NaN       NaN
# 资质有效期（仅药品）            NaN       NaN       NaN       NaN        NaN       NaN
#
#                  商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  \
# 开始日期                  NaN           NaN        NaN              NaN
# 结束日期                  NaN           NaN        NaN              NaN
# 商家ID            -0.053518           NaN  -0.002739              NaN
# 首次上线日期          -0.052353           NaN  -0.018036              NaN
# （日均）预设营业时长（h）    0.060796           NaN   0.065327              NaN
# （日均）在线营业时长（h）    0.062621           NaN   0.068248              NaN
# 曝光人数             0.005722           NaN   0.126222              NaN
# 入店人数            -0.021913           NaN   0.138453              NaN
# 下单人数            -0.004843           NaN   0.157612              NaN
# 下单新客人数          -0.013499           NaN   0.127939              NaN
# 入店转化率           -0.039293           NaN   0.053603              NaN
# 推单数              0.005008           NaN   0.171123              NaN
# 有效订单数           -0.014649           NaN   0.123362              NaN
# 原价交易额           -0.017117           NaN   0.103378              NaN
# 实付交易额           -0.013604           NaN   0.085435              NaN
# 商家补贴金额          -0.020170           NaN   0.119955              NaN
# 商家原因取消订单数        0.490940           NaN   0.608580              NaN
# 商家拒单数           -0.016138           NaN   0.307687              NaN
# 商家超时未接单数         1.000000           NaN  -0.010143              NaN
# 商家取消不告知用户订单数          NaN           NaN        NaN              NaN
# 缺货导致退款订单数       -0.010143           NaN   1.000000              NaN
# 商家少送错送导致用户退款订单数       NaN           NaN        NaN              NaN
# 商家质量问题导致用户退款订单数       NaN           NaN        NaN              NaN
# 配送原因取消订单数             NaN           NaN        NaN              NaN
# 拣货超时订单数               NaN           NaN        NaN              NaN
# 使用间或完成按钮订单数     -0.018550           NaN   0.153437              NaN
# 平均骑手到店等待时间（min）       NaN           NaN        NaN              NaN
# 平均骑手送货时长（min）   -0.007157           NaN  -0.005832              NaN
# IM会话数            0.017532           NaN   0.153900              NaN
# IM回复数            0.021967           NaN   0.148716              NaN
# IM回复率            0.023083           NaN   0.070028              NaN
# IM1分钟回复数         0.027634           NaN   0.189723              NaN
# 差评订单数           -0.014404           NaN  -0.011736              NaN
# 投诉订单数                 NaN           NaN        NaN              NaN
# 平均商家评分           0.057753           NaN   0.106930              NaN
# 平均商品评分           0.057753           NaN   0.106930              NaN
# 平均配送评分           0.061355           NaN   0.111913              NaN
# 平均配送时长（min）     -0.009911           NaN  -0.008075              NaN
# 资质类型（仅药品）             NaN           NaN        NaN              NaN
# 资质有效期（仅药品）            NaN           NaN        NaN              NaN
#
#                  商家质量问题导致用户退款订单数  配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  \
# 开始日期                         NaN        NaN      NaN          NaN
# 结束日期                         NaN        NaN      NaN          NaN
# 商家ID                         NaN        NaN      NaN    -0.161402
# 首次上线日期                       NaN        NaN      NaN    -0.156030
# （日均）预设营业时长（h）                NaN        NaN      NaN     0.184961
# （日均）在线营业时长（h）                NaN        NaN      NaN     0.184127
# 曝光人数                         NaN        NaN      NaN     0.473534
# 入店人数                         NaN        NaN      NaN     0.838166
# 下单人数                         NaN        NaN      NaN     0.991956
# 下单新客人数                       NaN        NaN      NaN     0.993922
# 入店转化率                        NaN        NaN      NaN     0.670784
# 推单数                          NaN        NaN      NaN     0.998089
# 有效订单数                        NaN        NaN      NaN     0.995996
# 原价交易额                        NaN        NaN      NaN     0.975652
# 实付交易额                        NaN        NaN      NaN     0.958016
# 商家补贴金额                       NaN        NaN      NaN     0.953786
# 商家原因取消订单数                    NaN        NaN      NaN     0.158400
# 商家拒单数                        NaN        NaN      NaN     0.160454
# 商家超时未接单数                     NaN        NaN      NaN    -0.018550
# 商家取消不告知用户订单数                 NaN        NaN      NaN          NaN
# 缺货导致退款订单数                    NaN        NaN      NaN     0.153437
# 商家少送错送导致用户退款订单数              NaN        NaN      NaN          NaN
# 商家质量问题导致用户退款订单数              NaN        NaN      NaN          NaN
# 配送原因取消订单数                    NaN        NaN      NaN          NaN
# 拣货超时订单数                      NaN        NaN      NaN          NaN
# 使用间或完成按钮订单数                  NaN        NaN      NaN     1.000000
# 平均骑手到店等待时间（min）              NaN        NaN      NaN          NaN
# 平均骑手送货时长（min）                NaN        NaN      NaN     0.165364
# IM会话数                        NaN        NaN      NaN     0.851696
# IM回复数                        NaN        NaN      NaN     0.851030
# IM回复率                        NaN        NaN      NaN     0.502195
# IM1分钟回复数                     NaN        NaN      NaN     0.834418
# 差评订单数                        NaN        NaN      NaN     0.210715
# 投诉订单数                        NaN        NaN      NaN          NaN
# 平均商家评分                       NaN        NaN      NaN     0.496155
# 平均商品评分                       NaN        NaN      NaN     0.496155
# 平均配送评分                       NaN        NaN      NaN     0.482290
# 平均配送时长（min）                  NaN        NaN      NaN     0.040898
# 资质类型（仅药品）                    NaN        NaN      NaN          NaN
# 资质有效期（仅药品）                   NaN        NaN      NaN          NaN
#
#                  平均骑手到店等待时间（min）  平均骑手送货时长（min）     IM会话数     IM回复数     IM回复率  \
# 开始日期                         NaN            NaN       NaN       NaN       NaN
# 结束日期                         NaN            NaN       NaN       NaN       NaN
# 商家ID                         NaN      -0.017962 -0.193890 -0.201638 -0.074670
# 首次上线日期                       NaN      -0.042866 -0.176012 -0.185761 -0.063961
# （日均）预设营业时长（h）                NaN       0.112951  0.128532  0.132841  0.149382
# （日均）在线营业时长（h）                NaN       0.114455  0.129713  0.134566  0.148239
# 曝光人数                         NaN       0.105730  0.532929  0.510107  0.269261
# 入店人数                         NaN       0.108906  0.822586  0.814322  0.475846
# 下单人数                         NaN       0.160078  0.861640  0.862235  0.504370
# 下单新客人数                       NaN       0.183162  0.842789  0.842059  0.512088
# 入店转化率                        NaN       0.012288  0.564633  0.568857  0.487373
# 推单数                          NaN       0.163187  0.852665  0.851546  0.500338
# 有效订单数                        NaN       0.177499  0.851491  0.851969  0.508541
# 原价交易额                        NaN       0.141783  0.848786  0.847822  0.478533
# 实付交易额                        NaN       0.185006  0.866912  0.860997  0.463364
# 商家补贴金额                       NaN       0.079289  0.790225  0.795393  0.477384
# 商家原因取消订单数                    NaN      -0.012063  0.157015  0.151506  0.097909
# 商家拒单数                        NaN      -0.009279  0.129964  0.121338  0.088098
# 商家超时未接单数                     NaN      -0.007157  0.017532  0.021967  0.023083
# 商家取消不告知用户订单数                 NaN            NaN       NaN       NaN       NaN
# 缺货导致退款订单数                    NaN      -0.005832  0.153900  0.148716  0.070028
# 商家少送错送导致用户退款订单数              NaN            NaN       NaN       NaN       NaN
# 商家质量问题导致用户退款订单数              NaN            NaN       NaN       NaN       NaN
# 配送原因取消订单数                    NaN            NaN       NaN       NaN       NaN
# 拣货超时订单数                      NaN            NaN       NaN       NaN       NaN
# 使用间或完成按钮订单数                  NaN       0.165364  0.851696  0.851030  0.502195
# 平均骑手到店等待时间（min）              NaN            NaN       NaN       NaN       NaN
# 平均骑手送货时长（min）                NaN       1.000000  0.098408  0.104942  0.057756
# IM会话数                        NaN       0.098408  1.000000  0.994565  0.556367
# IM回复数                        NaN       0.104942  0.994565  1.000000  0.572627
# IM回复率                        NaN       0.057756  0.556367  0.572627  1.000000
# IM1分钟回复数                     NaN       0.133878  0.965110  0.969975  0.559886
# 差评订单数                        NaN      -0.008282  0.177532  0.179038  0.082661
# 投诉订单数                        NaN            NaN       NaN       NaN       NaN
# 平均商家评分                       NaN       0.071535  0.441734  0.439372  0.418675
# 平均商品评分                       NaN       0.071535  0.441734  0.439372  0.418675
# 平均配送评分                       NaN       0.078971  0.421233  0.416708  0.391927
# 平均配送时长（min）                  NaN       0.233755  0.054570  0.059932  0.079973
# 资质类型（仅药品）                    NaN            NaN       NaN       NaN       NaN
# 资质有效期（仅药品）                   NaN            NaN       NaN       NaN       NaN
#
#                  IM1分钟回复数     差评订单数  投诉订单数    平均商家评分    平均商品评分    平均配送评分  \
# 开始日期                  NaN       NaN    NaN       NaN       NaN       NaN
# 结束日期                  NaN       NaN    NaN       NaN       NaN       NaN
# 商家ID            -0.202157  0.044514    NaN -0.076408 -0.076408 -0.061240
# 首次上线日期          -0.187901  0.039679    NaN -0.065604 -0.065604 -0.049559
# （日均）预设营业时长（h）    0.143677  0.050728    NaN  0.228846  0.228846  0.232461
# （日均）在线营业时长（h）    0.146268  0.051057    NaN  0.235927  0.235927  0.238338
# 曝光人数             0.501630  0.066185    NaN  0.415863  0.415863  0.433853
# 入店人数             0.802242  0.200771    NaN  0.566317  0.566317  0.557785
# 下单人数             0.844433  0.209777    NaN  0.487083  0.487083  0.474393
# 下单新客人数           0.824059  0.212840    NaN  0.493763  0.493763  0.478341
# 入店转化率            0.554048  0.179324    NaN  0.387069  0.387069  0.326478
# 推单数              0.833906  0.200311    NaN  0.495485  0.495485  0.482088
# 有效订单数            0.833645  0.213107    NaN  0.492919  0.492919  0.476503
# 原价交易额            0.832156  0.195596    NaN  0.482452  0.482452  0.467483
# 实付交易额            0.852843  0.167047    NaN  0.476751  0.476751  0.465423
# 商家补贴金额           0.770894  0.220707    NaN  0.470218  0.470218  0.451508
# 商家原因取消订单数        0.162687 -0.024276    NaN  0.109339  0.109339  0.116218
# 商家拒单数            0.108033 -0.018673    NaN  0.055229  0.055229  0.059837
# 商家超时未接单数         0.027634 -0.014404    NaN  0.057753  0.057753  0.061355
# 商家取消不告知用户订单数          NaN       NaN    NaN       NaN       NaN       NaN
# 缺货导致退款订单数        0.189723 -0.011736    NaN  0.106930  0.106930  0.111913
# 商家少送错送导致用户退款订单数       NaN       NaN    NaN       NaN       NaN       NaN
# 商家质量问题导致用户退款订单数       NaN       NaN    NaN       NaN       NaN       NaN
# 配送原因取消订单数             NaN       NaN    NaN       NaN       NaN       NaN
# 拣货超时订单数               NaN       NaN    NaN       NaN       NaN       NaN
# 使用间或完成按钮订单数      0.834418  0.210715    NaN  0.496155  0.496155  0.482290
# 平均骑手到店等待时间（min）       NaN       NaN    NaN       NaN       NaN       NaN
# 平均骑手送货时长（min）    0.133878 -0.008282    NaN  0.071535  0.071535  0.078971
# IM会话数            0.965110  0.177532    NaN  0.441734  0.441734  0.421233
# IM回复数            0.969975  0.179038    NaN  0.439372  0.439372  0.416708
# IM回复率            0.559886  0.082661    NaN  0.418675  0.418675  0.391927
# IM1分钟回复数         1.000000  0.193102    NaN  0.456690  0.456690  0.431137
# 差评订单数            0.193102  1.000000    NaN  0.088740  0.088740  0.092978
# 投诉订单数                 NaN       NaN    NaN       NaN       NaN       NaN
# 平均商家评分           0.456690  0.088740    NaN  1.000000  1.000000  0.966224
# 平均商品评分           0.456690  0.088740    NaN  1.000000  1.000000  0.966224
# 平均配送评分           0.431137  0.092978    NaN  0.966224  0.966224  1.000000
# 平均配送时长（min）      0.045340 -0.011468    NaN -0.019598 -0.019598 -0.015688
# 资质类型（仅药品）             NaN       NaN    NaN       NaN       NaN       NaN
# 资质有效期（仅药品）            NaN       NaN    NaN       NaN       NaN       NaN
#
#                  平均配送时长（min）  资质类型（仅药品）  资质有效期（仅药品）
# 开始日期                     NaN        NaN         NaN
# 结束日期                     NaN        NaN         NaN
# 商家ID               -0.127662        NaN         NaN
# 首次上线日期             -0.127705        NaN         NaN
# （日均）预设营业时长（h）       0.156400        NaN         NaN
# （日均）在线营业时长（h）       0.158483        NaN         NaN
# 曝光人数                0.001136        NaN         NaN
# 入店人数                0.028654        NaN         NaN
# 下单人数                0.040388        NaN         NaN
# 下单新客人数              0.049629        NaN         NaN
# 入店转化率               0.049949        NaN         NaN
# 推单数                 0.039568        NaN         NaN
# 有效订单数               0.047131        NaN         NaN
# 原价交易额               0.035623        NaN         NaN
# 实付交易额               0.046516        NaN         NaN
# 商家补贴金额              0.020144        NaN         NaN
# 商家原因取消订单数          -0.016703        NaN         NaN
# 商家拒单数              -0.012848        NaN         NaN
# 商家超时未接单数           -0.009911        NaN         NaN
# 商家取消不告知用户订单数             NaN        NaN         NaN
# 缺货导致退款订单数          -0.008075        NaN         NaN
# 商家少送错送导致用户退款订单数          NaN        NaN         NaN
# 商家质量问题导致用户退款订单数          NaN        NaN         NaN
# 配送原因取消订单数                NaN        NaN         NaN
# 拣货超时订单数                  NaN        NaN         NaN
# 使用间或完成按钮订单数         0.040898        NaN         NaN
# 平均骑手到店等待时间（min）          NaN        NaN         NaN
# 平均骑手送货时长（min）       0.233755        NaN         NaN
# IM会话数               0.054570        NaN         NaN
# IM回复数               0.059932        NaN         NaN
# IM回复率               0.079973        NaN         NaN
# IM1分钟回复数            0.045340        NaN         NaN
# 差评订单数              -0.011468        NaN         NaN
# 投诉订单数                    NaN        NaN         NaN
# 平均商家评分             -0.019598        NaN         NaN
# 平均商品评分             -0.019598        NaN         NaN
# 平均配送评分             -0.015688        NaN         NaN
# 平均配送时长（min）         1.000000        NaN         NaN
# 资质类型（仅药品）                NaN        NaN         NaN
# 资质有效期（仅药品）               NaN        NaN         NaN
