# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns',None)
from sklearn.feature_extraction.text import CountVectorizer
import jieba # 导入关键字提取库
import pandas as pd  # 导入pandas
from collections import Counter

# %%
def improt_data(lujing,code):
    data = pd.read_csv(lujing,encoding =code)
    return data

def wenzi(data,z,a):
    list_2 = []
    list_3 = []
    lis = []
    
    for row,data_ in data.iterrows():
#         name = data_['接单时间']
#         list_3.append(name)
        y = data_[a]
        tr = y.find(z)
        if tr > -1 :
            list_2.append(y)
    print('关于' + '“' + z + '”' + '的订单数量是：',len(list_2))  
    lis.append(list_2)
    lis.append(list_3)
    return lis

def wenzi1(data,z,a):
    list_2 = []
    list_3 = []
    lis = []
    
    for row,data_ in data.iterrows():
        name = data_['接单时间1']
        list_3.append(name)
        y = data_[a]
        tr = y.find(z)
        if tr > -1 :
            list_2.append(y)
    print('关于' + '“' + z + '”' + '的订单数量是：',len(list_2))  
    lis.append(list_2)
    lis.append(list_3)
    return lis

def jiebe(data):    
    text_list = []
    for line in data:
        hou = ",".join(jieba.cut(line))
        strlist = hou.split(',') 
        text_list.append(strlist)
    return text_list

def clean(list_name_,stopwords_):    
    clean_line = []
    for line in list_name_:
        haha = []
        for word in line:
            if word in stopwords_:
                continue
            haha.append(word)
        haha = ','.join(haha)
        clean_line.append(haha)

    return clean_line

def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    dict_ = {}
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['订单编号'].count()
        if sum_ > 1 :
            list__.append(b)
            dict_[b] = sum_
        else:
            list_sum.append(b)
    k = [list__,dict_,list_sum]
    return k

# %%
lujing = '问题订单.csv'
code = 'gbk'
wrong = improt_data(lujing,code)

# %%
wrong
# Out:
#                     订单编号                   下单时间                店铺名称     店铺ID  \
# 0      27219013382704585  2020-08-25 11:58:34\t  遇见花开(七夕预定，表白，鲜花)\t  2721901
# 1      35221483470084206  2020-08-25 08:31:40\t        馨梦缘花艺·七夕鲜花\t  3522148
# 2       9112331300204059  2020-08-25 09:16:59\t      邂逅花坊鲜花（花园花坊）\t   911233
# 3      35221482386186755  2020-08-25 09:02:47\t        馨梦缘花艺·七夕鲜花\t  3522148
# 4      27219012141837702  2020-08-25 12:44:58\t  遇见花开(七夕预定，表白，鲜花)\t  2721901
# ...                  ...                    ...                 ...      ...
# 12655  97688012342655417  2020-08-25 13:51:39\t            花好月缘花店\t  9768801
# 12656  97688010372010069  2020-08-25 13:51:45\t            花好月缘花店\t  9768801
# 12657  97688010890902196  2020-08-25 14:00:51\t            花好月缘花店\t  9768801
# 12658  97688013774986605  2020-08-25 14:08:36\t            花好月缘花店\t  9768801
# 12659  97688012454686031  2020-08-25 14:12:39\t            花好月缘花店\t  9768801
#
#       店铺所在城市  订单总金额（元）  退款金额（元）                               退款商品   商家服务问题
# 0       昆明\t     399.0      0.0                                NaN  拣货超时；\t
# 1       北京\t     399.0      0.0                                NaN  拣货超时；\t
# 2       绍兴\t     409.0      0.0                                NaN  拣货超时；\t
# 3       北京\t     319.0      0.0                                NaN  拣货超时；\t
# 4       昆明\t     249.0      0.0                                NaN  拣货超时；\t
# ...      ...       ...      ...                                ...      ...
# 12655   肇庆\t     388.0    388.0     明天你好【33枝香槟玫瑰七夕情人节表白鲜花礼盒】*数量1\t  商家拒单；\t
# 12656   肇庆\t     388.0    388.0     明天你好【33枝香槟玫瑰七夕情人节表白鲜花礼盒】*数量1\t  商家拒单；\t
# 12657   肇庆\t     188.0    188.0          常相伴【11枝香槟玫瑰搭配尤加利花束】*数量1\t  商家拒单；\t
# 12658   肇庆\t     178.0    178.0   亲密爱人【11枝粉玫瑰搭配满天星七夕情人节鲜花花束】*数量1\t  商家拒单；\t
# 12659   肇庆\t     399.0    399.0  加倍爱你【19枝香槟玫瑰搭配满天星七夕情人节鲜花礼盒】*数量1\t  商家拒单；\t
#
# [12660 rows x 9 columns]

# %%
data['下单时间'] = pd.to_datetime(data['下单时间'],format='%Y-%m-%d %H:%M:%S')
wrong['下单时间'] = pd.to_datetime(wrong['下单时间'],format='%Y-%m-%d %H:%M:%S')

# %%
wrong['下单时间_day'] = wrong['下单时间'].dt.day
wrong['下单时间_hour'] = wrong['下单时间'].dt.hour

# %%
wrong_judan = wrong[wrong['商家服务问题'] == '商家拒单；\t']

# %%
wrong_judan
# Out:
#                     订单编号                下单时间              店铺名称     店铺ID  \
# 39      4037213597207722 2020-08-25 18:14:19  邂逅花坊鲜花（创懿花艺婚庆）\t   403721
# 61     35346730408368023 2020-08-25 08:27:05    邂逅花坊鲜花（花海之家）\t  3534673
# 187    10259323213192828 2020-08-25 18:29:51  邂逅花坊鲜花（景都鲜花婚庆）\t  1025932
# 294    38789862631357360 2020-08-25 16:34:01    邂逅花坊鲜花（娜时花开）\t  3878986
# 298    38789862028886957 2020-08-25 17:38:39    邂逅花坊鲜花（娜时花开）\t  3878986
# ...                  ...                 ...               ...      ...
# 12655  97688012342655417 2020-08-25 13:51:39          花好月缘花店\t  9768801
# 12656  97688010372010069 2020-08-25 13:51:45          花好月缘花店\t  9768801
# 12657  97688010890902196 2020-08-25 14:00:51          花好月缘花店\t  9768801
# 12658  97688013774986605 2020-08-25 14:08:36          花好月缘花店\t  9768801
# 12659  97688012454686031 2020-08-25 14:12:39          花好月缘花店\t  9768801
#
#       店铺所在城市  订单总金额（元）  退款金额（元）                                退款商品   商家服务问题  \
# 39      杭州\t     399.0    399.0  甜蜜陪伴【19枝红玫瑰搭配乒乓菊七夕情人节告白鲜花花篮】*数量1\t  商家拒单；\t
# 61      六安\t     399.0    399.0    仪态万千【19枝红玫瑰搭配尤加利七夕情人节鲜花礼盒】*数量1\t  商家拒单；\t
# 187     滁州\t     298.0    298.0            享受时光【粉色满天星七夕情人节花束】*数量1\t  商家拒单；\t
# 294     中山\t     319.0    319.0   友谊的歌【11枝红玫瑰+8枝粉玫瑰搭配尤加利韩式花束】*数量1\t  商家拒单；\t
# 298     中山\t     324.0    324.0         细碎的小花【紫色满天星七夕情人节表白鲜花】*数量1\t  商家拒单；\t
# ...      ...       ...      ...                                 ...      ...
# 12655   肇庆\t     388.0    388.0      明天你好【33枝香槟玫瑰七夕情人节表白鲜花礼盒】*数量1\t  商家拒单；\t
# 12656   肇庆\t     388.0    388.0      明天你好【33枝香槟玫瑰七夕情人节表白鲜花礼盒】*数量1\t  商家拒单；\t
# 12657   肇庆\t     188.0    188.0           常相伴【11枝香槟玫瑰搭配尤加利花束】*数量1\t  商家拒单；\t
# 12658   肇庆\t     178.0    178.0    亲密爱人【11枝粉玫瑰搭配满天星七夕情人节鲜花花束】*数量1\t  商家拒单；\t
# 12659   肇庆\t     399.0    399.0   加倍爱你【19枝香槟玫瑰搭配满天星七夕情人节鲜花礼盒】*数量1\t  商家拒单；\t
#
#        下单时间_day  下单时间_hour
# 39           25         18
# 61           25          8
# 187          25         18
# 294          25         16
# 298          25         17
# ...         ...        ...
# 12655        25         13
# 12656        25         13
# 12657        25         14
# 12658        25         14
# 12659        25         14
#
# [795 rows x 11 columns]

# %%
drop_du(wrong,'下单时间_day')
# Out:
# [[26, 24, 25], {26: 66, 24: 496, 25: 12098}, []]

# %%
df24 = wrong_judan[wrong_judan['下单时间_day'] == 24]
df25 = wrong_judan[wrong_judan['下单时间_day'] == 25]

# %%
a = drop_du(df24,'下单时间_hour')
collection_d = Counter(a[1])
print(collection_d)
# Out:
# Counter({22: 11, 21: 9, 17: 6, 20: 6, 15: 5, 23: 4, 16: 3, 13: 3, 18: 3, 14: 3, 8: 2, 12: 2})

# %%
b = drop_du(df25,'下单时间_hour')
collection_e = Counter(b[1])
print(collection_e)
# Out:
# Counter({15: 72, 13: 72, 14: 70, 12: 60, 11: 59, 16: 51, 10: 49, 17: 45, 19: 42, 18: 40, 9: 28, 20: 27, 21: 26, 8: 25, 22: 18, 7: 15, 0: 14, 1: 6, 6: 3, 3: 2, 2: 2, 5: 2})

# %%
df24 = pd.DataFrame(pd.Series(a[1]), columns=['count'])
df24 = df24.reset_index().rename(columns={'index':'time'})
df24.sort_values(by = 'time',inplace=True)
df24['time'] = df24['time'].apply(str)

# %%
df24
# Out:
#    time  count
# 3     8      2
# 9    12      2
# 4    13      3
# 10   14      3
# 0    15      5
# 1    16      3
# 2    17      6
# 8    18      3
# 5    20      6
# 6    21      9
# 11   22     11
# 7    23      4

# %%
df25 = pd.DataFrame(pd.Series(b[1]), columns=['count'])
df25 = df25.reset_index().rename(columns={'index':'time'})
df25.sort_values(by = 'time',inplace=True)
df25['time'] = df25['time'].apply(str)

# %%
df25
# Out:
#    time  count
# 10    0     14
# 1     1      6
# 4     2      2
# 0     3      2
# 5     5      2
# 2     6      3
# 8     7     15
# 7     8     25
# 15    9     28
# 18   10     49
# 6    11     59
# 19   12     60
# 20   13     72
# 21   14     70
# 17   15     72
# 13   16     51
# 16   17     45
# 11   18     40
# 9    19     42
# 12   20     27
# 3    21     26
# 14   22     18

# %%
import matplotlib.pyplot as plt
plt.plot(df24['time'],df24['count'])

# %%
import matplotlib.pyplot as plt
plt.plot(df25['time'],df25['count'])
