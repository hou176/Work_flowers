# %%
import  pandas  as pd 
import  numpy  as np 
from defname import *

# %%
data = pd.read_csv('data/九月门店日.csv',encoding='gbk')

# %%
df = data[(data['结束日期'] <20200909) | (data['结束日期']  > 20200910)]

# %%
add = ['曝光人数', '入店人数', '下单人数', '下单新客人数', '推单数', '有效订单数', '原价交易额', '实付交易额', '商家补贴金额','商家原因取消订单数', 'IM1分钟回复数', '差评订单数', '投诉订单数', 'IM会话数', 'IM回复数','商家拒单数', '商家超时未接单数', '商家取消不告知用户订单数', '缺货导致退款订单数', '商家少送错送导致用户退款订单数', '商家质量问题导致用户退款订单数', '配送原因取消订单数', '拣货超时订单数', '使用间或完成按钮订单数']           
mean = ['（日均）预设营业时长（h）','（日均）在线营业时长（h）', '平均商家评分', '平均商品评分', '平均配送评分','平均配送时长（min）']
count = ['开始日期', '结束日期', '商家ID', '商家名称', '运营组', '省份', '城市', '是否新增商家', '首次上线日期', '门店在线状态']

# %%
colmuns = [count,add,mean]

# %%
df_M=groupdata(df,colmuns,'商家ID')

# %%
# df_M.to_csv('九月份门店.csv')

# %%
df_M = pd.read_csv('门店月数据.csv')

# %%
df_M
# Out:
#       Unnamed: 0     商家ID      蜂窝      开始日期      结束日期              商家名称  运营组  \
# 0              0  5531687     NaN  20200901  20200901     邂逅花坊鲜花(雅韵鲜花店）  鲜花组
# 1              1  4568666   植物园蜂窝  20200901  20200901     邂逅花坊鲜花（柠檬草花语）  鲜花组
# 2              2  5411231    石化百货  20200901  20200901      邂逅花坊鲜花（豆豆花卉）  鲜花组
# 3              3  6023935     NaN  20200901  20200901      邂逅花坊鲜花（缤纷花艺）  鲜花组
# 4              4  5417954     NaN  20200901  20200901      邂逅花坊鲜花（倾心花艺）  鲜花组
# ...          ...      ...     ...       ...       ...               ...  ...
# 2062        2062  8980725     NaN  20200901  20200901  初见花艺(七夕预定，表白，鲜花）  鲜花组
# 2063        2063  8980726     NaN  20200901  20200901  心缘花店(七夕预定，表白，鲜花)  鲜花组
# 2064        2064  8980728  东城领秀社区  20200901  20200901  简爱花舍(七夕预定，表白，鲜花)  鲜花组
# 2065        2065  5531959     NaN  20200901  20200901       邂逅花坊鲜花(爱花居）  鲜花组
# 2066        2066  8981642     NaN  20200901  20200901       七色鲜花·七夕表白鲜花  鲜花组
#
#             省份    城市 是否新增商家    首次上线日期 门店在线状态   曝光人数  入店人数  下单人数  下单新客人数  推单数  \
# 0          山西省   长治市      否  20180727     在线  28039  3025   211     190  249
# 1     新疆维吾尔自治区  乌鲁木齐      否  20180506     在线  28696  1223   176     116  177
# 2          上海市    上海      否  20180710     在线  18566  1467   143     117  154
# 3          广东省    阳江      否  20181105     在线  17321  1610   135     115  133
# 4          安徽省    合肥      否  20180710     在线  24717  1108   129      99  126
# ...        ...   ...    ...       ...    ...    ...   ...   ...     ...  ...
# 2062       安徽省    亳州      否  20200427     在线   1981    78     0       0    0
# 2063       河南省    新乡      否  20200427     在线   3389    53     0       0    0
# 2064      黑龙江省    大庆      否  20200427     在线   2543    14     0       0    0
# 2065       山西省    晋中      否  20180730     在线   5483   124     3       0    2
# 2066       辽宁省    大连      否  20200428     在线   1708    49     0       0    0
#
#       有效订单数    原价交易额     实付交易额    商家补贴金额  商家原因取消订单数  IM1分钟回复数  差评订单数  投诉订单数  \
# 0       240  66009.0  26790.00  39156.20          1       115      0      0
# 1       169  33037.0  15544.64  17473.76          1        40      0      0
# 2       151  41715.0  18276.77  23472.63          0        51      0      0
# 3       130  35406.0  13466.62  21856.38          1        69      0      0
# 4       123  36071.0  14947.10  21115.40          1        49      0      0
# ...     ...      ...       ...       ...        ...       ...    ...    ...
# 2062      0      0.0      0.00      0.00          0         0      0      0
# 2063      0      0.0      0.00      0.00          0         0      0      0
# 2064      0      0.0      0.00      0.00          0         0      0      0
# 2065      0      0.0      0.00      0.00          0         0      0      0
# 2066      0      0.0      0.00      0.00          0         0      0      0
#
#       IM会话数  IM回复数  商家拒单数  商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  \
# 0       129    128      0         0             0          1                0
# 1        48     48      1         0             0          0                0
# 2        55     55      0         0             0          0                0
# 3        75     75      1         0             0          0                0
# 4        81     75      0         1             0          0                0
# ...     ...    ...    ...       ...           ...        ...              ...
# 2062      1      1      0         0             0          0                0
# 2063      0      0      0         0             0          0                0
# 2064      0      0      0         0             0          0                0
# 2065      1      1      0         0             0          0                0
# 2066      0      0      0         0             0          0                0
#
#       商家质量问题导致用户退款订单数  配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  （日均）预设营业时长（h）  \
# 0                   0          0        0          249      21.500000
# 1                   0          0        0          178      11.714286
# 2                   0          0        3          154      23.714286
# 3                   0          0        0          132      16.250000
# 4                   0          0        0          126      23.821429
# ...               ...        ...      ...          ...            ...
# 2062                0          0        0            0      14.285714
# 2063                0          0        0            0      14.000000
# 2064                0          0        0            0      15.071429
# 2065                0          0        0            2      15.642857
# 2066                0          0        0            0      14.857143
#
#       （日均）在线营业时长（h）    平均商家评分    平均商品评分    平均配送评分  平均配送时长（min） 城市等级
# 0         21.382143  4.825000  4.825000  4.928571     0.000000    0
# 1         11.628571  3.571429  3.571429  3.571429     0.000000   C1
# 2         23.692857  4.675000  4.675000  4.807143    13.035714    S
# 3         15.125000  4.842857  4.842857  4.857143     0.000000    0
# 4         23.792857  4.857143  4.857143  5.000000     0.000000   B1
# ...             ...       ...       ...       ...          ...  ...
# 2062      13.928571  1.428571  1.428571  1.428571     0.000000    0
# 2063      13.885714  0.000000  0.000000  0.000000     0.000000   C2
# 2064      15.053571  0.000000  0.000000  0.000000     0.000000   C2
# 2065      15.632143  1.721429  1.721429  1.785714     0.000000    0
# 2066      14.796429  0.000000  0.000000  0.000000     0.000000   B1
#
# [2067 rows x 43 columns]

# %%
df_M = df_M.sort_values(by='有效订单数',ascending = False)

# %%
df_city = pd.read_csv('城市与等级.csv')
df_city = df_city[['城市','城市等级']]
# df_city.to_csv('城市与等级.csv')

# %%
df_M_city = pd.merge(df_M,df_city,on='城市')

# %%
df_M_city = df_M

# %%
city_level_list = ['S', 'A', 'B1', 'B2', 'C1', 'C2', 'D1', 'D2', 'D3','0']

# %%
city_level_list_two = [['有效订单数','实付交易额','曝光人数','入店人数','下单人数'],['商家ID']]

# %%
k = pd.DataFrame(city_level_list,columns=['城市等级'])
for j in city_level_list_two[0]:
    list_ = []
    for i in city_level_list:
        city_level_dict = []
        a = df_M_city[df_M_city['城市等级'] == i]
        b = a[j].sum()
        list_.append(b)
    city_level_dataframe = pd.DataFrame(list_,columns=[j])
    k = pd.concat([k,city_level_dataframe],axis=1)

# %%
for j in city_level_list_two[1]:
    list_ = []
    for i in city_level_list:
        city_level_dict = []
        a = df_M_city[df_M_city['城市等级'] == i]
        b = a[j].count()
        list_.append(b)
    city_level_dataframe = pd.DataFrame(list_,columns=['门店数量'])
    k = pd.concat([k,city_level_dataframe],axis=1)

# %%
k['入店转化率'] = k['入店人数'] / k['曝光人数'] * 100
k['下单转化率'] = k['下单人数'] / k['入店人数'] * 100
# k.to_csv('城市等级门店.csv')

# %%
# city_level_sotre = pd.read_csv('城市等级门店.csv')

# %%
city_level_sotre['均订单'] = city_level_sotre['有效订单数'] / city_level_sotre['门店数量']

# %%
city_level_sotre['订单占比'] = city_level_sotre['有效订单数'] / city_level_sotre['有效订单数'].sum()

# %%
city_level_sotre.sort_values(by='均订单',ascending=False)
# Out:
#    Unnamed: 0 城市等级  有效订单数      实付交易额     曝光人数   入店人数  下单人数  门店数量     入店转化率  \
# 0           0    S   1823  251852.24   646553  27149  2118   132  4.199037
# 9           9    0   5002  635064.68  2557563  99613  5326   479  3.894841
# 4           4   C1   1925  243820.42  1070543  37037  2047   205  3.459646
# 7           7   D2   1573  185136.38   778157  30950  1687   191  3.977346
# 2           2   B1   1881  235566.83   940430  35288  1989   241  3.752326
# 1           1    A   1638  206052.74   813774  32071  1744   223  3.941020
# 3           3   B2   1157  147363.71   711189  25079  1230   159  3.526348
# 5           5   C2   1337  161971.96   931492  29528  1446   206  3.169968
# 8           8   D3    766   87634.94   449059  16094   825   124  3.583939
# 6           6   D1   1095  125031.40   801321  25395  1186   199  3.169142
#
#       下单转化率         均单价        均订单      门店占比      订单占比
# 0  7.801392  138.152628  13.810606  0.061139  0.100181
# 9  5.346692  126.962151  10.442589  0.221862  0.274880
# 4  5.526906  126.659958   9.390244  0.094951  0.105787
# 7  5.450727  117.696364   8.235602  0.088467  0.086443
# 2  5.636477  125.234891   7.804979  0.111626  0.103369
# 1  5.437935  125.795324   7.345291  0.103289  0.090015
# 3  4.904502  127.367079   7.276730  0.073645  0.063582
# 5  4.897047  121.145819   6.490291  0.095415  0.073474
# 8  5.126134  114.405927   6.177419  0.057434  0.042095
# 6  4.670211  114.183927   5.502513  0.092172  0.060175

# %%
# countey_sotre = pd.read_csv('0831.csv')

# %%
# countey_sotre = countey_sotre[['门店ID','蜂窝']]
# countey_sotre['商家ID'] = countey_sotre['门店ID']

# %%
# df_M = pd.merge(df_M,countey_sotre,on='商家ID')

# %%
# df_M = df_M.drop('门店ID',axis = 1)

# %%
# df_M['蜂窝'].count()

# %%
df_M = pd.read_csv('门店月数据.csv')

# %%
df_M = df_M[['商家ID','蜂窝']]

# %%
data = pd.merge(df_M,df_M_city,on='商家ID')

# %%
data = data.drop('Unnamed: 0',axis=1)

# %%
# data.to_csv('门店月数据.csv')

# %%
data = pd.read_csv('门店月数据.csv',encoding='utf8')
data_city = pd.read_csv('城市等级门店.csv',encoding='utf8')

# %%
data.head()
# Out:
#    Unnamed: 0     商家ID     蜂窝      开始日期      结束日期           商家名称  运营组  \
# 0           0  5531687    NaN  20200901  20200901  邂逅花坊鲜花(雅韵鲜花店）  鲜花组
# 1           1  4568666  植物园蜂窝  20200901  20200901  邂逅花坊鲜花（柠檬草花语）  鲜花组
# 2           2  5411231   石化百货  20200901  20200901   邂逅花坊鲜花（豆豆花卉）  鲜花组
# 3           3  6023935    NaN  20200901  20200901   邂逅花坊鲜花（缤纷花艺）  鲜花组
# 4           4  5417954    NaN  20200901  20200901   邂逅花坊鲜花（倾心花艺）  鲜花组
#
#          省份    城市 是否新增商家    首次上线日期 门店在线状态   曝光人数  入店人数  下单人数  下单新客人数  推单数  \
# 0       山西省   长治市      否  20180727     在线  28039  3025   211     190  249
# 1  新疆维吾尔自治区  乌鲁木齐      否  20180506     在线  28696  1223   176     116  177
# 2       上海市    上海      否  20180710     在线  18566  1467   143     117  154
# 3       广东省    阳江      否  20181105     在线  17321  1610   135     115  133
# 4       安徽省    合肥      否  20180710     在线  24717  1108   129      99  126
#
#    有效订单数    原价交易额     实付交易额    商家补贴金额  商家原因取消订单数  IM1分钟回复数  差评订单数  投诉订单数  \
# 0    240  66009.0  26790.00  39156.20          1       115      0      0
# 1    169  33037.0  15544.64  17473.76          1        40      0      0
# 2    151  41715.0  18276.77  23472.63          0        51      0      0
# 3    130  35406.0  13466.62  21856.38          1        69      0      0
# 4    123  36071.0  14947.10  21115.40          1        49      0      0
#
#    IM会话数  IM回复数  商家拒单数  商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  \
# 0    129    128      0         0             0          1                0
# 1     48     48      1         0             0          0                0
# 2     55     55      0         0             0          0                0
# 3     75     75      1         0             0          0                0
# 4     81     75      0         1             0          0                0
#
#    商家质量问题导致用户退款订单数  配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  （日均）预设营业时长（h）  \
# 0                0          0        0          249      21.500000
# 1                0          0        0          178      11.714286
# 2                0          0        3          154      23.714286
# 3                0          0        0          132      16.250000
# 4                0          0        0          126      23.821429
#
#    （日均）在线营业时长（h）    平均商家评分    平均商品评分    平均配送评分  平均配送时长（min） 城市等级
# 0      21.382143  4.825000  4.825000  4.928571     0.000000    0
# 1      11.628571  3.571429  3.571429  3.571429     0.000000   C1
# 2      23.692857  4.675000  4.675000  4.807143    13.035714    S
# 3      15.125000  4.842857  4.842857  4.857143     0.000000    0
# 4      23.792857  4.857143  4.857143  5.000000     0.000000   B1

# %% [markdown]
# #### 线性回归预测曝光入店  入店下单人数关系

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor

# %%
data_linear = data[['曝光人数','入店人数','下单人数']]
data_linear = data_linear[data_linear['曝光人数'] < 17348]

# %%
# q3 = data_linear['曝光人数'].quantile(0.75)
# q4 = data_linear['曝光人数'].quantile(0.25)
# iq = 1.5*(q3 + q4)
# print(q3+iq)

# %%
plt.figure(figsize=(16,8))
plt.scatter(data_linear['曝光人数'],data_linear['入店人数'],c = '#000000')
# plt.scatter(data_linear['入店人数'],data_linear['下单人数'],c = 'blue')
x = np.linspace(0,20000, 10000)
y = 0.036168* x + 3.6546 
plt.plot(x,y,c = 'red')
plt.xlabel('bg')
plt.xlabel('rd')
plt.show()

# %%
X = data_linear_bg['曝光人数'].values.reshape(-1,1)
y = data_linear_bg['入店人数'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-b368f009f188> in <module>
# ----> 1 X = data_linear_bg['曝光人数'].values.reshape(-1,1)
#       2 y = data_linear_bg['入店人数'].values.reshape(-1,1)
#       3 reg = LinearRegression()
#       4 reg.fit(X,y)
#
# NameError: name 'data_linear_bg' is not defined

# %%
LinearRegression(copy_X=True,fit_intercept=True,n_jobs=1,normalize=False)
# Out:
# LinearRegression(n_jobs=1)

# %%
print('a = {:.5}'.format(reg.coef_[0][0]))
print('b = {:.5}'.format(reg.intercept_[0]))
print("线性模型为: Y = {:.5}X + {:.5} ".format(reg.coef_[0][0], reg.intercept_[0]))
# Out:
# a = 0.036168
# b = 3.6546
# 线性模型为: Y = 0.036168X + 3.6546

# %% [markdown]
# #### 城市等级详情

# %%
data_city = data_city.drop('Unnamed: 0',axis=1)

# %%
data_city['门店均曝光人数'] = data_city['曝光人数'] / data_city['门店数量']

# %%
data_city
# Out:
#   城市等级  有效订单数      实付交易额     曝光人数   入店人数  下单人数  门店数量     入店转化率     下单转化率  \
# 0    S   1823  251852.24   646553  27149  2118   132  4.199037  7.801392
# 1    A   1638  206052.74   813774  32071  1744   223  3.941020  5.437935
# 2   B1   1881  235566.83   940430  35288  1989   241  3.752326  5.636477
# 3   B2   1157  147363.71   711189  25079  1230   159  3.526348  4.904502
# 4   C1   1925  243820.42  1070543  37037  2047   205  3.459646  5.526906
# 5   C2   1337  161971.96   931492  29528  1446   206  3.169968  4.897047
# 6   D1   1095  125031.40   801321  25395  1186   199  3.169142  4.670211
# 7   D2   1573  185136.38   778157  30950  1687   191  3.977346  5.450727
# 8   D3    766   87634.94   449059  16094   825   124  3.583939  5.126134
# 9    0   5002  635064.68  2557563  99613  5326   479  3.894841  5.346692
#
#        门店均曝光人数
# 0  4898.128788
# 1  3649.210762
# 2  3902.199170
# 3  4472.886792
# 4  5222.160976
# 5  4521.805825
# 6  4026.738693
# 7  4074.120419
# 8  3621.443548
# 9  5339.379958

# %%
data['蜂窝'] = data['蜂窝'].fillna('无')

# %%
data
# Out:
#       Unnamed: 0     商家ID      蜂窝      开始日期      结束日期              商家名称  运营组  \
# 0              0  5531687       无  20200901  20200901     邂逅花坊鲜花(雅韵鲜花店）  鲜花组
# 1              1  4568666   植物园蜂窝  20200901  20200901     邂逅花坊鲜花（柠檬草花语）  鲜花组
# 2              2  5411231    石化百货  20200901  20200901      邂逅花坊鲜花（豆豆花卉）  鲜花组
# 3              3  6023935       无  20200901  20200901      邂逅花坊鲜花（缤纷花艺）  鲜花组
# 4              4  5417954       无  20200901  20200901      邂逅花坊鲜花（倾心花艺）  鲜花组
# ...          ...      ...     ...       ...       ...               ...  ...
# 2062        2062  8980725       无  20200901  20200901  初见花艺(七夕预定，表白，鲜花）  鲜花组
# 2063        2063  8980726       无  20200901  20200901  心缘花店(七夕预定，表白，鲜花)  鲜花组
# 2064        2064  8980728  东城领秀社区  20200901  20200901  简爱花舍(七夕预定，表白，鲜花)  鲜花组
# 2065        2065  5531959       无  20200901  20200901       邂逅花坊鲜花(爱花居）  鲜花组
# 2066        2066  8981642       无  20200901  20200901       七色鲜花·七夕表白鲜花  鲜花组
#
#             省份    城市 是否新增商家    首次上线日期 门店在线状态   曝光人数  入店人数  下单人数  下单新客人数  推单数  \
# 0          山西省   长治市      否  20180727     在线  28039  3025   211     190  249
# 1     新疆维吾尔自治区  乌鲁木齐      否  20180506     在线  28696  1223   176     116  177
# 2          上海市    上海      否  20180710     在线  18566  1467   143     117  154
# 3          广东省    阳江      否  20181105     在线  17321  1610   135     115  133
# 4          安徽省    合肥      否  20180710     在线  24717  1108   129      99  126
# ...        ...   ...    ...       ...    ...    ...   ...   ...     ...  ...
# 2062       安徽省    亳州      否  20200427     在线   1981    78     0       0    0
# 2063       河南省    新乡      否  20200427     在线   3389    53     0       0    0
# 2064      黑龙江省    大庆      否  20200427     在线   2543    14     0       0    0
# 2065       山西省    晋中      否  20180730     在线   5483   124     3       0    2
# 2066       辽宁省    大连      否  20200428     在线   1708    49     0       0    0
#
#       有效订单数    原价交易额     实付交易额    商家补贴金额  商家原因取消订单数  IM1分钟回复数  差评订单数  投诉订单数  \
# 0       240  66009.0  26790.00  39156.20          1       115      0      0
# 1       169  33037.0  15544.64  17473.76          1        40      0      0
# 2       151  41715.0  18276.77  23472.63          0        51      0      0
# 3       130  35406.0  13466.62  21856.38          1        69      0      0
# 4       123  36071.0  14947.10  21115.40          1        49      0      0
# ...     ...      ...       ...       ...        ...       ...    ...    ...
# 2062      0      0.0      0.00      0.00          0         0      0      0
# 2063      0      0.0      0.00      0.00          0         0      0      0
# 2064      0      0.0      0.00      0.00          0         0      0      0
# 2065      0      0.0      0.00      0.00          0         0      0      0
# 2066      0      0.0      0.00      0.00          0         0      0      0
#
#       IM会话数  IM回复数  商家拒单数  商家超时未接单数  商家取消不告知用户订单数  缺货导致退款订单数  商家少送错送导致用户退款订单数  \
# 0       129    128      0         0             0          1                0
# 1        48     48      1         0             0          0                0
# 2        55     55      0         0             0          0                0
# 3        75     75      1         0             0          0                0
# 4        81     75      0         1             0          0                0
# ...     ...    ...    ...       ...           ...        ...              ...
# 2062      1      1      0         0             0          0                0
# 2063      0      0      0         0             0          0                0
# 2064      0      0      0         0             0          0                0
# 2065      1      1      0         0             0          0                0
# 2066      0      0      0         0             0          0                0
#
#       商家质量问题导致用户退款订单数  配送原因取消订单数  拣货超时订单数  使用间或完成按钮订单数  （日均）预设营业时长（h）  \
# 0                   0          0        0          249      21.500000
# 1                   0          0        0          178      11.714286
# 2                   0          0        3          154      23.714286
# 3                   0          0        0          132      16.250000
# 4                   0          0        0          126      23.821429
# ...               ...        ...      ...          ...            ...
# 2062                0          0        0            0      14.285714
# 2063                0          0        0            0      14.000000
# 2064                0          0        0            0      15.071429
# 2065                0          0        0            2      15.642857
# 2066                0          0        0            0      14.857143
#
#       （日均）在线营业时长（h）    平均商家评分    平均商品评分    平均配送评分  平均配送时长（min） 城市等级
# 0         21.382143  4.825000  4.825000  4.928571     0.000000    0
# 1         11.628571  3.571429  3.571429  3.571429     0.000000   C1
# 2         23.692857  4.675000  4.675000  4.807143    13.035714    S
# 3         15.125000  4.842857  4.842857  4.857143     0.000000    0
# 4         23.792857  4.857143  4.857143  5.000000     0.000000   B1
# ...             ...       ...       ...       ...          ...  ...
# 2062      13.928571  1.428571  1.428571  1.428571     0.000000    0
# 2063      13.885714  0.000000  0.000000  0.000000     0.000000   C2
# 2064      15.053571  0.000000  0.000000  0.000000     0.000000   C2
# 2065      15.632143  1.721429  1.721429  1.785714     0.000000    0
# 2066      14.796429  0.000000  0.000000  0.000000     0.000000   B1
#
# [2067 rows x 43 columns]
