# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
data = pd.read_csv(r'C:/Users/Administrator/Datas/训练数据/商品订单/商品订单数据合并/result.csv',encoding='gbk')

# %%
data
# Out:
#                         日期               订单编号                   下单时间  接单时长  \
# 0                        1   2956803154075995  2020-01-18 21:02:24\t  142秒
# 1                        1   2956801656539530  2020-01-19 18:15:14\t   13秒
# 2                        1   2956803231530438  2020-01-21 17:30:45\t   23秒
# 3                        1   6536431702303577  2020-01-10 11:28:22\t  156秒
# 4                        1   6536430042747760  2020-01-13 21:58:33\t  198秒
# ...                    ...                ...                    ...   ...
# 40451  \t20200501-20200601  91398090097466925  2020-05-20 09:54:40\t  174秒
# 40452  \t20200501-20200601  91398090884432379  2020-05-20 19:12:49\t    0秒
# 40453  \t20200501-20200601  91398090115046017  2020-05-27 15:35:23\t   19秒
# 40454  \t20200501-20200601  91398092729503591  2020-05-31 14:49:08\t  187秒
# 40455  \t20200501-20200601  91398090331935260  2020-06-01 21:07:18\t  269秒
#
# ...

# %%
data[data['是否预订单'] == '是'].count()
# 5105
# Out:
# 日期               5105
# 订单编号             5105
# 下单时间             5105
# 接单时长             5105
# 店铺名称             5105
# 店铺ID             5105
# 店铺所在城市           5105
# 订单支付类型           5105
# 订单状态             5105
# 订单配送状态           5105
# 是否预订单            5105
# 订单总金额            5105
# 订单折扣后金额          5105
# 平台承担活动金额         5105
# 商家承担活动金额         5105
# 商品分类             5105
# 商品名称             5105
# UPC码                0
# 商品SKU码           3838
# 商品销售数量           5105
# 商品原价销售额          5105
# 商品实付销售额          5105
# 商品总补贴金额          5105
# 商品商家补贴金额         5105
# 商品平台补贴金额         5105
# 是否部分退款商品         5105
# 部分退款商品数量         5105
# 部分退款商品金额         5105
# 订单小额付款           5105
# 配送费              5105
# 是否活动订单           5105
# 优惠活动             5090
# 是否催单             5105
# 回复状态             5105
# 商家回复内容             41
# 配送时长             5105
# 打包袋费             5105
# 订单完成时间           3544
# 订单取消原因（仅取消订单）     578
# dtype: int64

# %%
data[data['是否预订单'] == '否'].count()
# 35351
# Out:
# 日期               35351
# 订单编号             35351
# 下单时间             35351
# 接单时长             35351
# 店铺名称             35351
# 店铺ID             35351
# 店铺所在城市           35351
# 订单支付类型           35351
# 订单状态             35351
# 订单配送状态           35351
# 是否预订单            35351
# 订单总金额            35351
# 订单折扣后金额          35351
# 平台承担活动金额         35351
# 商家承担活动金额         35351
# 商品分类             35351
# 商品名称             35351
# UPC码                 0
# 商品SKU码           24877
# 商品销售数量           35351
# 商品原价销售额          35351
# 商品实付销售额          35351
# 商品总补贴金额          35351
# 商品商家补贴金额         35351
# 商品平台补贴金额         35351
# 是否部分退款商品         35351
# 部分退款商品数量         35351
# 部分退款商品金额         35351
# 订单小额付款           35351
# 配送费              35351
# 是否活动订单           35351
# 优惠活动             35195
# 是否催单             35351
# 回复状态             35351
# 商家回复内容            2436
# 配送时长             35351
# 打包袋费             35351
# 订单完成时间           29981
# 订单取消原因（仅取消订单）     5566
# dtype: int64

# %%
data[data['配送费'] > 0 ].count()   #5617
data[(data['配送费'] > 0 ) & (data['是否预订单'] == '是')].count()   #561
# data[data['配送费'] > 10]
# Out:
# 日期               703
# 订单编号             703
# 下单时间             703
# 接单时长             703
# 店铺名称             703
# 店铺ID             703
# 店铺所在城市           703
# 订单支付类型           703
# 订单状态             703
# 订单配送状态           703
# 是否预订单            703
# 订单总金额            703
# 订单折扣后金额          703
# 平台承担活动金额         703
# 商家承担活动金额         703
# 商品分类             703
# 商品名称             703
# UPC码               0
# 商品SKU码           541
# 商品销售数量           703
# 商品原价销售额          703
# 商品实付销售额          703
# 商品总补贴金额          703
# 商品商家补贴金额         703
# 商品平台补贴金额         703
# 是否部分退款商品         703
# 部分退款商品数量         703
# 部分退款商品金额         703
# 订单小额付款           703
# 配送费              703
# 是否活动订单           703
# 优惠活动             702
# 是否催单             703
# 回复状态             703
# 商家回复内容             3
# 配送时长             703
# 打包袋费             703
# 订单完成时间           486
# 订单取消原因（仅取消订单）     99
# dtype: int64

# %%
data['是否预订单'] = np.where(data['是否预订单'] == '是', 1, 0)

# %%
data
# Out:
#                         日期               订单编号                   下单时间  接单时长  \
# 0                        1   2956803154075995  2020-01-18 21:02:24\t  142秒
# 1                        1   2956801656539530  2020-01-19 18:15:14\t   13秒
# 2                        1   2956803231530438  2020-01-21 17:30:45\t   23秒
# 3                        1   6536431702303577  2020-01-10 11:28:22\t  156秒
# 4                        1   6536430042747760  2020-01-13 21:58:33\t  198秒
# ...                    ...                ...                    ...   ...
# 40451  \t20200501-20200601  91398090097466925  2020-05-20 09:54:40\t  174秒
# 40452  \t20200501-20200601  91398090884432379  2020-05-20 19:12:49\t    0秒
# 40453  \t20200501-20200601  91398090115046017  2020-05-27 15:35:23\t   19秒
# 40454  \t20200501-20200601  91398092729503591  2020-05-31 14:49:08\t  187秒
# 40455  \t20200501-20200601  91398090331935260  2020-06-01 21:07:18\t  269秒
#
# ...

# %%
data.corr()
# Out:
#               订单编号      店铺ID     是否预订单     订单总金额   订单折扣后金额  平台承担活动金额  \
# 订单编号      1.000000  1.000000  0.014473  0.002908  0.003530  0.007270
# 店铺ID      1.000000  1.000000  0.014473  0.002908  0.003530  0.007270
# 是否预订单     0.014473  0.014473  1.000000  0.031156  0.041952  0.023959
# 订单总金额     0.002908  0.002908  0.031156  1.000000  0.450085 -0.019730
# 订单折扣后金额   0.003530  0.003530  0.041952  0.450085  1.000000 -0.056768
# 平台承担活动金额  0.007270  0.007270  0.023959 -0.019730 -0.056768  1.000000
# 商家承担活动金额  0.001532  0.001532  0.019744  0.931963  0.097992 -0.006351
# UPC码           NaN       NaN       NaN       NaN       NaN       NaN
# 商品销售数量    0.007592  0.007592 -0.039888 -0.031766 -0.132811 -0.020405
# 商品原价销售额   0.002301  0.002301  0.048805  0.793179  0.502219 -0.018076
# 商品实付销售额   0.002929  0.002929  0.039427  0.362419  0.929034 -0.063061
# 商品总补贴金额   0.001149  0.001149  0.036154  0.732039  0.100409  0.011762
# 商品商家补贴金额  0.001063  0.001063  0.035873  0.732441  0.101254 -0.001061
# ...

# %%
data['折扣情况'] = data['订单折扣后金额'] / data['订单总金额']

# %%
data
# Out:
#                         日期               订单编号                   下单时间  接单时长  \
# 0                        1   2956803154075995  2020-01-18 21:02:24\t  142秒
# 1                        1   2956801656539530  2020-01-19 18:15:14\t   13秒
# 2                        1   2956803231530438  2020-01-21 17:30:45\t   23秒
# 3                        1   6536431702303577  2020-01-10 11:28:22\t  156秒
# 4                        1   6536430042747760  2020-01-13 21:58:33\t  198秒
# ...                    ...                ...                    ...   ...
# 40451  \t20200501-20200601  91398090097466925  2020-05-20 09:54:40\t  174秒
# 40452  \t20200501-20200601  91398090884432379  2020-05-20 19:12:49\t    0秒
# 40453  \t20200501-20200601  91398090115046017  2020-05-27 15:35:23\t   19秒
# 40454  \t20200501-20200601  91398092729503591  2020-05-31 14:49:08\t  187秒
# 40455  \t20200501-20200601  91398090331935260  2020-06-01 21:07:18\t  269秒
#
# ...

# %%
# data['折扣情况'] = data['折扣情况']* 10
data
# Out:
#                         日期               订单编号                   下单时间  接单时长  \
# 0                        1   2956803154075995  2020-01-18 21:02:24\t  142秒
# 1                        1   2956801656539530  2020-01-19 18:15:14\t   13秒
# 2                        1   2956803231530438  2020-01-21 17:30:45\t   23秒
# 3                        1   6536431702303577  2020-01-10 11:28:22\t  156秒
# 4                        1   6536430042747760  2020-01-13 21:58:33\t  198秒
# ...                    ...                ...                    ...   ...
# 40451  \t20200501-20200601  91398090097466925  2020-05-20 09:54:40\t  174秒
# 40452  \t20200501-20200601  91398090884432379  2020-05-20 19:12:49\t    0秒
# 40453  \t20200501-20200601  91398090115046017  2020-05-27 15:35:23\t   19秒
# 40454  \t20200501-20200601  91398092729503591  2020-05-31 14:49:08\t  187秒
# 40455  \t20200501-20200601  91398090331935260  2020-06-01 21:07:18\t  269秒
#
# ...

# %%
data['折扣情况'] = data['折扣情况'].astype('int64')

# %%
data
# Out:
#                         日期               订单编号                   下单时间  接单时长  \
# 0                        1   2956803154075995  2020-01-18 21:02:24\t  142秒
# 1                        1   2956801656539530  2020-01-19 18:15:14\t   13秒
# 2                        1   2956803231530438  2020-01-21 17:30:45\t   23秒
# 3                        1   6536431702303577  2020-01-10 11:28:22\t  156秒
# 4                        1   6536430042747760  2020-01-13 21:58:33\t  198秒
# ...                    ...                ...                    ...   ...
# 40451  \t20200501-20200601  91398090097466925  2020-05-20 09:54:40\t  174秒
# 40452  \t20200501-20200601  91398090884432379  2020-05-20 19:12:49\t    0秒
# 40453  \t20200501-20200601  91398090115046017  2020-05-27 15:35:23\t   19秒
# 40454  \t20200501-20200601  91398092729503591  2020-05-31 14:49:08\t  187秒
# 40455  \t20200501-20200601  91398090331935260  2020-06-01 21:07:18\t  269秒
#
# ...

# %%
result =pd.DataFrame(columns=('sum','zhekou'))
#将计算结果逐行插入result,注意变量要用[]括起来,同时ignore_index=True，否则会报错，ValueError: If using all scalar values, you must pass an index
for i in range(0,11):
    lei = data[data['折扣情况'] == i]
    j = len(lei)
    time = i 
    sum_ = j
    result=result.append(pd.DataFrame({'sum':[sum_],'zhekou':[time]}),ignore_index=True)
result
# Out:
#       sum zhekou
# 0     259      0
# 1      51      1
# 2     591      2
# 3    9842      3
# 4   14118      4
# 5    6378      5
# 6    3656      6
# 7    1850      7
# 8    2771      8
# 9     719      9
# 10    221     10

# %%
result.plot.bar(x='zhekou',y='sum')
