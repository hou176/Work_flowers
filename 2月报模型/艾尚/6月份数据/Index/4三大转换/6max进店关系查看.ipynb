# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
data = pd.read_excel(r'C:\Users\Administrator\Datas\训练数据\门店数据\4门店获取提高进店(进店)\Q4数据.xlsx')

# %%
data.corr()['入店']
# Out:
# ID       -0.344070
# 上线时间     -0.330757
# 曝光        0.726955
# 入店        1.000000
# 入店率       0.445586
# 评分        0.054732
# 月售        0.785667
# 配送距离     -0.185379
# 免费距离     -0.129213
# 增加距离      0.260045
# 增加钱       0.270696
# 原价交易额     0.910795
# 真实交易额     0.913819
# 比率        0.028924
# 配送时间      0.109214
# 距离时间      0.219127
# 增加距离.1    0.219127
# 增加时间     -0.029333
# Name: 入店, dtype: float64

# %%
data
# Out:
#          ID              name      上线时间         地址城市     曝光    入店    入店率   评分  \
# 0   3128450     花生活鲜花（花之恋鲜花店）  20170821           绍兴   7538   426   5.65  5.0
# 1   3468033       花生活鲜花（家美园艺）  20171016           上海  10559  1249  11.83  5.0
# 2   4363389      花生活鲜花（意达鲜花店）  20180201           唐山   7129   554   7.77  5.0
# 3   5196478             郁涧鲜花坊  20180612           赤峰   5855   409   6.99  0.0
# 4   6774016       花生活鲜花（婷雅花坊）  20190329          马鞍山   4971   440   8.85  4.7
# 5   7022274       花生活鲜花（唯爱花坊）  20190509           合肥   4676   529  11.31  5.0
# 6   7194721   花生活鲜花（四季春花艺美学馆）  20190614           丽江  11071   772   6.97  0.0
# 7   7207846     花生活鲜花（极乐莲华鲜花）  20190604           杭州   7814   513   6.57  5.0
# 8   7207851       花生活鲜花（龙兴花艺）  20190603           龙岩  11157   996   8.93  5.0
# 9   7475298       花生活鲜花（香阁丽娜）  20190723           遵义  11770   662   5.62  5.0
# 10  7743130  花生活鲜花（静静花艺凤凰北街店）  20190905           银川   5649   319   5.65  5.0
# ...
