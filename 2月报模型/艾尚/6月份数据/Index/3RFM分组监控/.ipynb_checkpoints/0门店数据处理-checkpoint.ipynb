# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)

# %%
def improt_data(lujing,code):
    data = pd.read_csv(lujing,encoding =code)
    return data

# %%
lujing = r'C:/Users/Administrator/Datas/爱尚花语/艾尚花语指标模型/test/门店数据（M）/1-1.csv'
code = 'gbk'
data = improt_data(lujing,code)

# %%
def ziduan(data,list_ziduan):
    data = data[list_ziduan]
    return data

# %%
list_ziduan = ['开始日期','结束日期','商家ID','商家名称','运营组','省份','城市','是否新增商家','首次上线日期','门店在线状态','（日均）预设营业时长（h）','（日均）在线营业时长（h）','曝光人数','入店人数','下单人数','有效订单数','下单新客人数','入店转化率','下单转化率','原价交易额','实付交易额','商家补贴金额']

# %%
data = ziduan(data,list_ziduan)

# %%
def zhibiao(a):
    list_ziduan = ['开始日期','结束日期','商家ID','商家名称','运营组','省份','城市','是否新增商家','首次上线日期','门店在线状态','（日均）预设营业时长（h）','（日均）在线营业时长（h）','曝光人数','入店人数','下单人数','有效订单数','下单新客人数','复购人数','入店转化率','下单转化率','新客转化率','复购率','原价交易额','实付交易额','商家补贴金额','原价客单价','实付客单价']
    a = a.reindex(columns=list_ziduan, fill_value=1)
    a['复购人数'] = a['下单人数'] - a['下单新客人数']
    a['新客转化率'] = a['下单新客人数'] / a['下单人数']
    a['复购率'] = a['复购人数'] / a['下单人数']
    a['原价客单价'] = a['原价交易额'] / a['下单人数']
    a['实付客单价'] = a['实付交易额'] / a['下单人数']
    a = a.sort_values(by='曝光人数',ascending=False)
    a = a.fillna(0)
    return a

# %%
def kmeans(data,zhibiao):
    x = data[zhibiao]  
    wcss = []
    for i in range(1,11):
        kmeans = KMeans(n_clusters=i,init='k-means++',random_state = 42)
        kmeans.fit(x)
        wcss.append(kmeans.inertia_)#促内误差平方和
    print('促内误差平方和：',wcss)
    plt.plot(range(1, 11), wcss)
    plt.title('The Elbow Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('WCSS')
    plt.show()
def kmeans_(data,cluster_x):
    x = cluster_x[0]
    del cluster_x[0]
    data_one = data[cluster_x]
    model=cluster.KMeans(n_clusters=x,random_state=10)
    model.fit(data_one)
    data['cluster']=model.labels_
    return data

# %%
data = zhibiao(data)
data
# Out:
#          开始日期      结束日期     商家ID            商家名称  运营组   省份          城市 是否新增商家  \
# 223  20200101  20200131  7514883     花生活鲜花（倾城花屋）  鲜花组  江苏省          徐州      否
# 298  20200101  20200131  8197675            蔚然花坊  鲜花组  江苏省          南通      否
# 281  20200101  20200131  7934077    花生活鲜花（夜来香鲜花）  鲜花组  北京市          北京      否
# 179  20200101  20200131  7310188  花生活鲜花（伊佰莲鲜花婚庆）  鲜花组  浙江省          绍兴      否
# 272  20200101  20200131  7785967      花生活鲜花（芸花坊）  鲜花组  辽宁省          抚顺      否
# ..        ...       ...      ...             ...  ...  ...         ...    ...
# 61   20200101  20200131  5138638            遇见花开  鲜花组  湖南省          长沙      否
# 45   20200101  20200131  4139743            花日国际  鲜花组  北京市          北京      否
# 4    20200101  20200131   720330            浪漫花屋  鲜花组  湖北省          荆州      否
# 93   20200101  20200131  6507601    花生活鲜花（初见花艺馆）  鲜花组  福建省          福州      否
# 70   20200101  20200131  5630285            呆子花艺  鲜花组  贵州省  黔东南苗族侗族自治州      否
#
#        首次上线日期 门店在线状态  （日均）预设营业时长（h）  （日均）在线营业时长（h）   曝光人数  入店人数  下单人数  有效订单数  \
# 223  20190723     在线           24.0           24.0  52616   733     6      3
# 298  20191218     在线           20.0           20.4  43027   515    16      9
# 281  20191123     在线           24.0           24.0  40353   521     0      0
# 179  20190620     在线           19.0           19.3  40087   340     9      9
# 272  20190912     在线           24.0           24.0  37363   447    21     19
# ..        ...    ...            ...            ...    ...   ...   ...    ...
# 61   20180605     下线            0.0            0.0      3     0     0      0
# 45   20171222     下线            0.0            0.0      3     0     0      0
# 4    20160130     下线            0.0            0.0      1     0     0      0
# 93   20190117     下线            0.0            0.0      1     0     0      0
# 70   20180926     下线            0.0            0.0      1     0     0      0
#
#      下单新客人数  复购人数  入店转化率  下单转化率     新客转化率       复购率   原价交易额    实付交易额   商家补贴金额  \
# 223       3     3   1.39   0.82  0.500000  0.500000   955.0   588.00   484.00
# 298       9     7   1.20   3.11  0.562500  0.437500  2966.0  1320.00  1641.00
# 281       0     0   1.29   0.00  0.000000  0.000000     0.0     0.00     0.00
# 179       6     3   0.85   2.65  0.666667  0.333333  9050.0  1046.17  8270.73
# 272      12     9   1.20   4.70  0.571429  0.428571  3563.0  1370.00  2734.00
# ..      ...   ...    ...    ...       ...       ...     ...      ...      ...
# 61        0     0   0.00   0.00  0.000000  0.000000     0.0     0.00     0.00
# 45        0     0   0.00   0.00  0.000000  0.000000     0.0     0.00     0.00
# 4         0     0   0.00   0.00  0.000000  0.000000     0.0     0.00     0.00
# 93        0     0   0.00   0.00  0.000000  0.000000     0.0     0.00     0.00
# 70        0     0   0.00   0.00  0.000000  0.000000     0.0     0.00     0.00
#
#            原价客单价       实付客单价
# 223   159.166667   98.000000
# 298   185.375000   82.500000
# 281     0.000000    0.000000
# 179  1005.555556  116.241111
# 272   169.666667   65.238095
# ..           ...         ...
# 61      0.000000    0.000000
# 45      0.000000    0.000000
# 4       0.000000    0.000000
# 93      0.000000    0.000000
# 70      0.000000    0.000000
#
# [372 rows x 27 columns]

# %%
a = ['曝光人数','入店人数','下单人数']
kmeans(data,a)
# Out:
# 促内误差平方和： [22423533030.59946, 8649072859.245039, 4334051164.746415, 2468797118.919611, 1611481198.2887502, 1178129163.6614933, 904311097.0778854, 710743666.2610518, 554468300.7793293, 432177747.0719409]

# %%
b = [4,'曝光人数','入店人数','下单人数']
c = kmeans_(data,b)

# %%
import seaborn as sns
# %matplotlib inline
sns.lmplot(x="曝光人数", y="入店人数",data=c,fit_reg=False,hue='cluster')
# Out:
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20837 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 24215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20837 missing from current font.
#   font.set_text(s, 0, flags=flags)
# e:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 24215 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data.to_csv('clean_data.csv')
