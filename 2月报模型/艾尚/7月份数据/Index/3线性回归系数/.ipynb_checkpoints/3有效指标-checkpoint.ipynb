# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def improt_data(lujing,code):
    data = pd.read_csv(lujing,encoding =code)
    return data

def mean(data,a):
    print(data[a].mean())
    print(data[a].std())

def box_polt(a):
    zhongwei = a.median()
    mean = a.mean()
    q1 = a.quantile(0.25)
    q2 = a.quantile(0.5)
    q3 = a.quantile(0.75)
    q4 = a.quantile(1)
    iqr = q3-q1
    upper = q3 + 1.5*iqr
    print('--------------')
    print('中位:',zhongwei)
    print('平均:',mean)    
    print('--------------')
    print('50% :',q2)
    print('75% :',q3)
    print('100%:',upper)
    print('max :',q4)
    print('--------------')
    list_ = []
    list_.append(q2)
    list_.append(q3)
    list_.append(upper)
    return list_

def data_order(a,b):
#     lujing = r'C:/Users/Administrator/Datas/爱尚花语/艾尚花语指标模型/data/Ddata.csv'
#     code = 'gbk'
    data = improt_data(lujing,code)
    if b == 0:
        df_hsh_max = data[data['下单人数'] > a]
        k = df_hsh_max
        return k
    elif a == 0:
        df_hsh_min = data[data['下单人数'] < b  ]
        k = df_hsh_min
        return k
    else:
        df_hsh_ = data[(data['下单人数'] >a) & (data['下单人数'] < b) ]
        k = df_hsh_
        return k 


def line_bg_rd(x1,y1):   
    x = x1
    y = y1
    data_min = data_order(x,y)
    baoguang = data_min['下单人数'].values.reshape(-1,1)
    jindian = data_min['有效订单数'].values.reshape(-1, 1)
    linear(baoguang,jindian)

# %%
lujing = r'C:/Users/Administrator/Datas/爱尚花语/艾尚月季度数据/7月份数据/2data/Mdata_kmeans.csv'
code = 'gbk'
data = improt_data(lujing,code)

# %%
data
# Out:
#      Unnamed: 0      开始日期      结束日期     商家ID             商家名称  运营组        省份  \
# 0           130  20200701  20200731  9438920       拾花间鲜花礼品鲜花店  鲜花组       广东省
# 1           156  20200701  20200731  9529764       花之坊鲜花礼品鲜花店  鲜花组  新疆维吾尔自治区
# 2             1  20200701  20200731  9024278    友新意鲜花坊鲜花礼品鲜花店  鲜花组       陕西省
# 3             7  20200701  20200731  9043317        花坞鲜花礼品鲜花店  鲜花组       福建省
# 4            59  20200701  20200731  9323842       花无缺鲜花礼品鲜花店  鲜花组    内蒙古自治区
# ..          ...       ...       ...      ...              ...  ...       ...
# 186          81  20200701  20200731  9370710      戴氏花艺鲜花礼品鲜花店  鲜花组       山东省
# 187         112  20200701  20200731  9415707            鑫福源鲜花  鲜花组       山东省
# 188         132  20200701  20200731  9456415        夏沫鲜花（文峰店）  鲜花组       山东省
# 189         189  20200701  20200731  9641339  MINE FUN鲜花礼品鲜花店  鲜花组       浙江省
# 190         190  20200701  20200731  9641341             伊人鲜花  鲜花组       甘肃省
#
#         城市 是否新增商家    首次上线日期 门店在线状态  （日均）预设营业时长（h）  （日均）在线营业时长（h）   曝光人数  入店人数  \
# 0       佛山      否  20200703     在线             23           22.8  44869   633
# 1     哈密地区      否  20200717     在线             14           13.8  25088   408
# 2       西安      否  20200508     在线             18           18.0  21575   606
# 3       福州      否  20200508     在线             18           18.0  15287   429
# 4    锡林郭勒盟      否  20200617     在线             13           12.0  15265   390
# ..     ...    ...       ...    ...            ...            ...    ...   ...
# 186     临沂      否  20200708     在线              0            0.0    299    15
# 187     青岛      否  20200629     下线             11           11.3    261     2
# 188     青岛      否  20200706     下线             12           12.5    222    18
# 189     杭州      否  20200730     在线              6            5.7     84     3
# 190     白银      否  20200730     在线              0            0.0     30     2
#
#      下单人数  推单数  有效订单数  下单新客人数  入店转化率  下单转化率  原价交易额   实付交易额  商家补贴金额  复购人数  \
# 0      34   31     25      26   1.41   0.05   6225  2701.0  3780.0     8
# 1      10    9      7       7   1.63   0.02   1362   821.0   566.0     3
# 2      53   50     48      43   2.81   0.09  10547  5459.4  5218.6    10
# 3      20   21     19      19   2.81   0.05   4831  2043.0  2878.0     1
# 4      26   23     23      23   2.55   0.07   5386  2382.0  3099.0     3
# ..    ...  ...    ...     ...    ...    ...    ...     ...     ...   ...
# 186     0    0      0       0   5.02   0.00      0     0.0     0.0     0
# 187     0    0      0       0   0.77   0.00      0     0.0     0.0     0
# 188     4    4      4       4   8.11   0.22    816   256.0   580.0     0
# 189     0    0      0       0   3.57   0.00      0     0.0     0.0     0
# 190     0    0      0       0   6.67   0.00      0     0.0     0.0     0
#
#         新客转化率       复购率       原价客单价       实付客单价       有效率  cluster
# 0    0.764706  0.235294  183.088235   79.441176  0.806452        2
# 1    0.700000  0.300000  136.200000   82.100000  0.777778        1
# 2    0.811321  0.188679  199.000000  103.007547  0.960000        1
# 3    0.950000  0.050000  241.550000  102.150000  0.904762        1
# 4    0.884615  0.115385  207.153846   91.615385  1.000000        1
# ..        ...       ...         ...         ...       ...      ...
# 186  0.000000  0.000000    0.000000    0.000000  0.000000        0
# 187  0.000000  0.000000    0.000000    0.000000  0.000000        0
# 188  1.000000  0.000000  204.000000   64.000000  1.000000        0
# 189  0.000000  0.000000    0.000000    0.000000  0.000000        0
# 190  0.000000  0.000000    0.000000    0.000000  0.000000        0
#
# [191 rows x 31 columns]

# %%
a = data['下单人数']
list_ = box_polt(a)
q1 = list_[0]
q2 = list_[1]
q3 = list_[2]
q04 =  0
print(q1)
print(q2)
print(q3)
# Out:
# --------------
# 中位: 5.0
# 平均: 7.890052356020942
# --------------
# 50% : 5.0
# 75% : 10.5
# 100%: 24.75
# max : 63.0
# --------------
# 5.0
# 10.5
# 24.75

# %%
data_max = data_order(q3,q04)
data_one = data_order(q2,q3)
data_two = data_order(q1,q2)
data_min = data_order(q04,q1)

# %%
data_max
# Out:
#      Unnamed: 0      开始日期      结束日期     商家ID           商家名称  运营组      省份  \
# 0           130  20200701  20200731  9438920     拾花间鲜花礼品鲜花店  鲜花组     广东省
# 2             1  20200701  20200731  9024278  友新意鲜花坊鲜花礼品鲜花店  鲜花组     陕西省
# 4            59  20200701  20200731  9323842     花无缺鲜花礼品鲜花店  鲜花组  内蒙古自治区
# 5           110  20200701  20200731  9415615      一花一木花艺生活馆  鲜花组     海南省
# 10           35  20200701  20200731  9288258    花开相爱鲜花礼品鲜花店  鲜花组     山西省
# 12           43  20200701  20200731  9295286    婉苑鲜花婚庆礼品鲜花店  鲜花组    黑龙江省
# 15           58  20200701  20200731  9322697    锦上添花鲜花礼品鲜花店  鲜花组     吉林省
# 20          106  20200701  20200731  9415611    圣格花艺鲜花礼品鲜花店  鲜花组    黑龙江省
# 5    0.933333  0.066667  249.700000  161.233333  0.966667        1
# 10   0.944444  0.055556  258.888889  104.277778  0.928571        3
# 12   0.894737  0.105263  252.421053   90.789474  1.000000        3
# 15   0.925926  0.074074  214.888889   96.688889  0.964286        3
# 20   0.896552  0.103448  213.413793  105.965517  0.939394        3
# 22   0.888889  0.111111  242.301587   95.812698  0.878788        3
# 38   0.962963  0.037037  272.740741  102.985185  0.965517        3
# 47   0.932203  0.067797  271.593220  117.406780  0.967742        3
# 76   1.000000  0.000000  307.400000  103.440000  0.888889        0
# 95   0.793103  0.206897  205.103448   88.724138  0.896552        0
# 111  0.911765  0.088235  240.470588   96.200000  1.000000        0
# 113  0.923077  0.076923  247.692308   91.923077  0.935484        0

# %%
mean(data_max,'有效率')
print('-------------------')
mean(data_one,'有效率')
print('--------------------')
mean(data_two,'有效率')
print('--------------------')
mean(data_min,'有效率')
# Out:
# 0.9398893934311064
# 0.05355573660343543
# -------------------
# 0.9438608521186624
# 0.05280260537740142
# --------------------
# 0.960455747955748
# 0.0736089254494862
# --------------------
# 0.4508771929824561
# 0.48735407842795186

# %%
print(data_max['复购人数'].sum())
print(data_one['复购人数'].sum())
print(data_two['复购人数'].sum())
print(data_min['复购人数'].sum())
# Out:
# 57
# 42
# 24
# 12

# %%
mean(data_max,'复购率')
print('-------------------')
mean(data_one,'复购率')
print('--------------------')
mean(data_two,'复购率')
print('--------------------')
mean(data_min,'复购率')
# Out:
# 0.10215769263001978
# 0.06400680696682703
# -------------------
# 0.08334720629841716
# 0.08025591817490506
# --------------------
# 0.07874779541446207
# 0.11245888299254789
# --------------------
# 0.07192982456140351
# 0.23900482153230704

# %%
print(data_max['原价交易额'].sum())
print(data_one['原价交易额'].sum())
print(data_two['原价交易额'].sum())
print(data_min['原价交易额'].sum())
# Out:
# 127454.0
# 128968.0
# 72025.0
# 20722.0

# %%
print(data_max['实付交易额'].sum())
print(data_one['实付交易额'].sum())
print(data_two['实付交易额'].sum())
print(data_min['实付交易额'].sum())
# Out:
# 54830.6
# 52129.0
# 26261.6
# 8064.799999999999

# %%
mean(data_max,'原价客单价')
print('-------------------')
mean(data_one,'原价客单价')
print('--------------------')
mean(data_two,'原价客单价')
print('--------------------')
mean(data_min,'原价客单价')
# Out:
# 237.7237731697029
# 33.550564162698684
# -------------------
# 244.63027951959782
# 48.762142942749236
# --------------------
# 251.63277116402116
# 49.171662863520964
# --------------------
# 115.47017543859648
# 134.33225922380745

# %%
mean(data_max,'实付客单价')
print('-------------------')
mean(data_one,'实付客单价')
print('--------------------')
mean(data_two,'实付客单价')
print('--------------------')
mean(data_min,'实付客单价')
# Out:
# 101.96739848629241
# 18.691582874001515
# -------------------
# 98.82545748185453
# 30.004773815198256
# --------------------
# 91.18735670194002
# 19.828289405517417
# --------------------
# 46.77
# 66.7838720869192

# %%
print(data_max['下单人数'].sum())
print(data_one['下单人数'].sum())
print(data_two['下单人数'].sum())
print(data_min['下单人数'].sum())
# Out:
# 536
# 526
# 289
# 96
