# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)
from pyecharts import Bar3D # 3D柱形图
# %matplotlib inline

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code)
    return data

# %%
lujing = r'C:/Users/Administrator/Datas/艾尚花语/艾尚月季度数据/7月份数据/Data/艾尚七夕好评.xlsx'
code = 'utf8'
data = improt_data(lujing,code)

# %%
data.head()
# Out:
#   所属账号  账号负责人  门店数  5星门店数  5星门店占比  每日好评数  优质好评数  截至当日动销门店数  截至当日动销门店率  \
# 0  总账号    NaN  186    NaN     NaN     25      0         42     0.2258
# 1  总账号    NaN  187    0.0  0.0000     14      0         58     0.3102
# 2  总账号    NaN  189    4.0  0.0209     34      0         73     0.3862
# 3  总账号    NaN  191    4.0  0.0209     36      3         89     0.4660
# 4  总账号    NaN  191    8.0  0.0419     36      3         94     0.4921
#
#    较前一天动销增长率  体检分中等以上门店率  较前一天中等体检分增长率  当日订单数  较昨天订单增长单数  无效订单数         日期
# 0     0.0000      0.3208        0.0000     58          0      3 2020-07-27
# 1     0.0844      0.3690        0.0482     45        -13      4 2020-07-28
# 2     0.0760      0.3863        0.0173     58         13      9 2020-07-29
# 3     0.0798      0.3875        0.0012     67          9      4 2020-07-30
# 4     0.0261      0.3822       -0.0053     58         -9      7 2020-07-31

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
fig = plt.figure(figsize = (10,6))
# 绘图
plt.plot(data.日期, # x轴数据
         data.当日订单数, # y轴数据
         linestyle = '-', # 折线类型
         linewidth = 2, # 折线宽度
         color = 'steelblue', # 折线颜色
         marker = '', # 点的形状
         markersize = 6, # 点的大小
         markeredgecolor='black', # 点的边框色
         markerfacecolor='brown') # 点的填充色
# 添加标题和坐标轴标签
plt.title('当日订单数折线图')
plt.xlabel('日期')
plt.ylabel('订单数')

# 剔除图框上边界和右边界的刻度
plt.tick_params(top = 'off', right = 'off')

# 为了避免x轴日期刻度标签的重叠，设置x轴刻度自动展现，并且45度倾斜
fig.autofmt_xdate(rotation = 45)

# 显示图形
plt.show()

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
fig = plt.figure(figsize = (10,6))
# 绘图
plt.plot(data.日期, # x轴数据
         data.体检分中等以上门店率, # y轴数据
         linestyle = '-', # 折线类型
         linewidth = 2, # 折线宽度
         color = 'steelblue', # 折线颜色
         marker = '', # 点的形状
         markersize = 6, # 点的大小
         markeredgecolor='black', # 点的边框色
         markerfacecolor='brown') # 点的填充色
# 添加标题和坐标轴标签
plt.title('中等体检分门店率折线图')
plt.xlabel('日期')
plt.ylabel('门店比')

# 剔除图框上边界和右边界的刻度
plt.tick_params(top = 'off', right = 'off')

# 为了避免x轴日期刻度标签的重叠，设置x轴刻度自动展现，并且45度倾斜
fig.autofmt_xdate(rotation = 45)

# 显示图形
plt.show()

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
fig = plt.figure(figsize = (10,6))
# 绘图
plt.plot(data.日期, # x轴数据
         data.截至当日动销门店数, # y轴数据
         linestyle = '-', # 折线类型
         linewidth = 2, # 折线宽度
         color = 'steelblue', # 折线颜色
         marker = '', # 点的形状
         markersize = 6, # 点的大小
         markeredgecolor='black', # 点的边框色
         markerfacecolor='brown') # 点的填充色
# 添加标题和坐标轴标签
plt.title('截至当日动销门店数折线图')
plt.xlabel('日期')
plt.ylabel('动销门店率')

# 剔除图框上边界和右边界的刻度
plt.tick_params(top = 'off', right = 'off')

# 为了避免x轴日期刻度标签的重叠，设置x轴刻度自动展现，并且45度倾斜
fig.autofmt_xdate(rotation = 45)

# 显示图形
plt.show()
