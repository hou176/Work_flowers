# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)
from pyecharts import Bar3D # 3D柱形图
# %matplotlib inline

# %%
def improt_data(lujing,code):
    data = pd.read_csv(lujing,encoding =code)
    return data

# %%
lujing = r'C:\Users\Administrator\Datas\爱尚花语\艾尚月季度数据\季度累计数据\data_rfm.csv'
code = 'gbk'
data = improt_data(lujing,code)

# %%
data.head()
# Out:
#    Unnamed: 0      time     商家ID           商家名称     r   f       m  r_score  \
# 0           0  20200701  9024275   花韵花艺馆鲜花礼品鲜花店  18.0   0     0.0        3
# 1           1  20200701  9024278  友新意鲜花坊鲜花礼品鲜花店  18.0  50  5459.4        3
# 2           2  20200701  9043306       花之都创意鲜花馆  18.0   1    56.0        3
# 3           3  20200701  9043308    时初花艺鲜花礼品鲜花店   4.2   0     0.0        1
# 4           4  20200701  9043310    元寳花店鲜花礼品鲜花店   9.0   5   410.0        1
#
#    f_score  m_score  rfm_group
# 0        1        1        311
# 1        3        3        333
# 2        1        1        311
# 3        1        1        111
# 4        1        2        112

# %%
display_data =data.groupby(['rfm_group','time'],as_index=False)['商家ID'].count()
display_data.columns = ['rfm_group','year','number']
display_data['rfm_group'] = display_data['rfm_group'].astype(np.int32)
display_data
# Out:
#     rfm_group      year  number
# 0         111  20200601      33
# 1         111  20200701      50
# 2         112  20200601      10
# 3         112  20200701       6
# 4         121  20200701       1
# 5         122  20200601       4
# 6         122  20200701      21
# 7         123  20200601       7
# 8         123  20200701       1
# 9         133  20200601       8
# 10        133  20200701      17
# 11        211  20200601      16
# 12        211  20200701      32
# 13        212  20200601       2
# 14        222  20200601       4
# 15        222  20200701       5
# 16        223  20200601       2
# 17        233  20200601       3
# 18        233  20200701      12
# 19        311  20200601      11
# 20        311  20200701      13
# 21        312  20200601       2
# 22        312  20200701       1
# 23        322  20200601       7
# 24        322  20200701      12
# 25        323  20200601       1
# 26        323  20200701       2
# 27        332  20200701       2
# ...

# %%
list_one = []
list_two = []
for index, row in display_data.iterrows():
    a = row['']

# %%
bar3d = Bar3D("", width=100, height=600)
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
bar3d.add(
    "rfm分组结果",
    "",
    "",
    [d.tolist() for d in display_data.values],
    
    is_visualmap=True,
    
    visual_range=[0, display_data['number'].max()],
    
#     visual_range_color=range_color,
    
    grid3d_width=200,
    grid3d_height=80,
    grid3d_depth=80
)
bar3d
# Out:
# <div id="2020-08-12 18:35:31.575498" style="width:100px; height:600px;"></div>
# <script>
#     require.config({
#          paths:{
#             echarts: '//cdn.bootcss.com/echarts/3.6.2/echarts.min',
#             echartsgl: '//oog4yfyu0.bkt.clouddn.com/echarts-gl',
#             china: '//echarts.baidu.com/gallery/vendors/echarts/map/js/china',
#          }
#     });
#     require(['echarts', 'echartsgl', 'china'],function(ec){
#     var myChart = ec.init(document.getElementById('2020-08-12 18:35:31.575498'));
#                var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
#!/usr/bin/python3
#code-python(3.6)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()  #设置画布
#将画布分为1行1列，共1个子图，并定位在第1个子图
ax = fig.add_subplot(111, projection='3d')  #画3D图
x = [1, 2, 3]
y = [4,5,6]
z = [7,8,9]
ax.bar(x, y, zs=z,zdir='y',color='blue')    #将y值刻在z轴
plt.show()

# %%
#!/usr/bin/python3
#code-python(3.6)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = [1, 2, 3]
y = [4,5,6]
z = [2,2,1]
ax.bar(x, y, zs=z, color='blue', alpha=0.8)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = Axes3D(fig)

# %%
ax.scatter(x,y,z)
plt.savefig('picture.jpg')
plt.show()

# %%
ax.plot_surface(x,y,z,rstride=1,cstride=1,camp=plt.get_cmap('rainbow'））#彩虹色
# Out:
#   File "<ipython-input-35-3ad546ca78c3>", line 1
#     ax.plot_surface(x,y,z,rstride=1,cstride=1,camp=plt.get_cmap('rainbow')） #彩虹色
#                                                                           ^
# SyntaxError: invalid character in identifier

# %%
ax.contour(x,y,z,zdir='z',offset=-2,camp=plt.get_camp('rainbow'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-e653cb612bcd> in <module>
# ----> 1 ax.contour(x,y,z,zdir='z',offset=-2,camp=plt.get_camp('rainbow'))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'get_camp'

# %%
plt.show()
