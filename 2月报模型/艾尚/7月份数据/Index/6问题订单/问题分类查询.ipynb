# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code )
    return data

# %%
def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['订单编号'].count()
        dict_ = {}
    
        if sum_ > 1 :
            list__.append(b)
            dict_ = {b:sum_}
            list_sum.append(dict_)
        else:
            list__.append(b)
            dict_ = {b:sum_}
            list_sum_.append(dict_)
        i = i + 1  
    k = [list_sum,list_sum_,list__]
    return k
def wenzi(list_1,z):
    list_2 = []
    i = 0
    for x in list_1:

        y = x

        tr = y.find(z)
        if tr > -1 :
            i = i+1
            list_2.append(x)
   

    print('关于' + '“' + zi + '”' + '的订单数量是：',i)  
    return list_2


def shaixuan(data,a,b,c):
    data = data[data[a] == b]
    df = data.drop_duplicates(subset=c,inplace=False,keep = 'last')
    list_ = list(df[c])
    list_sum = []
    list_sum_ = []
    list__ = []
    for i in range(len(list_)):
        j = list_[i]
        
        sum_ = data[data[c] == j ]['订单编号'].count()
        dict_ = {}
        if sum_ > 1 :
            list__.append(j)
            dict_ = {j:sum_}
            list_sum.append(dict_)
        else:
            list__.append(j)
            dict_ = {j:sum_}
            list_sum_.append(dict_)
        i = i + 1 
    k = [list_sum,list__,list_sum_]
    return k 

def syn(data,a,b):
    dataframe = pd.DataFrame()
    for i in range(len(b)):
        x = b[i]
        df = data[data[a] == x ]

        dataframe = dataframe.append(df)
    return dataframe

# %%
lujing = r'C:\Users\Administrator\Datas\艾尚花语\艾尚月季度数据\7月份数据\Data/无效订单.xls'
code = 'gbk'
df = improt_data(lujing,code)

# %%
df
# Out:
#                  订单编号                     门店名称       门店ID                下单时间  \
# 0   93146063126568044                      NaN        NaN 2020-06-29 10:17:00
# 1   92953252871595796                      NaN        NaN 2020-06-30 11:27:00
# 2   90242780178790164                      NaN        NaN 2020-07-02 08:41:00
# 3   92238723863016689                    天天花坊   9223872.0 2020-07-06 11:41:00
# 4   92212392488802479                   花知语婚典   9228865.0 2020-07-07 16:04:00
# 5   92288652488802479                     花仙子   9221239.0 2020-07-07 14:52:00
# 6   94398961932190118                      NaN        NaN 2020-07-08 15:49:00
# 7   93226971932190118                      NaN        NaN 2020-07-08 14:50:00
# 8   92212390039859179                      NaN        NaN 2020-07-08 09:59:00
# 9   94798810900598053                    鲜花朵朵   9479881.0 2020-07-09 23:42:00
# 10  91321252145229893                    等你花舍   9132125.0 2020-07-10 07:26:00
# ...

# %%
s = drop_du(df,'门店名称')

# %%
# s

# %%
s = drop_du(df,'退单主体')
s
# Out:
# [[{'顾客退款': 11}, {'商家退款': 23}], [{'极速同款': 1}], ['顾客退款', '极速同款', '商家退款']]

# %%
x = shaixuan(df,'退单主体','顾客退款','退单原因')
x
# Out:
# [[{'顾客急速退款': 5}, {'商家联系我说没货了': 3}],
#  ['计划有变，我不想要了',
#   '顾客急速退款',
#   '商家联系我说没货了',
#   '商家其他原因电话挂断，商家无人回复，九点的单，一直没人理会',
#   '商品出问题（质量、重量、图片不符等）太坑人了图片跟现实中收到的完全不一样。'],
#  [{'计划有变，我不想要了': 1},
#   {'商家其他原因电话挂断，商家无人回复，九点的单，一直没人理会': 1},
#   {'商品出问题（质量、重量、图片不符等）太坑人了图片跟现实中收到的完全不一样。': 1}]]

# %%
x = shaixuan(df,'退单原因','顾客急速退款','备注原因')
x
# Out:
# [[], [nan], [{nan: 0}]]

# %%
list_name = list(data_name_)
zi = '拒单'
wenzi(list_name,zi)

# %%
s = drop_du(df,'退单主体')
s
# Out:
# [[{'顾客退款': 11}, {'商家退款': 23}], [{'极速同款': 1}], ['顾客退款', '极速同款', '商家退款']]

# %%
x = shaixuan(df,'退单主体','商家退款','退单原因')
x
# Out:
# [[{'商家拒单': 2}, {'下单超时未确认，系统自动取消': 5}, {'商家联系我说没货了': 5}],
#  ['商家太忙，拒单 ',
#   '超时未接',
#   '商品已售完',
#   '静上花开鲜花礼品鲜花店',
#   '俊萍花艺鲜花礼品鲜花店',
#   '其他不好',
#   '给接单后，商家拒单',
#   '配送时间太早',
#   '地址无法配送',
#   '联系不上用户',
#   '商家拒单',
#   '其他改个送货时间',
#   '下单超时未确认，系统自动取消',
#   '商家联系我说没货了'],
#  [{'商家太忙，拒单 ': 1},
#   {'超时未接': 1},
#   {'商品已售完': 1},
#   {'静上花开鲜花礼品鲜花店': 1},
#   {'俊萍花艺鲜花礼品鲜花店': 1},
#   {'其他不好': 1},
#   {'给接单后，商家拒单': 1},
#   {'配送时间太早': 0},
#   {'地址无法配送': 1},
#   {'联系不上用户': 0},
#   {'其他改个送货时间': 0}]]

# %%
x = shaixuan(df,'退单原因','下单超时未确认，系统自动取消','备注原因')
x
# Out:
# [[{'商家未接': 2}],
#  ['商家未接', '超时未接到', '老板在休息', '店铺出去玩，没有调休。联系不到店铺'],
#  [{'超时未接到': 1}, {'老板在休息': 1}, {'店铺出去玩，没有调休。联系不到店铺': 1}]]

# %%
x = shaixuan(df,'门店名称','拾花间鲜花礼品鲜花店','备注原因')
x
# Out:
# [[], [], []]

# %%
df[df['门店ID'] == 9438920]
# Out:
#                  订单编号         门店名称       门店ID                下单时间  \
# 19  94389202108776062  拾花间鲜花礼品鲜花店   9438920.0 2020-07-23 12:17:00
# 23  94389202845207833  拾花间鲜花礼品鲜花店   9438920.0 2020-07-28 19:36:00
# 25  94389203470429064  拾花间鲜花礼品鲜花店   9438920.0 2020-07-30 23:21:00
# 26  94389201276496070  拾花间鲜花礼品鲜花店   9438920.0 2020-07-30 15:52:00
# 31  94389201347763621  拾花间鲜花礼品鲜花店   9438920.0 2020-08-08 22:38:00
#
#                   退单时间  退单主体 退款提示       退单原因    日期  \
# 19 2020-07-23 12:48:00  商家退款  NaN  商家联系我说没货了  7.22
# 23 2020-07-28 22:16:00  顾客退款  NaN  商家联系我说没货了  7.28
# 25 2020-07-30 23:25:00  顾客退款  NaN  商家联系我说没货了  7.30
# 26 2020-07-30 16:01:00  顾客退款  NaN  商家联系我说没货了  7.30
# 31 2020-08-08 22:45:00  极速同款  NaN  商家联系我说没货了  8.80
#
#                                             备注原因         解决办法 是否解决
# 19                                  嫌价格低，联系订花人取消       已回访，调价    是
# 23                               自己接单出门了，不转单怕给差评      做不了线下退款    是
# ...
