# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append(r'C:\Users\Administrator\Datas\程序冗余\Python_files\pandas_')
from defname import  *

# %%
def quantile_three(data_month,a):
    print(data_month[a].quantile(0.75))
    print(data_month[a].quantile(0.5))
    print(data_month[a].quantile(0.25))

# %%
data_days_8 = pd.read_csv(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/一家花店/8/8日.csv',encoding='gbk')     
data_month_8 = pd.read_csv(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/一家花店/8/8.csv',encoding='gbk')

# %%
data_month_8['商家ID'].count()
# Out:
# 2048

# %%
data_month_8 = data_month_8.sort_values(by='有效订单数',ascending= False)

# %%
data_month_8['问题单'] = data_month_8['商家原因取消订单数']+data_month_8['商家拒单数']+data_month_8['商家超时未接单数']+data_month_8['商家取消不告知用户订单数']+data_month_8['缺货导致退款订单数']+data_month_8['商家少送错送导致用户退款订单数']+data_month_8['商家质量问题导致用户退款订单数']

# %%
data_month_8
# Out:
#           开始日期      结束日期     商家ID                   商家名称  运营组        省份    城市  \
# 427   20200801  20200831  5531687          邂逅花坊鲜花(雅韵鲜花店）  鲜花组       山西省   长治市
# 389   20200801  20200831  5444884            邂逅花坊鲜花（先花店）  鲜花组       广东省    广州
# 882   20200801  20200831  6023935           邂逅花坊鲜花（缤纷花艺）  鲜花组       广东省    阳江
# 449   20200801  20200831  5531963  邂逅花坊鲜花（BEWITHYOU早安花艺）  鲜花组       浙江省    台州
# 329   20200801  20200831  5417954           邂逅花坊鲜花（倾心花艺）  鲜花组       安徽省    合肥
# ...        ...       ...      ...                    ...  ...       ...   ...
# 101   20200801  20200831  4568666          邂逅花坊鲜花（柠檬草花语）  鲜花组  新疆维吾尔自治区  乌鲁木齐
# 1384  20200801  20200831  8331705        邂逅花坊鲜花（木锦印记鲜花坊）  鲜花组       山东省    淄博
# 1402  20200801  20200831  8408780            邂逅花坊鲜花（荼草作）  鲜花组       上海市    上海
# 1409  20200801  20200831  8409433           邂逅花坊鲜花（院子花艺）  鲜花组   广西壮族自治区    北海
# 2047  20200801  20200831  9857476                   程妮花坊  鲜花组       广东省    广州
#
# ...

# %%
data_month_8['（日均）在线营业时长（h）'].mean()
# Out:
# 15.756542968749937

# %%
data_month_8.boxplot('（日均）在线营业时长（h）')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 22343 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 22312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
data_month_8.boxplot('曝光人数')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
data_month_8.boxplot('入店人数')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20837 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 24215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20837 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
data_month_8.boxplot('下单人数')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 19979 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 21333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 19979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
quantile_three(data_month_8,'（日均）在线营业时长（h）')
# Out:
# 18.4
# 15.7
# 14.7

# %%
quantile_three(data_month_8,'曝光人数')
# Out:
# 8281.25
# 5443.0
# 3402.75

# %%
quantile_three(data_month_8,'入店人数')
# Out:
# 578.0
# 313.5
# 155.75

# %%
quantile_three(data_month_8,'下单人数')
# Out:
# 55.0
# 27.0
# 11.0

# %%
quantile_three(data_month_8,'问题单')
# Out:
# 2.0
# 0.0
# 0.0

# %%
quantile_three(data_month_8,'差评订单数')
# Out:
# 1.0
# 0.0
# 0.0

# %%
data_month_8['差评订单数'].quantile(0.99)
# Out:
# 5.0
