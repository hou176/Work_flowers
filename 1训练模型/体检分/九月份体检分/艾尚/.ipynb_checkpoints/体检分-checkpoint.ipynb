# %%
import pandas as pd 
import numpy  as np

# %%
df1 = pd.read_csv('0902艾尚.csv',encoding='gbk')

# %%
df1
# Out:
#                                  门店     门店ID 城市(城市负责人)   体检分 权益奖励  \
# 0       花韵花艺馆鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9024275        郑州  61.0   --
# 1         友新意鲜花坊(七夕节预定,生日鲜花，表白鲜花)\t  9024278        西安  73.0   --
# 2       花之都创意鲜花馆(七夕节预定,生日鲜花，表白鲜花)\t  9043306        潍坊  80.0   --
# 3        时初花艺鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9043308        咸阳  58.0   --
# 4    元寳花店鲜花礼品鲜花店(七夕节预定,生日鲜花，表白鲜花)\t  9043310        长春  66.0   --
# ..                              ...      ...       ...   ...  ...
# 253                          玫瑰花店\t  9811345        怀化  75.0   --
# 254                         绿之川花艺\t  9819316        杭州  62.0   --
# 255                          诗情花艺\t  9835439      齐齐哈尔  53.0   --
# 256                        花觅花艺甜品\t  9850495        唐山  61.0   --
# 257                     雅园花馆-艾尚花语\t  9863847        柳州  57.0   --
#
#      近7日服务问题导致的营业额损失(元) 本周触犯红线 上周触犯红线
# 0                     0  未触犯红线  未触犯红线
# 1                     0  未触犯红线  未触犯红线
# 2                     0  未触犯红线  未触犯红线
# ...

# %%
df2 = pd.read_csv('0902.csv',encoding='gbk')

# %%
df2
# Out:
#          开始日期      结束日期     商家ID                    商家名称  运营组       省份    城市  \
# 0    20200902  20200902  9024275     花韵花艺馆鲜花店(生日鲜花，表白鲜花)  鲜花组      河南省    郑州
# 1    20200902  20200902  9024278       友新意鲜花坊(生日鲜花，表白鲜花)  鲜花组      陕西省    西安
# 2    20200902  20200902  9043306     花之都创意鲜花馆(生日鲜花，表白鲜花)  鲜花组      山东省    潍坊
# 3    20200902  20200902  9043308      时初花艺鲜花店(生日鲜花，表白鲜花)  鲜花组      陕西省    咸阳
# 4    20200902  20200902  9043310  元寳花店鲜花礼品鲜花店(生日鲜花，表白鲜花)  鲜花组      吉林省    长春
# ..        ...       ...      ...                     ...  ...      ...   ...
# 253  20200902  20200902  9811345          玫瑰花店-生日鲜花，表白鲜花  鲜花组      湖南省    怀化
# 254  20200902  20200902  9819316        绿之川花艺（生日鲜花，表白鲜花）  鲜花组      浙江省    杭州
# 255  20200902  20200902  9835439                    诗情花艺  鲜花组     黑龙江省  齐齐哈尔
# 256  20200902  20200902  9850495                  花觅花艺甜品  鲜花组      河北省    唐山
# 257  20200902  20200902  9863847               雅园花馆-艾尚花语  鲜花组  广西壮族自治区    柳州
#
# ...
