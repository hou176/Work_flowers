# %%
import pandas as pd 
import numpy as np
import  matplotlib.pyplot  as plt
import sys
sys.path.append(r'C:\Users\Administrator\Desktop\Pyprojects\Python_files\pandas_')
from defname  import *

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\data\艾尚体检分/1.csv',encoding='gbk')
# data2 = pd.read_csv(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/用户数据/12.1春哥/11.csv',encoding='utf8')

# %%
df
# Out:
#                      日期                订单编号                 下单时间 接单时长  \
# 0     20201101-20201216   93458390716742637  2020-11-21 18:52:30   0秒
# 1     20201101-20201216   96083140903055246  2020-12-10 22:49:24  11秒
# 2     20201101-20201216   90433172508985796  2020-12-14 12:08:24  38秒
# 3     20201101-20201216  105359172027415372  2020-12-04 09:39:22  52秒
# 4     20201101-20201216   90242782741981752  2020-11-25 11:22:23  28秒
# ...                 ...                 ...                  ...  ...
# 6033  20201101-20201216  100875550317155100  2020-11-19 21:22:53  41秒
# 6034  20201101-20201216  100875553942999596  2020-11-19 21:00:10  12秒
# 6035  20201101-20201216  100875553835973500  2020-11-19 20:31:49  37秒
# 6036  20201101-20201216  102837363835973500  2020-11-19 15:26:33  32秒
# 6037  20201101-20201216  102837363835973500  2020-11-19 15:26:33  32秒
#
#                              店铺名称      店铺ID 店铺所在城市 订单支付类型  订单状态 订单配送状态 是否预订单  \
# ...

# %%
df = duplicates(df,'商品SKU码')

# %%
df[1]
# Out:
# {'ashy0502': 2,
#  'ashy0498': 572,
#  'ashy0497': 5,
#  'ashy0496': 7,
#  'ashy0495': 5,
#  'ashy0478': 37,
#  'ashy0477': 14,
#  'ashy0476': 7,
#  'ashy0473': 7,
#  'ashy0472': 7,
#  'ashy0471': 3,
#  'ashy0470': 3,
#  'ashy0469': 2,
#  'ashy0461': 8,
#  'ashy0460': 17,
#  'ashy0459': 20,
#  'ashy0458': 18,
#  'ashy0457': 8,
#  'ashy0456': 3,
#  'ashy0455': 8,
#  'ashy0454': 10,
#  'ashy0453': 15,
#  'ashy0452': 55,
#  'ashy0451': 9,
#  'ashy0450': 3,
#  'ashy0449': 18,
#  'ashy0448': 27,
#  'ashy0446': 4,
#  'ashy0445': 14,
#  'ashy0444': 19,
#  'ashy0443': 35,
#  'ashy0442': 47,
#  'ashy0435': 121,
#  'ashy0434': 15,
#  'ashy0431': 38,
#  'ashy0430': 4,
#  'ashy0425': 4,
#  'ashy0424': 57,
#  'ashy0423': 66,
#  'ashy0418': 2,
#  'ashy0417': 8,
#  'ashy0414': 2,
#  'ashy0413': 43,
#  'ashy0412': 13,
#  'ashy0411': 2,
#  'ashy0409': 10,
#  'ashy0408': 39,
#  'ashy0405': 21,
#  'ashy0403': 53,
#  'ashy0402': 8,
#  'ashy0400': 4,
#  'ashy0399': 3,
#  'ashy0397': 7,
# ...

# %%
data = pd.DataFrame.from_dict(df[1],orient='index')

# %%
data = data.sort_values(by=0,ascending=False)

# %%
data
# Out:
#             0
# ashy0498  572
# as0236    550
# as0238    401
# as0241    338
# ashy0390  314
# ...       ...
# as0101      2
# as0100      2
# as0095      2
# as0094      2
# as0218      2
#
# [212 rows x 1 columns]

# %%
data1 = pd.DataFrame.from_dict(df[2],orient='index')

# %%
data1
# Out:
#           0
# ashy0507  1
# ashy0503  1
# ashy0482  1
# ashy0480  1
# ashy0474  1
# ...      ..
# as0010    1
# as0003    1
# as0002    1
# 57        1
# NaN       0
#
# [87 rows x 1 columns]

# %%
data = pd.concat([data,data1],axis=0)

# %%
data.to_csv(r'C:\Users\Administrator\Desktop\data\艾尚体检分/data.csv')

# %%
data = pd.read_excel(r'C:/Users/Administrator/Desktop/data/艾尚体检分/data.xlsx')

# %%
df = df[['店铺名称','商品名称','商品SKU码']]

# %%
df= df.drop_duplicates(subset='商品SKU码',inplace=False)

# %%
data
# Out:
#        商品SKU码   数量
# 0    ashy0498  572
# 1      as0236  550
# 2      as0238  401
# 3      as0241  338
# 4    ashy0390  314
# ..        ...  ...
# 294    as0010    1
# 295    as0003    1
# 296    as0002    1
# 297        57    1
# 298       NaN    0
#
# [299 rows x 2 columns]

# %%
df
# Out:
#                              店铺名称                    商品名称    商品SKU码
# 0       花戒鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰      【新婚快乐】新娘手捧05款 混搭花束  ashy0507
# 1     花王花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰      【新婚快乐】新娘手捧04款 混搭花束  ashy0503
# 2       花坞鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰            幸福相伴 喜娘手捧花鲜花  ashy0502
# 4      友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰       【单枝粉色小雏菊】到店自取款不配送  ashy0498
# 576     花坞鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰          童年乐趣 致知己 一份小惊喜  ashy0497
# ...                           ...                     ...       ...
# 5796     锦上添花-生日鲜花，表白鲜花，开业花篮，婚车装饰        【只因有你】11枝红玫瑰鲜花礼盒        57
# 5797   友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰         【情投意合】蓝色满天星鲜花花束        37
# 5810   花鲜阁鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰  【白头偕老】粉色满天星鲜花花束送女友爱人闺蜜        34
# 5819   友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰        【阳光海岸】11枝粉玫瑰鲜花礼盒       111
# 5956  花开相爱鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰                  【浪漫彩灯】       NaN
#
# [299 rows x 3 columns]

# %%
df= pd.merge(data,df,on='商品SKU码')

# %%
df
# Out:
#        商品SKU码   数量                          店铺名称                   商品名称
# 0    ashy0498  572    友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰      【单枝粉色小雏菊】到店自取款不配送
# 1      as0236  550    友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰    【爱一世】9枝粉玫瑰搭配满天星简约花束
# 2      as0238  401    友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰      【单枝粉色小雏菊】到店自取款不配送
# 3      as0241  338  花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰       【幸福时光】11枝粉玫瑰鲜花花束
# 4    ashy0390  314    友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰  【单枝粉色小雏菊】到店自取款不配送1204
# ..        ...  ...                           ...                    ...
# 290    as0018    1    友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰      【爱的骑士】11枝香槟玫瑰鲜花礼盒
# 291    as0010    1      邂逅花店-生日鲜花，表白鲜花，开业花篮，婚车装饰    【财运亨通】辫子发财树盆栽观赏花+带盆
# 292    as0003    1     花坞鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰      【花开富贵】招钱树盆栽观赏花+带盆
# 293    as0002    1        人家有花鲜花店-生日鲜花，表白鲜花，开业花篮      【招财进宝】发财树盆栽观赏花+带盆
# 294       NaN    0   花开相爱鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰                 【浪漫彩灯】
#
# [295 rows x 4 columns]

# %%
df.to_csv(r'C:\Users\Administrator\Desktop\data\艾尚体检分/data.csv')
