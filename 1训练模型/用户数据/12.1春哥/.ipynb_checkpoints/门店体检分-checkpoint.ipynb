# %%
import pandas as pd 
import numpy as np
import sys
# sys.path.append(r'C:\Users\Administrator\Datas\程序冗余\Python_files\pandas_')
# from defname  import *
import  matplotlib.pyplot  as plt

# %%
data = pd.read_excel(r'C:/Users/Administrator/Desktop/data/12.2.xlsx',encoding='gbk')
df = pd.read_excel(r'C:/Users/Administrator/Desktop/data/艾尚体检分.xlsx',encoding='gbk')

# %%
df = df[['门店ID',12.01]]
df.columns =  ['门店ID','12.01']

# %%
df
# Out:
#          门店ID  12.01
# 0     9024275   56.0
# 1     9024278   85.0
# 2     9043306   69.0
# 3     9043308   68.0
# 4     9043310   82.0
# ..        ...    ...
# 427  10537530   55.0
# 428  10540218   56.0
# 429  10553536   55.0
# 430  10553537   73.0
# 431  10553783   50.0
#
# [432 rows x 2 columns]

# %%
test = data[['门店','门店ID','城市(城市负责人)']]

# %%
data = data[['门店ID','体检分']]
data.columns = ['门店ID','12.02']
data
# Out:
#          门店ID  12.02
# 0     9024275   56.0
# 1     9024278   86.0
# 2     9043306   69.0
# 3     9043308   68.0
# 4     9043310   81.0
# ..        ...    ...
# 431  10553537   75.0
# 432  10553541   53.0
# 433  10553783   71.0
# 434  10557998   66.0
# 435  10557999   64.0
#
# [436 rows x 2 columns]

# %%
test
# Out:
#                                     门店      门店ID 城市(城市负责人)
# 0      花韵花艺馆鲜花店(生日鲜花，表白鲜花，开业花篮，婚车装饰)\t   9024275        郑州
# 1         友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278        西安
# 2       花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043306        潍坊
# 3        时初花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043308        咸阳
# 4    元寳花店鲜花礼品鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043310        长春
# ..                                 ...       ...       ...
# 431         花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537        遵义
# 432        名卉鲜花（丹青路店-生日鲜花，表白鲜花，开业花篮）\t  10553541        南京
# 433            公主鲜花店（南三巷店-生日鲜花，表白鲜花）\t  10553783        中山
# 434             浪漫花苑（联民街店-生日鲜花，表白鲜花）\t  10557998        中山
# 435             田园花坊（永泰路店-生日鲜花，表白鲜花）\t  10557999        中山
#
# [436 rows x 3 columns]

# %%
test = pd.merge(test,df,on='门店ID',left_index=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-3b339d1e810e> in <module>
# ----> 1 test = pd.merge(test,df,on='门店ID',left_index='left')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     600
#     601         if not is_bool(left_index):
# --> 602             raise ValueError(
#     603                 "left_index parameter must be of type bool, not "
#     604                 "{left_index}".format(left_index=type(left_index))
#
# ValueError: left_index parameter must be of type bool, not <class 'str'>

# %%
test = pd.merge(test,data,on='门店ID',left_index=test)

# %%
test
# Out:
#                                     门店      门店ID 城市(城市负责人)  12.01  12.02
# 0      花韵花艺馆鲜花店(生日鲜花，表白鲜花，开业花篮，婚车装饰)\t   9024275        郑州   56.0   56.0
# 1         友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278        西安   85.0   86.0
# 2       花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043306        潍坊   69.0   69.0
# 3        时初花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043308        咸阳   68.0   68.0
# 4    元寳花店鲜花礼品鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043310        长春   82.0   81.0
# ..                                 ...       ...       ...    ...    ...
# 427      521鲜花坊（和平路店-生日鲜花，表白鲜花，婚车装饰）\t  10537530        锦州   55.0   67.0
# 428           花艺空间（孙村七号路店-生日鲜花，表白鲜花）\t  10540218        济南   56.0   69.0
# 429         花之缘（灵台县店-生日鲜花，表白鲜花，开业花篮）\t  10553536        平凉   55.0   70.0
# 430         花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537        遵义   73.0   75.0
# 431            公主鲜花店（南三巷店-生日鲜花，表白鲜花）\t  10553783        中山   50.0   71.0
#
# [432 rows x 5 columns]

# %%
df
# Out:
#          门店ID  12.01                                 门店 城市(城市负责人)  12.02
# 0     9024275   56.0    花韵花艺馆鲜花店(生日鲜花，表白鲜花，开业花篮，婚车装饰)\t        郑州   56.0
# 1     9024278   85.0       友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t        西安   86.0
# 2     9043306   69.0     花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰\t        潍坊   69.0
# 3     9043308   68.0      时初花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t        咸阳   68.0
# 4     9043310   82.0  元寳花店鲜花礼品鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t        长春   81.0
# ..        ...    ...                                ...       ...    ...
# 427  10537530   55.0      521鲜花坊（和平路店-生日鲜花，表白鲜花，婚车装饰）\t        锦州   67.0
# 428  10540218   56.0           花艺空间（孙村七号路店-生日鲜花，表白鲜花）\t        济南   69.0
# 429  10553536   55.0         花之缘（灵台县店-生日鲜花，表白鲜花，开业花篮）\t        平凉   70.0
# 430  10553537   73.0         花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t        遵义   75.0
# 431  10553783   50.0            公主鲜花店（南三巷店-生日鲜花，表白鲜花）\t        中山   71.0
#
# [432 rows x 5 columns]

# %%
df['value'] = df[12.01]-df['12.02']
df['value'] = df['value'].astype('int')

# %%
df
# Out:
#                                     门店      门店ID 城市(城市负责人)  12.01  12.02  \
# 0      花韵花艺馆鲜花店(生日鲜花，表白鲜花，开业花篮，婚车装饰)\t   9024275        郑州   56.0   56.0
# 1         友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278        西安   85.0   86.0
# 2       花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043306        潍坊   69.0   69.0
# 3        时初花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043308        咸阳   68.0   68.0
# 4    元寳花店鲜花礼品鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043310        长春   82.0   81.0
# ..                                 ...       ...       ...    ...    ...
# 427      521鲜花坊（和平路店-生日鲜花，表白鲜花，婚车装饰）\t  10537530        锦州   55.0   67.0
# 428           花艺空间（孙村七号路店-生日鲜花，表白鲜花）\t  10540218        济南   56.0   69.0
# 429         花之缘（灵台县店-生日鲜花，表白鲜花，开业花篮）\t  10553536        平凉   55.0   70.0
# 430         花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537        遵义   73.0   75.0
# 431            公主鲜花店（南三巷店-生日鲜花，表白鲜花）\t  10553783        中山   50.0   71.0
#
#      value
# 0        0
# 1       -1
# 2        0
# 3        0
# 4        1
# ..     ...
# 427    -12
# 428    -13
# 429    -15
# 430     -2
# 431    -21
#
# [432 rows x 6 columns]

# %%
df['test'] = None

# %%
df.test[df.value > 0] = -1
df.test[df.value == 0] = 0
df.test[df.value < 0] = 1
# Out:
# <ipython-input-25-75d714748beb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.test[df.value > 0] = -1
# <ipython-input-25-75d714748beb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.test[df.value == 0] = 0
# <ipython-input-25-75d714748beb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.test[df.value < 0] = 1

# %%
df
# Out:
#                                     门店      门店ID 城市(城市负责人)  12.01  12.02  \
# 0      花韵花艺馆鲜花店(生日鲜花，表白鲜花，开业花篮，婚车装饰)\t   9024275        郑州   56.0   56.0
# 1         友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278        西安   85.0   86.0
# 2       花之都创意鲜花馆-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043306        潍坊   69.0   69.0
# 3        时初花艺鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043308        咸阳   68.0   68.0
# 4    元寳花店鲜花礼品鲜花店-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9043310        长春   82.0   81.0
# ..                                 ...       ...       ...    ...    ...
# 427      521鲜花坊（和平路店-生日鲜花，表白鲜花，婚车装饰）\t  10537530        锦州   55.0   67.0
# 428           花艺空间（孙村七号路店-生日鲜花，表白鲜花）\t  10540218        济南   56.0   69.0
# 429         花之缘（灵台县店-生日鲜花，表白鲜花，开业花篮）\t  10553536        平凉   55.0   70.0
# 430         花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537        遵义   73.0   75.0
# 431            公主鲜花店（南三巷店-生日鲜花，表白鲜花）\t  10553783        中山   50.0   71.0
#
#      value test
# 0        0    0
# 1       -1    1
# 2        0    0
# 3        0    0
# 4        1   -1
# ..     ...  ...
# 427    -12    1
# 428    -13    1
# 429    -15    1
# 430     -2    1
# 431    -21    1
#
# [432 rows x 7 columns]

# %%
df = df.drop(columns=['value'])

# %%
df.to_excel('艾尚体检分.xlsx')
