# %%
import pandas as pd 
import numpy as np
import sys
sys.path.append(r'C:\Users\Administrator\Datas\程序冗余\Python_files\pandas_')
from defname  import *
import  matplotlib.pyplot  as plt

# %%
data1 = pd.read_csv(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/用户数据/12.1春哥/1.csv',encoding='gbk')
data2 = pd.read_csv(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/用户数据/12.1春哥/11.csv',encoding='utf8')

# %%
data1
# Out:
#                        日期                订单编号                   下单时间 接单时长  \
# 0     \t20201101-20201130   90242783929940047  2020-11-02 06:13:38\t   0秒
# 1     \t20201101-20201130   90242781262263527  2020-11-02 12:32:23\t  35秒
# 2     \t20201101-20201130   90242783234671115  2020-11-02 20:40:22\t  19秒
# 3     \t20201101-20201130   90242784212612522  2020-11-03 14:17:10\t  33秒
# 4     \t20201101-20201130   90242781622548099  2020-11-03 16:30:53\t  17秒
# ...                   ...                 ...                    ...  ...
# 3454  \t20201101-20201130  105535372485584206  2020-11-28 21:32:34\t  26秒
# 3455  \t20201101-20201130  105535371243363050  2020-11-28 21:34:52\t  10秒
# 3456  \t20201101-20201130  105535372506186604  2020-11-29 12:45:46\t  65秒
# 3457  \t20201101-20201130  105535370278840598  2020-11-30 13:59:18\t   9秒
# 3458  \t20201101-20201130  105535371188626620  2020-11-30 17:08:21\t   5秒
#
#                               店铺名称      店铺ID 店铺所在城市 订单支付类型  订单状态  订单配送状态  \
# 0     友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278   西安\t   在线支付  订单完成     配送中
# 1     友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278   西安\t   在线支付  订单完成     配送中
# 2     友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278   西安\t   在线支付  订单完成  用户提交订单
# 3     友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278   西安\t   在线支付  订单完成  用户提交订单
# 4     友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t   9024278   西安\t   在线支付  订单完成  用户提交订单
# ...                            ...       ...    ...    ...   ...     ...
# 3454    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537   遵义\t   在线支付  订单完成     配送中
# 3455    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537   遵义\t   在线支付  订单完成     配送中
# 3456    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537   遵义\t   在线支付  订单完成     配送中
# 3457    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537   遵义\t   在线支付  订单完成     配送中
# 3458    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t  10553537   遵义\t   在线支付  订单完成     配送中
#
#      是否预订单  订单总金额  订单折扣后金额  平台承担活动金额  商家承担活动金额     商品分类  \
# 0        是  259.0     89.0       0.0     175.0   艾尚折扣\t
# 1        否  239.0     86.0       0.0     158.0  11枝专区\t
# 2        否  477.0    411.0       0.0      71.0  52枝专区\t
# 3        否   69.0     36.9       0.0      32.1   家居鲜花\t
# 4        否  259.0    109.0       0.0     155.0   艾尚折扣\t
# ...    ...    ...      ...       ...       ...      ...
# 3454     否  100.0     36.8       0.0      63.2   艾尚折扣\t
# 3455     否  100.0     36.8       0.0      63.2   艾尚折扣\t
# 3456     否  100.0     36.8       0.0      63.2   爱情告白\t
# 3457     否  100.0     33.8       6.0      60.2   爱情告白\t
# 3458     否  100.0     36.8       0.0      63.2   爱情告白\t
#
#                        商品名称  UPC码      商品SKU码  商品销售数量  商品原价销售额  商品实付销售额  \
# 0          【粉色公主】11枝粉玫瑰鲜花礼盒   NaN  ashy0394\t       1    259.0     89.0
# 1          【一生挚爱】11枝红玫瑰鲜花花束   NaN    as0110\t       1    239.0     86.0
# 2     【情动一生】52枝红玫瑰黑纱皇冠款鲜花花束   NaN    as0137\t       1    459.0    396.0
# 3      【日常家居鲜花】3枝粉康乃馨（不带包装）   NaN  ashy0445\t       1     69.0     36.9
# 4         【四块五的妞】11枝红玫瑰鲜花礼盒   NaN  ashy0405\t       1    259.0    109.0
# ...                     ...   ...         ...     ...      ...      ...
# 3454      【单枝粉色小雏菊】到店自取款不配送   NaN  ashy0498\t      20    100.0     36.8
# 3455      【单枝粉色小雏菊】到店自取款不配送   NaN  ashy0498\t      20    100.0     36.8
# 3456      【单枝粉色小雏菊】到店自取款不配送   NaN    as0236\t      20    100.0     36.8
# 3457      【单枝粉色小雏菊】到店自取款不配送   NaN    as0238\t      20    100.0     33.8
# 3458      【单枝粉色小雏菊】到店自取款不配送   NaN    as0238\t      20    100.0     36.8
#
#       商品总补贴金额  商品商家补贴金额  商品平台补贴金额 是否部分退款商品  部分退款商品数量  部分退款商品金额  订单小额付款   配送费  \
# 0       170.0     170.0       0.0        否         0       0.0     0.0   0.0
# 1       153.0     153.0       0.0        否         0       0.0     0.0   0.0
# 2        63.0      63.0       0.0        否         0       0.0     0.0  18.0
# 3        32.1      32.1       0.0        否         0       0.0     0.0   0.0
# 4       150.0     150.0       0.0        否         0       0.0     0.0   0.0
# ...       ...       ...       ...      ...       ...       ...     ...   ...
# 3454     63.2      63.2       0.0        否         0       0.0     0.0   0.0
# 3455     63.2      63.2       0.0        否         0       0.0     0.0   0.0
# 3456     63.2      63.2       0.0        否         0       0.0     0.0   0.0
# 3457     66.2      60.2       6.0        否         0       0.0     0.0   0.0
# 3458     63.2      63.2       0.0        否         0       0.0     0.0   0.0
#
#      是否活动订单                                               优惠活动 是否催单 回复状态  \
# 0         是  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【粉色公主】11枝粉玫瑰鲜花礼盒原价259....    否  未回复
# 1         是  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【一生挚爱】11枝红玫瑰鲜花花束原价239....    否  未回复
# 2         是  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【情动一生】52枝红玫瑰黑纱皇冠款鲜花花束原...    否  未回复
# 3         是  购买【日常家居鲜花】3枝粉康乃馨（不带包装）原价69.0元现价39.9元/门店新客立减3.0元\t    否  未回复
# 4         是  满69.0元赠精美贺卡下单备注贺卡内容*1/购买【四块五的妞】11枝红玫瑰鲜花礼盒原价259...    否  未回复
# ...     ...                                                ...  ...  ...
# 3454      是  购买【单枝粉色小雏菊】到店自取款不配送原价5.0元现价1.99元/购买【单枝粉色小雏菊】到店...    否  已回复
# 3455      是  购买【单枝粉色小雏菊】到店自取款不配送原价5.0元现价1.99元/购买【单枝粉色小雏菊】到店...    否  已回复
# 3456      是  购买【单枝粉色小雏菊】到店自取款不配送原价5.0元现价1.99元/购买【单枝粉色小雏菊】到店...    否  未回复
# 3457      是  用户使用了支付红包减6元/购买【单枝粉色小雏菊】到店自取款不配送原价5.0元现价1.99元/...    否  已回复
# 3458      是  购买【单枝粉色小雏菊】到店自取款不配送原价5.0元现价1.99元/购买【单枝粉色小雏菊】到店...    否  已回复
#
#      商家回复内容   配送时长  打包袋费                 订单完成时间 订单取消原因（仅取消订单）
# 0       NaN  0.00分   0.0  2020-11-02 14:20:14\t           NaN
# 1       NaN  0.00分   0.0  2020-11-02 20:04:56\t           NaN
# 2       NaN  0.00分   0.0  2020-11-03 00:58:15\t           NaN
# 3       NaN  0.00分   0.0  2020-11-03 16:49:43\t           NaN
# 4       NaN  0.00分   0.0  2020-11-03 23:00:18\t           NaN
# ...     ...    ...   ...                    ...           ...
# 3454    NaN  0.00分   0.0  2020-11-29 02:34:22\t           NaN
# 3455    NaN  0.00分   0.0  2020-11-29 02:27:25\t           NaN
# 3456    NaN  0.00分   0.0  2020-11-29 20:25:39\t           NaN
# 3457    NaN  0.00分   0.0  2020-11-30 14:26:24\t           NaN
# 3458    NaN  0.00分   0.0  2020-11-30 18:19:02\t           NaN
#
# [3459 rows x 39 columns]

# %%
data2
# Out:
#      Unnamed: 0                订单编号
# 0             0   96083143202998545
# 1             1   93660911622548099
# 2             2   90242784212612522
# 3             3   94273993663932392
# 4             4   94156114212612522
# ..          ...                 ...
# 260         260   93660913690675580
# 261         261   90439950925241411
# 262         262  102310923690675580
# 263         263  102845160925241411
# 264         264   94273990248610380
#
# [265 rows x 2 columns]

# %%
data1 = data1[['订单编号','店铺ID','店铺名称','商品实付销售额']]

# %%
data2 = data2[['订单编号']]

# %%
data1
# Out:
#                     订单编号      店铺ID                          店铺名称  商品实付销售额
# 0      90242783929940047   9024278  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     89.0
# 1      90242781262263527   9024278  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     86.0
# 2      90242783234671115   9024278  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    396.0
# 3      90242784212612522   9024278  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     36.9
# 4      90242781622548099   9024278  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    109.0
# ...                  ...       ...                           ...      ...
# 3454  105535372485584206  10553537    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3455  105535371243363050  10553537    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3456  105535372506186604  10553537    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3457  105535370278840598  10553537    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     33.8
# 3458  105535371188626620  10553537    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
#
# [3459 rows x 4 columns]

# %%
data2
# Out:
#                    订单编号
# 0     96083143202998545
# 1     93660911622548099
# 2     90242784212612522
# 3     94273993663932392
# 4     94156114212612522
# ..                  ...
# 260   93660913690675580
# 261   90439950925241411
# 262  102310923690675580
# 263  102845160925241411
# 264   94273990248610380
#
# [265 rows x 1 columns]

# %%
data3 = data1.append(data2)

# %%
data3
# Out:
#                    订单编号       店铺ID                          店铺名称  商品实付销售额
# 0     90242783929940047  9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     89.0
# 1     90242781262263527  9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     86.0
# 2     90242783234671115  9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    396.0
# 3     90242784212612522  9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     36.9
# 4     90242781622548099  9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    109.0
# ..                  ...        ...                           ...      ...
# 260   93660913690675580        NaN                           NaN      NaN
# 261   90439950925241411        NaN                           NaN      NaN
# 262  102310923690675580        NaN                           NaN      NaN
# 263  102845160925241411        NaN                           NaN      NaN
# 264   94273990248610380        NaN                           NaN      NaN
#
# [3724 rows x 4 columns]

# %%
data3 = data3.drop_duplicates(subset='订单编号',keep=False)

# %%
data3.to_csv('1.csv')

# %%
data3.dropna(subset=['店铺ID'],inplace=True)
# Out:
# <ipython-input-13-90c4730cf15e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.dropna(subset=['店铺ID'],inplace=True)

# %%
data3
# Out:
#                     订单编号        店铺ID                          店铺名称  商品实付销售额
# 0      90242783929940047   9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     89.0
# 1      90242781262263527   9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t     86.0
# 2      90242783234671115   9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    396.0
# 4      90242781622548099   9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    109.0
# 6      90242780933314362   9024278.0  友新意鲜花坊-生日鲜花，表白鲜花，开业花篮，婚车装饰\t    143.0
# ...                  ...         ...                           ...      ...
# 3453  105535372224284096  10553537.0    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3454  105535372485584206  10553537.0    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3455  105535371243363050  10553537.0    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
# 3457  105535370278840598  10553537.0    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     33.8
# 3458  105535371188626620  10553537.0    花艺坊（上海路店-生日鲜花，表白鲜花，开业花篮）\t     36.8
#
# [2994 rows x 4 columns]

# %%
def j(data, columns_l,x):
    columns_l = columns_l
    df = pd.DataFrame()
    data_only = data.drop_duplicates(subset=x, inplace=False)
    name_id = list(data_only[x])
    #     循环得到不同门店ｄａｔａｆｒａｍｅ
    for i in name_id:
        dict_columns = {}
        df_only = data[data[x] == i]
        # 添加ｄｉｃｔ数据ｊｉｏｎ
        for j in columns_l[0]:
            if j != '0'  :
                dict_columns[j] = df_only.loc[:, [j]][j].values[0]
                # 添加ｄｉｃｔ数据ｓｕｍ
        for k in columns_l[1]:
            if k != '0':
                value = df_only[k].sum()
                dict_columns[k] = value
        for l in columns_l[2]:
            if l != '0' :
                value = df_only[l].mean()
                dict_columns[l] = value
        for m in columns_l[3]:
            if m != '0':
                value = df_only[m].count()
                dict_columns[m] = value

        df = df.append(pd.DataFrame([dict_columns]), ignore_index=True)
    return df

# %%
j(data3,[['店铺名称'],['商品实付销售额'],['0'],['店铺ID']],'店铺ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-a5abf8bda005> in <module>
# ----> 1 j(data3,[['店铺名称'],['商品实付销售额'],['0'],['店铺ID']],'店铺ID')
#
# <ipython-input-23-7762fece2323> in j(data, columns_l, x)
#      19         for l in columns_l[2]:
#      20             if l == '0' :
# ---> 21                 value = df_only[l].mean()
#      22                 dict_columns[l] = value
#      23         for m in columns_l[3]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
