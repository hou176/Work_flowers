# %%
import pandas as pd 
import numpy as np
import sys
sys.path.append(r'C:\Users\Administrator\Datas\程序冗余\Python_files\pandas_')
from defname  import *
import  matplotlib.pyplot  as plt

# %%
data = pd.read_excel(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/饿了么/饿了么无效门店/1.xlsx')

# %%
data_no = data[data['有效订单'] <=0]

# %%
data_yes = data[data['有效订单'] >0]

# %%
data_no
# Out:
#             供应商ID          供应商名  城市名        门店ID             门店名称  总成交额(元)  \
# 97    22267202676  花非花科技（原邂逅花坊）   广州   304912653  邂逅花坊（知意花坊双山大道店）      0.0
# 102   22267202676  花非花科技（原邂逅花坊）   日照   335794211   邂逅花坊（初暖花艺荣成路店）      0.0
# 103   22267202676  花非花科技（原邂逅花坊）  哈尔滨   300732225    邂逅花坊（鲜花林苑小区店）      0.0
# 104   22267202676  花非花科技（原邂逅花坊）   合肥   167744294       邂逅花坊（翡翠路店）      0.0
# 106   22267202676  花非花科技（原邂逅花坊）   内江   166924951     邂逅花坊（青青园花坊店）      0.0
# ...           ...           ...  ...         ...              ...      ...
# 1062  22267202676  花非花科技（原邂逅花坊）   阜新  2036892629   邂逅花坊（心花怒放建设路店）      0.0
# 1064  22267202676  花非花科技（原邂逅花坊）   东莞   167744260      邂逅花坊（思露花艺店）      0.0
# 1065  22267202676  花非花科技（原邂逅花坊）   天津   167744301   邂逅花坊（永香花店龙顺道店）      0.0
# 1066  22267202676  花非花科技（原邂逅花坊）   淮安   166924912    邂逅花坊（黄河花园小区店）      0.0
# 1067  22267202676  花非花科技（原邂逅花坊）   韶关   167744238  邂逅花坊（花一元花坊新兴路店）      0.0
#
# ...

# %%
data_yes = data_yes.sort_values(by='有效订单',ascending=False)

# %%
data_yes.to_csv('yes.csv')

# %%
data_no.to_csv('no.csv')
