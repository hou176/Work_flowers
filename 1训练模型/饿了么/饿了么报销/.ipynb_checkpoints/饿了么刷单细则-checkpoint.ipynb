# %%
import pandas as pd 
import numpy as np
import sys
sys.path.append(r'C:\Users\Administrator\Datas\程序冗余\Python_files\pandas_')
from defname  import *
import  matplotlib.pyplot  as plt

# %%
df = pd.read_excel(r'C:/Users/Administrator/Desktop/基础素材/DATA/1训练模型/饿了么/饿了么刷单细则/1.xlsx')

# %%
df.dropna(subset='门店ID',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-d4d20447fe64> in <module>
# ----> 1 df.dropna(subset='门店ID',inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4743         if subset is not None:
#    4744             ax = self._get_axis(agg_axis)
# -> 4745             indices = ax.get_indexer_for(subset)
#    4746             check = indices == -1
#    4747             if check.any():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4500         """
#    4501         if self.is_unique:
# -> 4502             return self.get_indexer(target, **kwargs)
#    4503         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4504         return indexer
#
# ...

# %%
df['门店ID'] = df['门店ID'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-13db413690da> in <module>
# ----> 1 df['门店ID'] = df['门店ID'].astype('int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   门店ID    389 non-null    float64
#  1   门店名称    389 non-null    object
#  2   地区      389 non-null    object
#  3   订单编 号   389 non-null    float64
#  4   产品名称    389 non-null    object
#  5   送达日期    389 non-null    datetime64[ns]
#  6   实际支付    389 non-null    float64
#  7   返款金额    389 non-null    float64
#  8   操作人     389 non-null    object
#  9   备注      107 non-null    object
#  10  报销日期    418 non-null    datetime64[ns]
#  11  金额总汇    30 non-null     object
#  12  门店ID.1  0 non-null      float64
# dtypes: datetime64[ns](2), float64(5), object(6)
# memory usage: 42.6+ KB

# %%
df
# Out:
#              门店ID             门店名称   地区         订单编 号                产品名称  \
# 0    2.267088e+09  邂逅花坊（云花阁鲜花正阳路店）  日照市  2.135661e+18            【日常家居鲜花】
# 1    2.267088e+09  邂逅花坊（玫瑰佳人太平西路店）  济宁市  2.135691e+18            【日常家居鲜花】
# 2    2.267088e+09  邂逅花坊（玫瑰佳人太平西路店）  济宁市  2.135692e+18            【日常家居鲜花】
# 3    2.267088e+09  邂逅花坊（玫瑰佳人太平西路店）  济宁市  2.135692e+18           【日常家居鲜花】
# 4    2.267088e+09  邂逅花坊（玫瑰佳人太平西路店）  济宁市  2.135693e+18            【日常家居鲜花】
# ..            ...              ...  ...           ...                 ...
# 413  2.267088e+09   邂逅花坊（cc花坊龙顺街店）  重庆市  5.012816e+18            【日常家居鲜花】
# 414  2.267088e+09   邂逅花坊（cc花坊龙顺街店）  重庆市  5.012819e+18            【日常家居鲜花】
# 415  2.267088e+09   邂逅花坊（cc花坊龙顺街店）  重庆市  5.012959e+18            【日常家居鲜花】
# 416  2.267088e+09   邂逅花坊（cc花坊龙顺街店）  重庆市  5.013162e+18  【日常花】-日常鲜花小花束【自取款】
# 417           NaN              NaN  NaN           NaN                 NaN
#
#                    送达日期  实际支付  返款金额  操作人   备注       报销日期   金额总汇  门店ID.1
# ...

# %%
df.style.background_gradient(cmap='gray_r')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_1b628c76_33a9_11eb_a193_e0d55eb95e65row0_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_1b628c76_33a9_11eb_a193_e0d55eb95e65row0_col3 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_1b628c76_33a9_11eb_a193_e0d55eb95e65row0_col6 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_1b628c76_33a9_11eb_a193_e0d55eb95e65row0_col7 {
#             background-color:  #cfcfcf;
#             color:  #000000;
# ...

# %%
from datetime import datetime, timedelta
import pandas as pd

name = ['Diego', 'Luis', 'Vidal', 'John', 'Yusef']
id = ['b000000005', 'b000000015', 'b000000002', 'b000000011', 'b000000013']
cel = [7878, 6464, 1100, 4545, 1717]
bel = [787, 646454, 110, 45454, 171]
date = pd.to_datetime(['2017-05-31 20:53:00', '2021-05-11 20:53:00', '2017-05-08 20:53:00', 
                       '2017-06-06 20:53:00', '2022-06-06 20:53:00'])

# %%
df = pd.DataFrame({'Name':name,'ID':id,'bel':bel,'Cel':cel,'Date':date})

# %%
df
# Out:
#     Name          ID     bel   Cel                Date
# 0  Diego  b000000005     787  7878 2017-05-31 20:53:00
# 1   Luis  b000000015  646454  6464 2021-05-11 20:53:00
# 2  Vidal  b000000002     110  1100 2017-05-08 20:53:00
# 3   John  b000000011   45454  4545 2017-06-06 20:53:00
# 4  Yusef  b000000013     171  1717 2022-06-06 20:53:00

# %%
df.style.applymap(lambda bel: 'background-color: %s' %'#FFCCFF' if bel>df.bel
                             else'background-color: %s'% '')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     180         Hooks into Jupyter notebook rich display system.
#     181         """
# --> 182         return self.render()
#     183
#     184     @Appender(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     535         * table_attributes
#     536         """
# --> 537         self._compute()
#     538         # TODO: namespace all the pandas keys
# ...

# %%
def color(val):
    if val[1] <val[0] :
        color = 'green'
    elif val[1] > val[0]:
        color = 'yellow'
    return 'background-color: %s' % color

df.style.applymap(color, subset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     180         Hooks into Jupyter notebook rich display system.
#     181         """
# --> 182         return self.render()
#     183
#     184     @Appender(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     535         * table_attributes
#     536         """
# --> 537         self._compute()
#     538         # TODO: namespace all the pandas keys
# ...

# %%
def low_red(s):
    color = 'red'  if s >= 0 else  'black'
    return  f"color:{color}"

# %%
columns = [['A', 'A', 'B', 'B', 'C']]
# 创建形状为（10，5） 的DataFrame 并设置二级标题
demo_df = pd.DataFrame(np.arange(50).reshape(10, 5), columns=columns)
print(demo_df)
# Out:
#     A   A   B   B   C
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# 5  25  26  27  28  29
# 6  30  31  32  33  34
# 7  35  36  37  38  39
# 8  40  41  42  43  44
# 9  45  46  47  48  49

# %%
demo_df = demo_df[['A','B']]
for index, row in demo_df.iterrows():
    a = row[0]
    b = row[1]
    x = demo_df.iloc[0:1,]
    if a > b:
        demo_df.style.applymap(low_red,subset=['A'])
    else:
        x = x.style.applymap(low_red,subset=['B'])
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-2746d12775af> in <module>
#       7         demo_df.style.applymap(low_red,subset=['A'])
#       8     else:
# ----> 9         x = x.style.applymap(low_red,subset=['B'])
#      10     break
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in style(self)
#     836         from pandas.io.formats.style import Styler
#     837
# --> 838         return Styler(self)
#     839
#     840     _shared_docs[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in __init__(self, data, precision, table_styles, uuid, caption, table_attributes, cell_ids, na_rep)
#     143             data = data.to_frame()
#     144         if not data.index.is_unique or not data.columns.is_unique:
# --> 145             raise ValueError("style is not supported for non-unique indices.")
#     146
# ...

# %%
columns = [['A', 'A', 'B', 'B', 'C'], ['a', 'b', 'c', 'd', 'e']]
# 创建形状为（10，5） 的DataFrame 并设置二级标题
demo_df = pd.DataFrame(np.arange(50).reshape(10, 5), columns=columns)
print(demo_df)
 
 
def style_color(df, colors):
    """
    
    :param df: pd.DataFrame
    :param colors: 字典  内容是 {标题:颜色}
    :return: 
    """
    return df.style.apply(style_apply, colors=colors)
    
def style_apply(series, colors, back_ground=''):
    """
    :param series: 传过来的数据是DataFramt中的一列   类型为pd.Series
    :param colors: 内容是字典  其中key 为标题名   value 为颜色
    :param back_ground: 北京颜色
    :return:
    """
    series_name = series.A[0]
    a = list()
    # 为了给每一个单元格上色
    for col in series:
        # 其中 col 为pd.DataFrame 中的 一个小单元格   大家可以根据不同需求为单元格设置不同的颜色
        # 获取什么一级标题获取什么颜色
        if series_name in colors:
            print(series_name)
            for title_name in colors:
                print(title_name)
                if title_name == series_name:
                    back_ground = 'background-color: ' + colors[title_name]
                    # '; border-left-color: #080808'
        a.append(back_ground)
        print(a)
    return a
 
 
style_df = style_color(demo_df, colors = {"A": 'blue', "B": 'red', "C": 'green'})
style_df
# Out:
#     A       B       C
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# 5  25  26  27  28  29
# 6  30  31  32  33  34
# 7  35  36  37  38  39
# 8  40  41  42  43  44
# 9  45  46  47  48  49
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     180         Hooks into Jupyter notebook rich display system.
#     181         """
# --> 182         return self.render()
#     183
# ...

# %%
a = style_apply(demo_df['A'], {"A": 'blue', "B": 'red', "C": 'green'},back_ground='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-962200c2eb14> in <module>
# ----> 1 a = style_apply(demo_df['A'], {"A": 'blue', "B": 'red', "C": 'green'},back_ground='')
#
# <ipython-input-199-0ed6d825edc1> in style_apply(series, colors, back_ground)
#      21     :return:
#      22     """
# ---> 23     series_name = series.A[0]
#      24     a = list()
#      25     # 为了给每一个单元格上色
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'A'

# %%
 
with pd.ExcelWriter('df_style.xlsx', engine='openpyxl') as writer:
    #注意： 二级标题的to_excel index 不能为False
    
    style_df.to_excel(writer, sheet_name='sheet_name')
