# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code,sheet_name= i )
    return data

# %%
def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    for i in range(len(list_)):
        b = list_[i]
        x = type(b)
        c = str(x)
        if  c =="<class 'int'>":
            sum_ = data[data[a] == b ]['门店ID'].count()
            dict_ = {}
            hah = data[data[a] == b ]['门店名称']
            hah = list(hah)
            hah = hah[0]
            if sum_ > 1 :
                dict_ = {hah:sum_}
                list_sum.append(dict_)
            else:
                dict_ = {hah:sum_}
                list_sum_.append(dict_)
            i = i + 1  
            b = str(b)
        else:
            sum_ = data[data[a] == b ]['门店ID'].count()

            dict_ = {}
            hah = data[data[a] == b ]['门店名称']
            hah = list(hah)
            hah = hah[0]
            if sum_ > 1 :
                dict_ = {b:sum_}
                list_sum.append(dict_)
            else:
                dict_ = {hah:sum_}
                list_sum_.append(dict_)
            i = i + 1  

    k = [list_sum,list_sum_]
    return k

def shaixuan(data,a,b,c):
    data = data[data[a] == b]
    df = data.drop_duplicates(subset=c,inplace=False,keep = 'last')
    list_ = list(df[c])
    list_sum = []
    list_sum_ = []
    for i in range(len(list_)):
        j = list_[i]
        sum_ = data[data[c] == j ]['门店ID'].count()
        dict_ = {}
        if sum_ > 1 :
            dict_ = {j:sum_}
            list_sum.append(dict_)
        else:
            dict_ = {j:sum_}
            list_sum_.append(dict_)
        i = i + 1 
    k = [list_sum,list_sum_]
    return k

# %%
lujing = r'C:/Users/Administrator/Datas/训练数据/问题订单/邂逅问题订单/2.xlsx'
code = 'gbk'
i = '3'
df = improt_data(lujing,code)

# %%
df
# Out:
#             日期     门店ID           门店名称  所属分账号 运营姓名               订单编号  \
# 0   2020-06-08  7429071    邂逅花坊鲜花（花艺轩）    NaN  NaN  74290710916241504
# 1   2020-06-06  7545314  邂逅花坊鲜花（花之语花卉）    NaN  NaN  75453143987531733
# 2   2020-06-06  8980725   邂逅花坊鲜花（初见花艺）    NaN  NaN  89807253419291169
# 3   2020-06-06  5539307   邂逅花坊鲜花（紫藤花艺）    NaN  NaN  55393071196321319
# 4   2020-06-05  5252928    邂逅花坊鲜花（花果园）    NaN  NaN  52529284040801325
# ..         ...      ...            ...    ...  ...                ...
# 109 2020-07-29  8981643        花语世界鲜花店    7.0  杨婉格  89816431914115905
# 110 2020-07-30  9417680          绿之缘花卉    8.0  冯宸阳  94176803859415939
# 111 2020-07-30  7392785  邂逅花坊鲜花（花之缘花艺）    4.0  王林林  73927852556232875
# 112 2020-07-30  5539307   邂逅花坊鲜花（紫藤花艺）    7.0  杨婉格  55393072556232875
# 113 2020-07-31  5631601  邂逅花坊鲜花（花之语鲜花）    6.0  张家僮  56316011211609187
#
#                     产品名称                下单时间                退单时间    退单主体  \
# 0                    NaN 2020-06-08 00:15:00 2020-06-08 00:15:00    顾客申请
# 1                    NaN 2020-06-06 21:22:00 2020-06-06 21:27:00    商家退单
# 2                    NaN 2020-06-06 16:21:00 2020-06-06 17:25:00    商家退款
# 3                    NaN 2020-05-10 08:14:00 2020-05-10 08:14:00    平台退款
# 4                    NaN 2020-05-20 12:23:00 2020-06-05 13:59:00    平台退款
# ..                   ...                 ...                 ...     ...
# 109   美轮美奂【9枝粉玫瑰满天星鲜花花束】 2020-07-29 14:11:00 2020-07-29 19:51:00  商家取消订单
# 110       简约小花束【下单请到店自取】 2020-07-29 21:46:00 2020-07-30 08:39:00  商家取消订单
# 111  梦醒之初【11枝红玫瑰搭配尤加利礼盒】 2020-07-30 19:38:00 2020-07-30 20:00:00  商家取消订单
# 112   爱的细语【11枝红玫瑰表白鲜花花束】 2020-07-30 16:55:00 2020-07-30 18:10:00  商家取消订单
# 113         大吉大利【单个开业花篮】 2020-07-31 10:13:00 2020-07-31 10:43:00  商家取消订单
#
#                          原因主体    退单理由  备注  记录人
# 0                  订单取消时，自动退款   店铺已打烊 NaN  张鑫蕊
# 1                        商家没货    商家同意 NaN  郭一心
# 2                        商家没货    商家退款 NaN  赵贺贤
# 3                邂逅花坊鲜花（紫藤花艺）     NaN NaN  魏宝珍
# 4    520订单顾客退单平台客服当时没解决6.5退款了     NaN NaN   苑云
# ..                        ...     ...  ..  ...
# 109                订单取消时，自动退款   商品已售完 NaN   孟飞
# 110                订单取消时，自动退款  联系不上用户 NaN   王悦
# 111                订单取消时，自动退款    重复订单 NaN   孟飞
# 112                订单取消时，自动退款   客户说好丑 NaN   孟飞
# 113                订单取消时，自动退款  商家取消订单 NaN   孟飞
#
# [114 rows x 14 columns]

# %% [markdown]
# ## 退单一级分类

# %%
drop_du(df,'退单主体')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-0a2cda188aae> in <module>
# ----> 1 drop_du(df,'退单主体')
#
# <ipython-input-3-9251f29e450c> in drop_du(data, a)
#      28             hah = data[data[a] == b ]['门店名称']
#      29             hah = list(hah)
# ---> 30             hah = hah[0]
#      31             if sum_ > 1 :
#      32                 dict_ = {b:sum_}
#
# IndexError: list index out of range

# %% [markdown]
# ## 退单二级分类

# %%
x = shaixuan(df,'退单类型','商家拒单','退单理由')
x
# Out:
# [[{'没时间': 2},
#   {'订单取消时，自动退款': 4},
#   {'今天没有香槟 有粉玫瑰': 2},
#   {'商家取消订单': 2},
#   {'店铺太忙': 6},
#   {'商品已售完': 57},
#   {'地址无法配送': 9},
#   {'店铺已打烊': 63}],
#  [{'送达地点离我店太远。': 1},
#   {'商家拒单': 1},
#   {'今天有事回乡下了，无法配送，请谅解哦！': 1},
#   {'配送员取货慢': 1},
#   {'今天康乃馨没货': 1},
#   {'快递还没联系好': 1},
#   {'红玫瑰已售完': 1},
#   {'需到店购买此款不配送': 1}]]

# %%
x = shaixuan(df4,'退单理由','店铺已打烊','门店名称')
x
# Out:
# [[{'漫艺花坊': 2},
#   {'邂逅花坊鲜花（缘庆花艺）': 2},
#   {'天天鲜花泉州店': 2},
#   {'邂逅花坊鲜花（那一朵花店)': 5},
#   {'邂逅花坊鲜花（勿忘我鲜花店）': 2},
#   {'邂逅花坊鲜花（爱神罗兰）': 2},
#   {'邂逅花坊鲜花（真情花艺）': 4},
#   {'邂逅花坊鲜花（花艺轩）': 3}],
#  [{'邂逅花坊鲜花（蝶恋花）': 1},
#   {'城市花坊': 1},
#   {'邂逅花坊鲜花（绮彩花果坊）': 1},
#   {'邂逅花坊鲜花（华苑鲜花）': 1},
#   {'邂逅花坊鲜花（花韵千谷)': 1},
#   {'邂逅花坊鲜花（馨灵花坊）': 1},
#   {'邂逅花坊鲜花（喜来鲜花得庆典）': 1},
#   {'邂逅花坊鲜花（花之美花艺设计）': 1},
#   {'欢欢花艺坊': 1},
#   {'邂逅花坊鲜花（喵姐花艺)': 1},
#   {'邂逅花坊鲜花（花雨轩花艺）': 1},
#   {'邂逅花坊鲜花(湖心花店）': 1},
#   {'邂逅花坊鲜花（洪庙店）': 1},
#   {'邂逅花坊鲜花（遇见花店）': 1},
#   {'邂逅花坊鲜花（爱慕花艺）': 1},
#   {'邂逅花坊鲜花（花唯媒）': 1},
#   {'邂逅花坊鲜花（新世纪花艺）': 1},
#   {'邂逅花坊鲜花（莫妮卡花艺）': 1},
#   {'花说花店': 1},
#   {'花东家': 1},
#   {'邂逅花坊鲜花（江楠花艺）': 1},
#   {'邂逅花坊鲜花（花仟朵花艺）': 1},
#   {'《花仙子》麒龙花坊': 1},
#   {'邂逅花坊鲜花（鱼小姐）': 1},
#   {'邂逅花坊鲜花（洋洋花之语鲜花）': 1},
#   {'邂逅花坊鲜花（欢庆鲜花店）': 1},
#   {'邂逅花坊鲜花（夏天植物鲜花）': 1},
#   {'鲜花·婚礼定制': 1},
#   {'邂逅花坊鲜花（蕾蕾花店）': 1},
#   {'缘来友花(生日、表白、鲜花店)': 1},
#   {'邂逅花坊鲜花（繁花里）': 1},
#   {'邂逅花坊鲜花（向晴花艺）': 1},
#   {'邂逅花坊鲜花（博艺花卉）': 1},
#   {' 邂逅花坊鲜花（园艺花卉': 1},
#   {' 邂逅花坊鲜花（玫瑰花屋）': 1},
#   {' 邂逅花坊鲜花（情人岛花店）': 1},
#   {' 邂逅花坊鲜花（新世纪花艺': 1},
#   {' 邂逅花坊鲜花（花韵千谷)': 1},
#   {'邂逅花坊鲜花(佳缘花艺）': 1},
#   {' 邂逅花坊鲜花（花艺轩）': 1},
#   {' 浪漫花都': 1}]]

# %%
x = shaixuan(df4,'退单理由','商品已售完','门店名称')
x
# Out:
# [[{'邂逅花坊鲜花（勿忘我鲜花店）': 2},
#   {'邂逅花坊鲜花（时尚花坊）': 2},
#   {'邂逅花坊鲜花（蕾蕾花店）': 4},
#   {'邂逅花坊鲜花（花芊岛花店）': 2},
#   {'邂逅花坊鲜花（先花店）': 2},
#   {'邂逅花坊鲜花（尚品花艺）': 3},
#   {'夜郎花卉': 2},
#   {'邂逅花坊鲜花（浪漫花店）': 2},
#   {'欢欢花艺坊': 2},
#   {' 邂逅花坊鲜花（绿之源花卉坊）': 2},
#   {'邂逅花坊鲜花（木闺香枝鲜花）': 2}],
#  [{'邂逅花坊鲜花（心语鲜花）': 1},
#   {'美丽心情鲜花店': 1},
#   {'邂逅花坊鲜花(幸福花坊）': 1},
#   {'邂逅花坊鲜花（江楠花艺）': 1},
#   {'邂逅花坊鲜花（缤纷花坊）': 1},
#   {'邂逅花坊鲜花（邂逅花开）': 1},
#   {'邂逅花坊鲜花（花颜巧雨鲜花）': 1},
#   {'邂逅花坊鲜花（Ainoflowery）': 1},
#   {'浪漫谷花卉': 1},
#   {'邂逅花坊鲜花（金百合鲜花）': 1},
#   {'邂逅花坊鲜花(有傢花店）': 1},
#   {'邂逅花坊鲜花(芳之红花艺）': 1},
#   {'樱木花都': 1},
#   {'邂逅花坊鲜花（雅艺花坊）': 1},
#   {'邂逅花坊鲜花（花木美花店）': 1},
#   {'邂逅花坊鲜花（灵感鲜花坊）': 1},
#   {'邂逅花坊鲜花（满天星鲜花）': 1},
#   {'邂逅花坊鲜花（娜时花开）': 1},
#   {'\xa0欢欢花艺坊': 1},
#   {'花好月圆': 1},
#   {'美丽心情鲜花超市': 1},
#   {' 鑫情梦缘花艺': 1},
#   {' 花韵花店（漪汾街店）': 1},
#   {' 羽沫花艺': 1},
#   {'邂逅花坊鲜花（那一朵花店)': 1},
#   {'邂逅花坊鲜花（琪琪花店）': 1},
#   {' 邂逅花坊鲜花（爱慕花艺）': 1},
#   {'《花仙子》麒龙花坊': 1},
#   {' 邂逅花坊鲜花（幸福花圃鲜花婚庆）': 1},
#   {'邂逅花坊鲜花（一花一世界）': 1},
#   {'邂逅花坊鲜花（绿之源花卉坊）': 1},
#   {'邂逅花坊鲜花（乖乖兽花店）': 1}]]

# %%
x = shaixuan(df4,'退单理由','地址无法配送','门店名称')
x
# Out:
# [[],
#  [{'邂逅花坊鲜花（晨曦绿植鲜花）': 1},
#   {'邂逅花坊鲜花（普罗旺斯婚庆）': 1},
#   {'情和缘鲜花': 1},
#   {'缘来友花(生日、表白、鲜花店)': 1},
#   {'邂逅花坊鲜花（雪儿婚庆鲜花坊）': 1},
#   {'邂逅花坊鲜花（永香花店）': 1},
#   {'邂逅花坊鲜花（花样年华）': 1},
#   {'邂逅花坊鲜花（牵手花店）': 1},
#   {'邂逅花坊鲜花（同心鲜花店）': 1}]]

# %%
x = shaixuan(df4,'退单理由','店铺太忙','门店名称')
x
# Out:
# [[],
#  [{'景园花艺': 1},
#   {'天天鲜花泉州店': 1},
#   {'邂逅花坊鲜花（俪缘花千谷）': 1},
#   {'邂逅花坊鲜花（爱花居梅香鲜花）': 1},
#   {'惜缘花业(生日鲜花,玫瑰花,鲜花店)': 1},
#   {'邂逅花坊鲜花（喜洋洋鲜花店）': 1}]]

# %%
x = shaixuan(df4,'退单理由','没时间','门店名称')
x
# Out:
# [[], [{'邂逅花坊鲜花（心颖花艺）': 1}, {'情窦初开': 1}]]
