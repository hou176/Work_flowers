# %%
import  pandas as pd 
import numpy as np
from sklearn.cluster  import KMeans
import matplotlib.pyplot  as plt
from sklearn.preprocessing import scale
from sklearn import cluster
pd.set_option('display.max_columns',None)

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code,sheet_name= i )
    return data

# %%
lujing = r'C:\Users\Administrator\datas\训练数据\问题订单\八月邂逅问题订单/2.xlsx'
code = 'gbk'
i = '超市未接单'
df = improt_data(lujing,code)

# %%
def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    data[a] = (data[a])
    list_sum = []
    for i in range(len(list_)):
        print(list_[i])
        b = list_[i]
        x = type(b)
        c = str(x)
        if  c =="<class 'int'>":
            sum_ = data[data[a] == b ]['门店ID'].count()
            print(sum_)
            dict_ = {}
            hah = data[data[a] == b ]['门店名称']
            hah = list(hah)
            hah = hah[0]
            if sum_ > 1 :
                dict_ = {hah:sum_}
                list_sum.append(dict_)
            i = i + 1  
            b = str(b)
            print('-' *len(b) )
        else:
            sum_ = data[data[a] == b ]['门店ID'].count()
            print(sum_)
#             dict_ = {}
#             if sum_ > 1 :
#                 dict_ = {b:sum_}
#                 list_sum.append(dict_)
#             i = i + 1  
#             print('--' *len(b) )
    return list_sum

def shaixuan(data,a,b,c):
    data = data[data[a] == b]
    df = data.drop_duplicates(subset=c,inplace=False,keep = 'last')
    list_ = list(df[c])
    list_sum = []
    list_sum_ = []
    for i in range(len(list_)):
        j = list_[i]
        sum_ = data[data[c] == j ]['门店ID'].count()
        dict_ = {}
        if sum_ > 1 :
            dict_ = {j:sum_}
            list_sum.append(dict_)
        else:
            dict_ = {j:sum_}
            list_sum_.append(dict_)
        i = i + 1 
    k = [list_sum,'-------------------------',list_sum_]
    return k

# %%
df
# Out:
#            日期     门店ID                 门店名称  所属分账号   运营姓名               订单编号  \
# 0  2020-08-01  8457223         邂逅花坊鲜花（紫馨花坊）    2.0    刘春思  84572231211609187
# 1  2020-08-03  6379426      邂逅花坊鲜花（爱花居时尚花店）    6.0    张家僮  63794260633483736
# 2  2020-08-03  5921835        邂逅花坊鲜花（花语鲜花店）    7.0    杨婉格  59218350431920409
# 3  2020-08-03  5568390         邂逅花坊鲜花（阳光花圃）    4.0    王林林  55683902319659458
# 4  2020-08-03  5718179       邂逅花坊鲜花（世缘鲜花婚庆）    2.0    刘春思  57181790431920409
# 5  2020-08-04  5539319         邂逅花坊鲜花（枫铃花卉）    1.0    孟金雨  55393193601647601
# 6  2020-08-04  2149848      邂逅花坊鲜花（花样年华河西店）    2.0    刘春思  21498483521940139
# 7  2020-08-05  5539553       邂逅花坊鲜花（喜洋洋鲜花店）    4.0    王林林  55395533601647601
# 8  2020-08-05  5108788        邂逅花坊鲜花（鑫芳馨花店）    9.0     张圆  51087883601647601
00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 16 2020-08-10 23:11:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 17 2020-08-10 23:34:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 18 2020-08-10 23:00:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 19 2020-08-11 18:41:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 20 2020-08-11 23:56:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 21 2020-08-12 00:34:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 22 2020-08-14 21:59:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 23 2020-08-15 22:38:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 24 2020-08-17 19:52:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 25 2020-08-18 07:09:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 26 2020-08-18 19:57:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 27 2020-08-19 10:09:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 28 2020-08-20 06:15:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
# 29 2020-08-20 22:15:00  商家超时未接单  订单取消自动确认退款  订单取消时，自动退款  系统自动通过退款
#
#                  原因主体  备注  记录人
# 0   开始营业15分钟后未及时处理预订单 NaN   王悦
# 1   开始营业15分钟后未及时处理预订单 NaN   王悦
# 2   开始营业15分钟后未及时处理预订单 NaN   王悦
# 3   开始营业15分钟后未及时处理预订单 NaN   王悦
# 4      下单超时未确认，系统自动取消 NaN   王悦
# 5   开始营业15分钟后未及时处理预订单 NaN   王悦
# 6      下单超时未确认，系统自动取消 NaN   王悦
# 7      下单超时未确认，系统自动取消 NaN   王悦
# 8      下单超时未确认，系统自动取消 NaN   王悦
# 9      下单超时未确认，系统自动取消 NaN   王悦
# 10     下单超时未确认，系统自动取消 NaN   王悦
# 11     下单超时未确认，系统自动取消 NaN  安梦迪
# 12  开始营业15分钟后未及时处理预订单 NaN  刘佳惠
# 13     下单超时未确认，系统自动取消 NaN  刘佳惠
# 14     下单超时未确认，系统自动取消 NaN  安梦迪
# 15     下单超时未确认，系统自动取消 NaN  安梦迪
# 16     下单超时未确认，系统自动取消 NaN  安梦迪
# 17  开始营业15分钟后未及时处理预订单 NaN  安梦迪
# 18  开始营业15分钟后未及时处理预订单 NaN  安梦迪
# 19  开始营业15分钟后未及时处理预订单 NaN  安梦迪
# 20     下单超时未确认，系统自动取消 NaN  刘佳惠
# 21     下单超时未确认，系统自动取消 NaN  刘佳惠
# 22     下单超时未确认，系统自动取消 NaN   孟飞
# 23     下单超时未确认，系统自动取消 NaN  刘佳惠
# 24     下单超时未确认，系统自动取消 NaN   王悦
# 25   开始营业5分钟后未及时处理预订单 NaN   王悦
# 26  开始营业15分钟后未及时处理预订单 NaN   王悦
# 27     下单超时未确认，系统自动取消 NaN   王悦
# 28  开始营业15分钟后未及时处理预订单 NaN   王悦
# 29  开始营业15分钟后未及时处理预订单 NaN  刘佳惠

# %%
drop_du(df,'退单主体')
# Out:
# 商家超时未接单
# 30
# []

# %%
drop_du(df,'退单理由')
# Out:
# 订单取消时，自动退款
# 30
# []

# %%
drop_du(df,'原因主体')
# Out:
# 开始营业5分钟后未及时处理预订单
# 1
# 下单超时未确认，系统自动取消
# 17
# 开始营业15分钟后未及时处理预订单
# 12
# []

# %%
drop_du(df,'退款提示')
# Out:
# 订单取消自动确认退款
# 30
# []

# %%
drop_du(df,'退款情况')
# Out:
# 系统自动通过退款
# 30
# []
