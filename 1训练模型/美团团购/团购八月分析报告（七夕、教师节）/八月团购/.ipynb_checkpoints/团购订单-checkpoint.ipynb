# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns',None)
from sklearn.feature_extraction.text import CountVectorizer
import jieba # 导入关键字提取库
import pandas as pd  # 导入pandas
# import newspaper

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code)
    return data

def wenzi(data,z,a):
    list_2 = []
    list_3 = []
    lis = []
    
    for row,data_ in data.iterrows():
        name = data_['订单号']
        list_3.append(name)
        y = data_[a]
        tr = y.find(z)
        if tr > -1 :
            list_2.append(y)
    print('关于' + '“' + z + '”' + '的订单数量是：',len(list_2))  
    lis.append(list_2)
    lis.append(list_3)
    return lis

def jiebe(data):    
    text_list = []
    for line in data:
        hou = ",".join(jieba.cut(line))
        strlist = hou.split(',') 
        text_list.append(strlist)
    return text_list

def clean(list_name_,stopwords_):    
    clean_line = []
    for line in list_name_:
        haha = []
        for word in line:
            if word in stopwords_:
                continue
            haha.append(word)
        haha = ','.join(haha)
        clean_line.append(haha)

    return clean_line

def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['订单号'].count()
        dict_ = {}
    
        if sum_ > 1 :
            list__.append(b)
            dict_ = {b:sum_}
            list_sum.append(dict_)
        else:
            list__.append(b)
            dict_ = {b:sum_}
            list_sum_.append(dict_)
        i = i + 1  
    k = [list_sum,list_sum_,list__]
    return k

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/八月团购/销售额.xls'
code = 'utf8'
df = improt_data(lujing,code)

# %%
df
# Out:
#               日期 商品类型       商品id             商品名称  商品售卖量  商品售卖金额  曝光人数  访问人数
# 0     2020-08-01   团购   35804226  【约会爆款】11枝玫瑰礼盒套餐      0     0.0   632    39
# 1     2020-08-01   团购   35818597  【约会推荐】11枝玫瑰爆款花束      0     0.0    98    12
# 2     2020-08-01   团购   35818693  【邂逅爱情】11枝玫瑰表白花束      0     0.0   133    31
# 3     2020-08-01   团购   35825487  【网红爆款】康乃馨百合混搭花束      0     0.0   178    22
# 4     2020-08-01   团购   35825649  【感恩玫瑰】向日葵玫瑰鲜花花束      0     0.0    17    14
# ...          ...  ...        ...              ...    ...     ...   ...   ...
# 1750  2020-08-31   团购   36201323    【散步斜阳】33枝手提花篮      0     0.0     3     0
# 1751  2020-08-31   团购   36396949  【开业大麦】大麦开业花篮 单个      0     0.0    18     7
# 1752  2020-08-31   团购   36397724   大吉大利-单层开业花篮 单个      0     0.0     6     0
# 1753  2020-08-31   团购  611934392  【一心一意】11枝玫瑰表白礼盒      0     0.0     4     2
# 1754  2020-08-31   团购  619925255    【一见钟情】满天星表白花束      0     0.0    10     5
#
# [1755 rows x 8 columns]

# %%
df = df[df['商品售卖金额'] > 0]
df = df[df['商品售卖量'] >1]
df['商品售卖金额'].sum()
# Out:
# 4100.0

# %%
name = df.drop_duplicates(subset='商品名称',inplace=False)
name = list(name['商品名称'])
for i in name :
    a = df[df['商品名称'] == i]
    x = a['商品售卖量'].sum()
    y = a['商品售卖金额'].sum()
    print(i)
    print(x)
    print(y)
    print('----------------')
# Out:
# 【到店自取】单只向日葵
# 42
# 1176.0
# ----------------
# 单层开业花篮一对
# 2
# 176.0
# ----------------
# 【满心欢喜】19枝玫瑰鲜花花束
# 6
# 974.0
# ----------------
# 【生如夏花】向日葵玫瑰韩式花束
# 2
# 218.0
# ----------------
# 【美轮美奂】9支玫瑰鲜花花束
# 2
# 138.0
# ----------------
# 【宛若清风】99枝玫瑰求婚花束
# 2
# 1418.0
# ----------------

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/团购成交订单.xls'
code = 'utf8'
df = improt_data(lujing,code)

# %%
df
# Out:
#      下单城市                       订单号                 下单时间            下单门店  \
# 0      白山  159877862240350210288259  2020-08-30 17:10:22    邂逅花坊鲜花(青青花行)
# 1      唐山  159868977841338240134132  2020-08-29 16:29:38         印象IOO鲜花
# 2      唐山  159875091288992940956611  2020-08-30 09:28:32         印象IOO鲜花
# 3      唐山  159879061400843650981903  2020-08-30 20:30:14  邂逅花坊鲜花(枫荷鲜花庆典)
# 4     长垣市  159858512956635280188597  2020-08-28 11:25:29    邂逅花坊鲜花(千艺鲜花)
# ...   ...                       ...                  ...             ...
# 1835   北京  159628042706548640461640  2020-08-01 19:13:47    邂逅花坊鲜花(雪莲花艺)
# 1836  舒城县  159625734604815560946023  2020-08-01 12:49:06   邂逅花坊鲜花(馨馨花艺店)
# 1837  蓝田县  159628347440959280397659  2020-08-01 20:04:34    邂逅花坊鲜花(七彩鲜花)
# 1838  南康区  159626153782112950500073  2020-08-01 13:58:57    邂逅花坊鲜花(遇见花坊)
# 1839  兖州区  159624970600518440995214  2020-08-01 10:41:46    邂逅花坊鲜花(百合花艺)
#
#                  商品名称  商品规格  商品总数  商品总额   实收金额  优惠金额 订单状态  配送方式 商家备注  \
# 0      【美轮美奂】9支玫瑰鲜花花束   NaN     1    78   78.0   0.0  已完成  商家配送  NaN
# 1      【美轮美奂】9支玫瑰鲜花花束   NaN     1    78   78.0   0.0  已完成  商家配送  NaN
# 2     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  到店自取  NaN
# 3     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  商家配送  NaN
# 4     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  商家配送  NaN
# ...               ...   ...   ...   ...    ...   ...  ...   ...  ...
# 1835  【感恩玫瑰】向日葵玫瑰鲜花花束   NaN     1   149  149.0   0.0  已完成  到店自取  NaN
# 1836  【佳人才子】11枝玫瑰鲜花花束   NaN     1    89   89.0   0.0  已完成  商家配送  NaN
# 1837  【夕颜若雪】11枝康乃馨鲜花束   NaN     1    79   79.0   0.0  已完成  商家配送  NaN
# 1838  【如花似玉】33枝玫瑰百合花束   NaN     1   189  189.0   0.0  已完成  商家配送  NaN
# 1839  【佳人才子】11枝玫瑰鲜花花束   NaN     1    89   89.0   0.0  已完成  商家配送  NaN
#
#                                                    配送地址 收货人/订货人    收货人/订货人电话  \
# 0     吉林省白山市浑江区通江路122号农业招待所(通江路)农业农村局通江路122号  138439...     徐志刚  13843913300
# 1                         河北省唐山市路北区建华西道2-13号甬妈妈(一号店)唐山市       刘  13752760199
# 2                                                   NaN     NaN  18331863302
# 3                           河北省唐山市古冶区新光路4号龙江瑞景北门底商济仁堂门诊     王司洋  13931496469
# 4     河南省新乡市长垣市河南省新乡市长垣市蒲西街道会友路与宏力大道交叉口西南50米长垣市水利局到门...       郭  18503874093
# ...                                                 ...     ...          ...
# 1835                                                NaN     NaN  15810368810
# 1836                      安徽省六安市舒城县合安路广进久富商业广场3号楼安丰皇家宾馆      高云  15862517146
# 1837                            陕西省西安市蓝田县北环路西段20号开诚酒店大厅       许  15229268628
# 1838               江西省赣州市南康区南水大道南150米顶呱呱托管中心到了顶呱呱幼儿园打电话     杜平英  15170194577
# 1839                    山东省济宁市兖州区飞龙街33号附近龙桥二区8号楼三单元三楼西户      高露  13954702688
#
#       快递单号
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 1835   NaN
# 1836   NaN
# 1837   NaN
# 1838   NaN
# 1839   NaN
#
# [1840 rows x 17 columns]

# %%
df['下单时间'] = pd.to_datetime(df['下单时间'],format='%Y-%m-%d %H:%M:%S')

# %%
df['day'] = df['下单时间'].dt.day

# %%
df_ = df[(df['day'] != 24)  & (df['day'] != 25)]

# %%
df_.to_excel('八月成交订单.xl')

# %%
drop_du(df_,'商品名称')
# Out:
# [[{'【一世爱人】33枝玫瑰鲜花礼盒': 2},
#   {'【百年好合】多头百合鲜花花束': 8},
#   {'【盛夏光年】33枝玫瑰花束套餐': 6},
#   {'【开业大麦】大麦开业花篮 一对': 4},
#   {'【一生爱你】11枝玫瑰百合花束': 3},
#   {'【一生所爱】19枝玫瑰表白礼盒': 13},
#   {'【相思】19枝白粉混搭玫瑰手提花篮': 3},
#   {'单层开业花篮一对': 3},
#   {'【心若向阳】33枝韩式皇冠花束': 10},
#   {'【一心一意】11枝玫瑰表白礼盒': 16},
#   {'【如花美眷】11枝玫瑰鲜花礼盒': 19},
#   {'【砰然心动】爆款表白玫瑰礼盒': 3},
#   {'【午后阳光】康乃馨混搭女王抱抱桶': 7},
#   {'【一见钟情】满天星表白花束': 23},
#   {'【开业大吉】生意大麦花束': 16},
#   {'【网红爆款】康乃馨百合混搭花束': 17},
#   {'【微微一笑】11枝玫瑰表白花束': 26},
#   {'到店自取送老师单枝向日葵': 19},
#   {'【默默的爱】33枝玫瑰韩式花束': 24},
#   {'【半夏倾心】52枝玫瑰女神花束': 6},
#   {' 【满心欢喜】19枝玫瑰鲜花花束': 23},
#   {'【送老师】到店自取康乃馨鲜花花束': 9},
#   {'【刻满关怀】19支玫瑰鲜花礼盒': 4},
#   {'【送老师】向日葵鲜花花束': 4},
#   {'【钟爱一生】11支玫瑰鲜花花束': 3},
#   {'【送老师】到店自取小花束单个': 14},
#   {'【春水盈盈】21枝玫瑰鲜花花束': 13},
#   {'【天缘巧合】33枝玫瑰鲜花花束': 52},
#   {'【手捧星河】简约小花束': 8},
#   {'【恩情似海】玫瑰康乃馨混搭礼盒': 9},
#   {'【美轮美奂】9支玫瑰鲜花花束': 68},
#   {'【生如夏花】向日葵玫瑰韩式花束': 97},
#   {'【琴瑟之好】11枝玫瑰女王花束': 9},
#   {'【致女王】99枝玫瑰表白鲜花花束': 16},
#   {' 【约会爆款】11枝玫瑰礼盒套餐': 93},
#   {'到店自取-单枝向日葵': 152},
#   {'【送老师】6枝向日葵韩式鲜花': 10},
#   {'【感恩玫瑰】向日葵玫瑰鲜花花束': 35},
#   {'【夕颜若雪】11枝康乃馨鲜花束': 46},
#   {'【如花似玉】33枝玫瑰百合花束': 11},
#   {'【佳人才子】11枝玫瑰鲜花花束': 49}],
#  [{'【蒸蒸日上】双层开业花篮 单个': 1},
#   {'【微光倾城】33枝红玫瑰鲜花抱抱桶': 1},
#   {'【大吉大利】单层开业花篮 单个': 1},
#   {'开业花篮-一对三脚架': 1},
#   {'一世爱人-11枝玫瑰百合花束': 1},
#   {'【宛若清风】99枝玫瑰求婚花束': 1}],
#  ['【蒸蒸日上】双层开业花篮 单个',
#   '【一世爱人】33枝玫瑰鲜花礼盒',
#   '【微光倾城】33枝红玫瑰鲜花抱抱桶',
#   '【大吉大利】单层开业花篮 单个',
#   '【百年好合】多头百合鲜花花束',
#   '开业花篮-一对三脚架',
#   '【盛夏光年】33枝玫瑰花束套餐',
#   '【开业大麦】大麦开业花篮 一对',
#   '【一生爱你】11枝玫瑰百合花束',
#   '【一生所爱】19枝玫瑰表白礼盒',
#   '【相思】19枝白粉混搭玫瑰手提花篮',
#   '单层开业花篮一对',
#   '【心若向阳】33枝韩式皇冠花束',
#   '一世爱人-11枝玫瑰百合花束',
#   '【一心一意】11枝玫瑰表白礼盒',
#   '【如花美眷】11枝玫瑰鲜花礼盒',
#   '【砰然心动】爆款表白玫瑰礼盒',
#   '【午后阳光】康乃馨混搭女王抱抱桶',
#   '【一见钟情】满天星表白花束',
#   '【开业大吉】生意大麦花束',
#   '【网红爆款】康乃馨百合混搭花束',
#   '【微微一笑】11枝玫瑰表白花束',
#   '到店自取送老师单枝向日葵',
#   '【默默的爱】33枝玫瑰韩式花束',
#   '【半夏倾心】52枝玫瑰女神花束',
#   ' 【满心欢喜】19枝玫瑰鲜花花束',
#   '【送老师】到店自取康乃馨鲜花花束',
#   '【刻满关怀】19支玫瑰鲜花礼盒',
#   '【宛若清风】99枝玫瑰求婚花束',
#   '【送老师】向日葵鲜花花束',
#   '【钟爱一生】11支玫瑰鲜花花束',
#   '【送老师】到店自取小花束单个',
#   '【春水盈盈】21枝玫瑰鲜花花束',
#   '【天缘巧合】33枝玫瑰鲜花花束',
#   '【手捧星河】简约小花束',
#   '【恩情似海】玫瑰康乃馨混搭礼盒',
#   '【美轮美奂】9支玫瑰鲜花花束',
#   '【生如夏花】向日葵玫瑰韩式花束',
#   '【琴瑟之好】11枝玫瑰女王花束',
#   '【致女王】99枝玫瑰表白鲜花花束',
#   ' 【约会爆款】11枝玫瑰礼盒套餐',
#   '到店自取-单枝向日葵',
#   '【送老师】6枝向日葵韩式鲜花',
#   '【感恩玫瑰】向日葵玫瑰鲜花花束',
#   '【夕颜若雪】11枝康乃馨鲜花束',
#   '【如花似玉】33枝玫瑰百合花束',
#   '【佳人才子】11枝玫瑰鲜花花束']]

# %%
df_name = df['商品名称']
list_name = list(df_name)
text = jiebe(list_name)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.933 seconds.
# Prefix dict has been built successfully.

# %%
text
# Out:
# [['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一生', '爱', '你', '】', '11', '枝', '玫瑰', '百合花', '束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '午后', '阳光', '】', '康乃馨', '混', '搭', '女王', '抱抱', '桶'],
#  ['【', '心若', '向阳', '】', '33', '枝', '韩式', '皇冠', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '蒸蒸日上', '】', '双层', '开业', '花篮', ' ', '单个'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['单层', '开业', '花篮', '一对'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一世', '爱人', '】', '33', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大麦', '】', '大麦', '开业', '花篮', ' ', '一对'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大麦', '】', '大麦', '开业', '花篮', ' ', '一对'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一世', '爱人', '】', '33', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['11', '枝', '玫瑰', '礼盒', '表白', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['11', '枝', '玫瑰', '礼盒', '表白', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '相思', '】', '19', '枝', '白粉', '混', '搭', '玫瑰', '手提', '花篮'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微光', '倾城', '】', '33', '枝', '红玫瑰', '鲜花', '抱抱', '桶'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一世', '爱人', '】', '33', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '宛若', '清风', '】', '99', '枝', '玫瑰', '求婚', '花束'],
#  ['【', '砰然', '心动', '】', '爆款', '表白', '玫瑰', '礼盒'],
#  ['【', '心若', '向阳', '】', '33', '枝', '韩式', '皇冠', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '相思', '】', '19', '枝', '白粉', '混', '搭', '玫瑰', '手提', '花篮'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '送', '老师', '】', '向日葵', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '砰然', '心动', '】', '爆款', '表白', '玫瑰', '礼盒'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '午后', '阳光', '】', '康乃馨', '混', '搭', '女王', '抱抱', '桶'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '午后', '阳光', '】', '康乃馨', '混', '搭', '女王', '抱抱', '桶'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '约会', '推荐', '】', '11', '枝', '玫瑰', '爆款', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '约会', '推荐', '】', '11', '枝', '玫瑰', '爆款', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '砰然', '心动', '】', '爆款', '表白', '玫瑰', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一世', '爱人', '】', '33', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '砰然', '心动', '】', '爆款', '表白', '玫瑰', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '午后', '阳光', '】', '康乃馨', '混', '搭', '女王', '抱抱', '桶'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '一生', '爱', '你', '】', '11', '枝', '玫瑰', '百合花', '束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '心若', '向阳', '】', '33', '枝', '韩式', '皇冠', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '相思', '】', '19', '枝', '白粉', '混', '搭', '玫瑰', '手提', '花篮'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '约会', '推荐', '】', '11', '枝', '玫瑰', '爆款', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['七夕节', '-', '11', '枝', '表白', '玫瑰', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '约会', '推荐', '】', '11', '枝', '玫瑰', '爆款', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '刻满', '关怀', '】', '19', '支', '玫瑰', '鲜花', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '向日葵', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '小', '花束', '单个'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['一世', '爱人', '-', '11', '枝', '玫瑰', '百合花', '束'],
#  ['19', '枝', '蓝色妖姬', '玫瑰', '套餐'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '琴瑟之好', '】', '11', '枝', '玫瑰', '女王', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '半夏', '倾心', '】', '52', '枝', '玫瑰', '女神', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '盛夏', '光年', '】', '33', '枝', '玫瑰花', '束', '套餐'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '心若', '向阳', '】', '33', '枝', '韩式', '皇冠', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '一生', '爱', '你', '】', '11', '枝', '玫瑰', '百合花', '束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '相思', '】', '19', '枝', '白粉', '混', '搭', '玫瑰', '手提', '花篮'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '网红', '爆款', '】', '康乃馨', '百合', '混', '搭', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '恩情', '似海', '】', '玫瑰', '康乃馨', '混', '搭', '礼盒'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '夕颜若雪', '】', '11', '枝', '康乃馨', '鲜花', '束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '开业', '大吉', '】', '生意', '大麦', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '致', '女王', '】', '99', '枝', '玫瑰', '表白', '鲜花', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '送', '老师', '】', '6', '枝', '向日葵', '韩式', '鲜花'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '百年好合', '】', '多头', '百合', '鲜花', '花束'],
#  ['【', '感恩', '玫瑰', '】', '向日葵', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['到', '店', '自取', '-', '单枝', '向日葵'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '一心一意', '】', '11', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '美轮美奂', '】', '9', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '手', '捧', '星河', '】', '简约', '小', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '午后', '阳光', '】', '康乃馨', '混', '搭', '女王', '抱抱', '桶'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  ['【', '如花似玉', '】', '33', '枝', '玫瑰', '百合花', '束'],
#  [' ', '【', '满心欢喜', '】', '19', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '如花美眷', '】', '11', '枝', '玫瑰', '鲜花', '礼盒'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '生如夏', '花', '】', '向日葵', '玫瑰', '韩式', '花束'],
#  ['【', '默默', '的', '爱', '】', '33', '枝', '玫瑰', '韩式', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '微微一笑', '】', '11', '枝', '玫瑰', '表白', '花束'],
#  ['【', '钟爱', '一生', '】', '11', '支', '玫瑰', '鲜花', '花束'],
#  ['【', '天缘', '巧合', '】', '33', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '送', '老师', '】', '到', '店', '自取', '康乃馨', '鲜花', '花束'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '佳人才子', '】', '11', '枝', '玫瑰', '鲜花', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['到', '店', '自取', '送', '老师', '单枝', '向日葵'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ['【', '一生', '所', '爱', '】', '19', '枝', '玫瑰', '表白', '礼盒'],
#  ['【', '一见钟情', '】', '满天星', '表白', '花束'],
#  [' ', '【', '约会', '爆款', '】', '11', '枝', '玫瑰', '礼盒', '套餐'],
#  ['【', '春水', '盈盈', '】', '21', '枝', '玫瑰', '鲜花', '花束'],
#  ...]

# %%
stopwords_ = ['【','】','，','+','花束','鲜花','搭配']
text_list= clean(text,stopwords_)

# %%
content = ','.join(text_list)
df_content = pd.DataFrame({'content':text_list})
df_content.head()
# Out:
#            content
# 0      美轮美奂,9,支,玫瑰
# 1      美轮美奂,9,支,玫瑰
# 2  生如夏,花,向日葵,玫瑰,韩式
# 3  生如夏,花,向日葵,玫瑰,韩式
# 4  生如夏,花,向日葵,玫瑰,韩式

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(font_path='simfang.ttf',background_color='white',width=1400,height = 400)
wordcloud.generate(' '.join(text_list))

plt.imshow(wordcloud)

# %%
lis = ['玫瑰','康乃馨','向日葵','礼盒','11','19','33','52',]
for i  in lis:
    wenzi(df,i,'商品名称')
# Out:
# 关于“玫瑰”的订单数量是： 1269
# 关于“康乃馨”的订单数量是： 134
# 关于“向日葵”的订单数量是： 440
# 关于“礼盒”的订单数量是： 493
# 关于“11”的订单数量是： 627
# 关于“19”的订单数量是： 119
# 关于“33”的订单数量是： 216
# 关于“52”的订单数量是： 21

# %%
df_['订单号'].count()
# Out:
# 959

# %%
df_
# Out:
#      下单城市                       订单号                下单时间            下单门店  \
# 0      白山  159877862240350210288259 2020-08-30 17:10:22    邂逅花坊鲜花(青青花行)
# 1      唐山  159868977841338240134132 2020-08-29 16:29:38         印象IOO鲜花
# 2      唐山  159875091288992940956611 2020-08-30 09:28:32         印象IOO鲜花
# 3      唐山  159879061400843650981903 2020-08-30 20:30:14  邂逅花坊鲜花(枫荷鲜花庆典)
# 4     长垣市  159858512956635280188597 2020-08-28 11:25:29    邂逅花坊鲜花(千艺鲜花)
# ...   ...                       ...                 ...             ...
# 1835   北京  159628042706548640461640 2020-08-01 19:13:47    邂逅花坊鲜花(雪莲花艺)
# 1836  舒城县  159625734604815560946023 2020-08-01 12:49:06   邂逅花坊鲜花(馨馨花艺店)
# 1837  蓝田县  159628347440959280397659 2020-08-01 20:04:34    邂逅花坊鲜花(七彩鲜花)
# 1838  南康区  159626153782112950500073 2020-08-01 13:58:57    邂逅花坊鲜花(遇见花坊)
# 1839  兖州区  159624970600518440995214 2020-08-01 10:41:46    邂逅花坊鲜花(百合花艺)
#
#                  商品名称  商品规格  商品总数  商品总额   实收金额  优惠金额 订单状态  配送方式 商家备注  \
# 0      【美轮美奂】9支玫瑰鲜花花束   NaN     1    78   78.0   0.0  已完成  商家配送  NaN
# 1      【美轮美奂】9支玫瑰鲜花花束   NaN     1    78   78.0   0.0  已完成  商家配送  NaN
# 2     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  到店自取  NaN
# 3     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  商家配送  NaN
# 4     【生如夏花】向日葵玫瑰韩式花束   NaN     1   128  128.0   0.0  已完成  商家配送  NaN
# ...               ...   ...   ...   ...    ...   ...  ...   ...  ...
# 1835  【感恩玫瑰】向日葵玫瑰鲜花花束   NaN     1   149  149.0   0.0  已完成  到店自取  NaN
# 1836  【佳人才子】11枝玫瑰鲜花花束   NaN     1    89   89.0   0.0  已完成  商家配送  NaN
# 1837  【夕颜若雪】11枝康乃馨鲜花束   NaN     1    79   79.0   0.0  已完成  商家配送  NaN
# 1838  【如花似玉】33枝玫瑰百合花束   NaN     1   189  189.0   0.0  已完成  商家配送  NaN
# 1839  【佳人才子】11枝玫瑰鲜花花束   NaN     1    89   89.0   0.0  已完成  商家配送  NaN
#
#                                                    配送地址 收货人/订货人    收货人/订货人电话  \
# 0     吉林省白山市浑江区通江路122号农业招待所(通江路)农业农村局通江路122号  138439...     徐志刚  13843913300
# 1                         河北省唐山市路北区建华西道2-13号甬妈妈(一号店)唐山市       刘  13752760199
# 2                                                   NaN     NaN  18331863302
# 3                           河北省唐山市古冶区新光路4号龙江瑞景北门底商济仁堂门诊     王司洋  13931496469
# 4     河南省新乡市长垣市河南省新乡市长垣市蒲西街道会友路与宏力大道交叉口西南50米长垣市水利局到门...       郭  18503874093
# ...                                                 ...     ...          ...
# 1835                                                NaN     NaN  15810368810
# 1836                      安徽省六安市舒城县合安路广进久富商业广场3号楼安丰皇家宾馆      高云  15862517146
# 1837                            陕西省西安市蓝田县北环路西段20号开诚酒店大厅       许  15229268628
# 1838               江西省赣州市南康区南水大道南150米顶呱呱托管中心到了顶呱呱幼儿园打电话     杜平英  15170194577
# 1839                    山东省济宁市兖州区飞龙街33号附近龙桥二区8号楼三单元三楼西户      高露  13954702688
#
#       快递单号  day
# 0      NaN   30
# 1      NaN   29
# 2      NaN   30
# 3      NaN   30
# 4      NaN   28
# ...    ...  ...
# 1835   NaN    1
# 1836   NaN    1
# 1837   NaN    1
# 1838   NaN    1
# 1839   NaN    1
#
# [959 rows x 18 columns]

# %%
def drop_(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    dict_one = {}
    dict_ = {}
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['实收金额'].sum()
        if sum_ > 1 :
            list__.append(b)
            dict_[b] = sum_
        else:
            list_sum.append(b)
            dict_one[b] = sum_
    k = [list__,dict_,dict_one]
    return k

# %%
dice = drop_(df_,'下单门店')
dice
# Out:
# [['邂逅花坊鲜花(枫荷鲜花庆典)',
#   '邂逅花坊鲜花(花仙子花店)',
#   '邂逅花坊鲜花(花艺轩花艺)',
#   '美洋有约鲜花',
#   '邂逅花坊鲜花(芳汀花店)',
#   '邂逅花坊鲜花(可美鲜花)',
#   '邂逅花坊鲜花(百草卉花店)',
#   '邂逅花坊鲜花(爱的花坊)',
#   '邂逅花坊鲜花(百花园店)',
#   '邂逅花坊鲜花(花无缺)',
#   '邂逅花坊鲜花(浪漫花都店)',
#   '邂逅花坊鲜花(友馨花坊)',
#   '邂逅花坊鲜花(花海花店)',
#   '邂逅花坊鲜花(花语嫣然店)',
#   '邂逅花坊鲜花(怡尚花缘)',
#   '邂逅花坊鲜花(飘香鲜花婚典)',
#   '邂逅花坊鲜花(唯尚鲜花店)',
#   '邂逅花坊鲜花(千百艺鲜花店)',
#   '邂逅花坊鲜花(喜来登花卉礼品)',
#   '邂逅花坊鲜花(朝花夕拾)',
#   '邂逅花坊鲜花(金喜缘鲜花)',
#   '邂逅花坊鲜花(情太子花坊)',
#   '恋尚花邂逅花坊',
#   '邂逅花坊鲜花(欢庆鲜花店)',
#   '邂逅花坊鲜花(爱尚店)',
#   '邂逅花坊鲜花(情和缘鲜花)',
#   '邂逅花坊鲜花(紫晶花坊)',
#   '邂逅花坊(麦琪花艺)',
#   '邂逅花坊鲜花(唯一鲜花礼品)',
#   '邂逅花坊鲜花(爱花行)',
#   '邂逅花坊鲜花(爱花鲜花)',
#   '邂逅花坊鲜花(八姐鲜花店)',
#   '邂逅花坊鲜花(一花一匠)',
#   '邂逅花坊鲜花(唯爱鲜花坊)',
#   '邂逅花坊鲜花(香都鲜花大庙店)',
#   '邂逅花坊鲜花(抚远伊甸园)',
#   '窃窃花语',
#   '邂逅花坊鲜花(佳美鲜花店)',
#   '邂逅花坊(髙邮市春城花店)',
#   '邂逅花坊鲜花(绮彩花果坊店)',
#   '邂逅花坊鲜花(如夏花艺)',
#   '阳光鲜花店',
#   '邂逅花坊鲜花(福地花苑店)',
#   '花花世界花艺',
#   '邂逅花坊鲜花(家太爱太)',
#   '花样年华花店',
#   '邂逅花坊鲜花(紫金花坊店)',
#   '邂逅花坊(逍遥花店)',
#   '邂逅花坊鲜花(花瓣里)',
#   '邂逅花坊鲜花(花沁阁花坊)',
#   '邂逅花坊鲜花·花开时节',
#   '邂逅花坊鲜花(天工花艺)',
#   '邂逅花坊鲜花(九月花舍)',
#   '邂逅花坊',
#   '邂逅花坊鲜花(花语鲜花)',
#   '邂逅花坊鲜花(田园花坊店)',
#   '邂逅花坊鲜花(花样年华店)',
#   '邂逅花坊鲜花(最美时光花艺店)',
#   '邂逅花坊鲜花(花趣花艺)',
#   '邂逅花坊鲜花(BEWITHYOU早安花艺)',
#   '花语鲜花店',
#   '邂逅花坊鲜花(花艺空间店)',
#   '邂逅花坊鲜花(八姐店)',
#   '千姿花艺',
#   '邂逅花坊鲜花(甜蜜花艺店)',
#   '邂逅花坊鲜花(芳汀鲜花)',
#   '花好月圆花艺',
#   '邂逅花坊鲜花(鱼小姐店)',
#   '邂逅花坊鲜花(童花品牌集合店)',
#   '邂逅花坊鲜花(大花轿婚庆)',
#   '邂逅花坊鲜花(青青花行)',
#   '邂逅花坊鲜花(豆豆花卉)',
#   '邂逅花坊鲜花(紫涵花兿)',
#   '邂逅花坊鲜花(时光花里店)',
#   '邂逅花坊(永香花店)',
#   '邂逅花坊鲜花(漪花园店)',
#   '邂逅花坊鲜花(悦禧鲜花店)',
#   '邂逅花坊鲜花(永红花艺馆)',
#   '邂逅花坊(喜来得鲜花店)',
#   '邂逅花坊鲜花(米蘭花店)',
#   '倾心花艺',
#   '邂逅花坊鲜花(墨兰鲜花店)',
#   '邂逅花坊鲜花(SaSa花艺生活馆)',
#   '邂逅花坊鲜花(御花源)',
#   '邂逅花坊鲜花(良缘婚庆鲜花)',
#   '邂逅花坊鲜花(时尚策划店)',
#   '花草当家鲜花店',
#   '花雨轩花艺',
#   '邂逅花坊鲜花(百合花艺坊)',
#   '邂逅花坊鲜花(宝宝花店)',
#   '邂逅花坊鲜花林東花鸟鱼',
#   '邂逅花坊鲜花(万卉源)',
#   '邂逅花坊鲜花(馨语花坊)',
#   '迷思花店',
#   '邂逅花坊鲜花(燕子鲜花)',
#   '邂逅花坊鲜花(四季花屋)',
#   '邂逅花坊鲜花(普罗旺斯婚庆)',
#   '花开半夏花艺生活馆',
#   '邂逅花坊鲜花(原野花艺)',
#   '花样年华(润和店)',
#   '邂逅花坊鲜花(原色店)',
#   '邂逅花坊鲜花(花之艺店)',
#   '邂逅花坊鲜花(竞花园店)',
#   '邂逅花坊鲜花(百合花坊)',
#   '锦尚鲜花(雅韵鲜花店)',
#   '邂逅花坊鲜花(欣雨花店)',
#   '小城故事鲜花坊',
#   '邂逅花坊鲜花(百合婚礼鲜花)',
#   '邂逅花坊(小屋店)',
#   '邂逅花坊鲜花(花娇艳鲜花店)',
#   '邂逅花坊鲜花(婷雅花坊店)',
#   '邂逅花坊鲜花(花世界)',
#   '邂逅花坊鲜花(千艺鲜花)',
#   '邂逅花坊鲜花(花语店)',
#   '邂逅花坊鲜花(温馨花都)',
#   '印象IOO鲜花',
#   '邂逅花坊鲜花(艾诺鲜花)',
#   '邂逅花坊鲜花(雅琳花艺店)',
#   '邂逅花坊鲜花(花花世界店)',
#   '鲜花小站',
#   '邂逅花坊鲜花(浪漫满屋店)',
#   '邂逅花坊鲜花(君悦鲜花)',
#   '佳佳花艺',
#   '邂逅花坊鲜花(雅景花坊)',
#   '邂逅花坊鲜花(百花派店)',
#   '邂逅花坊鲜花(季盛店)',
#   '邂逅花坊鲜花(乙甲花艺)',
#   '邂逅花坊鲜花(百花苑婚庆)',
#   '邂逅花坊鲜花(时尚花坊)',
#   '爱慕花艺',
#   '缤纷花艺',
#   '邂逅花坊鲜花(贵人花坊店)',
#   '蝶恋花坊',
#   '邂逅花坊鲜花(美好鲜花)',
#   '邂逅花坊鲜花(绿岛花苑)',
#   '邂逅花坊鲜花爱尚花坊',
#   '邂逅花坊鲜花(花之缘鲜花)',
#   '花语鲜花',
#   '邂逅花坊鲜花(你洋鲜花店)',
#   '邂逅花坊鲜花(同心鲜花店)',
#   '邂逅花坊鲜花(知音婚庆鲜花店)',
#   '邂逅花坊鲜花(鑫美花卉)',
#   '小立鲜花店(小立鲜花店（三河店）)',
#   '邂逅花坊鲜花(雪莲花艺)',
#   '邂逅花坊鲜花(馨馨花艺店)',
#   '邂逅花坊鲜花(七彩鲜花)',
#   '邂逅花坊鲜花(遇见花坊)',
#   '邂逅花坊鲜花(百合花艺)'],
#  {'邂逅花坊鲜花(枫荷鲜花庆典)': 128.0,
#   '邂逅花坊鲜花(花仙子花店)': 118.0,
#   '邂逅花坊鲜花(花艺轩花艺)': 88.0,
#   '美洋有约鲜花': 88.0,
#   '邂逅花坊鲜花(芳汀花店)': 88.0,
#   '邂逅花坊鲜花(可美鲜花)': 149.0,
#   '邂逅花坊鲜花(百草卉花店)': 78.0,
#   '邂逅花坊鲜花(爱的花坊)': 605.0,
#   '邂逅花坊鲜花(百花园店)': 269.0,
#   '邂逅花坊鲜花(花无缺)': 28.0,
#   '邂逅花坊鲜花(浪漫花都店)': 179.0,
#   '邂逅花坊鲜花(友馨花坊)': 56.0,
#   '邂逅花坊鲜花(花海花店)': 405.0,
#   '邂逅花坊鲜花(花语嫣然店)': 129.0,
#   '邂逅花坊鲜花(怡尚花缘)': 360.2,
#   '邂逅花坊鲜花(飘香鲜花婚典)': 209.0,
#   '邂逅花坊鲜花(唯尚鲜花店)': 368.0,
#   '邂逅花坊鲜花(千百艺鲜花店)': 1275.0,
#   '邂逅花坊鲜花(喜来登花卉礼品)': 28.0,
#   '邂逅花坊鲜花(朝花夕拾)': 84.0,
#   '邂逅花坊鲜花(金喜缘鲜花)': 28.0,
#   '邂逅花坊鲜花(情太子花坊)': 149.0,
#   '恋尚花邂逅花坊': 209.0,
#   '邂逅花坊鲜花(欢庆鲜花店)': 119.0,
#   '邂逅花坊鲜花(爱尚店)': 326.0,
#   '邂逅花坊鲜花(情和缘鲜花)': 84.0,
#   '邂逅花坊鲜花(紫晶花坊)': 179.0,
#   '邂逅花坊(麦琪花艺)': 28.0,
#   '邂逅花坊鲜花(唯一鲜花礼品)': 217.0,
#   '邂逅花坊鲜花(爱花行)': 28.0,
#   '邂逅花坊鲜花(爱花鲜花)': 168.0,
#   '邂逅花坊鲜花(八姐鲜花店)': 176.0,
#   '邂逅花坊鲜花(一花一匠)': 28.0,
#   '邂逅花坊鲜花(唯爱鲜花坊)': 112.0,
#   '邂逅花坊鲜花(香都鲜花大庙店)': 368.0,
#   '邂逅花坊鲜花(抚远伊甸园)': 84.0,
#   '窃窃花语': 112.0,
#   '邂逅花坊鲜花(佳美鲜花店)': 99.0,
#   '邂逅花坊(髙邮市春城花店)': 138.0,
#   '邂逅花坊鲜花(绮彩花果坊店)': 348.0,
#   '邂逅花坊鲜花(如夏花艺)': 28.0,
#   '阳光鲜花店': 119.0,
#   '邂逅花坊鲜花(福地花苑店)': 505.0,
#   '花花世界花艺': 358.0,
#   '邂逅花坊鲜花(家太爱太)': 666.2,
#   '花样年华花店': 227.0,
#   '邂逅花坊鲜花(紫金花坊店)': 88.0,
#   '邂逅花坊(逍遥花店)': 680.0,
#   '邂逅花坊鲜花(花瓣里)': 28.0,
#   '邂逅花坊鲜花(花沁阁花坊)': 457.0,
#   '邂逅花坊鲜花·花开时节': 88.0,
#   '邂逅花坊鲜花(天工花艺)': 189.0,
#   '邂逅花坊鲜花(九月花舍)': 583.0,
#   '邂逅花坊': 725.0,
#   '邂逅花坊鲜花(花语鲜花)': 119.0,
#   '邂逅花坊鲜花(田园花坊店)': 760.0,
#   '邂逅花坊鲜花(花样年华店)': 138.0,
#   '邂逅花坊鲜花(最美时光花艺店)': 497.0,
#   '邂逅花坊鲜花(花趣花艺)': 106.0,
#   '邂逅花坊鲜花(BEWITHYOU早安花艺)': 437.0,
#   '花语鲜花店': 268.0,
#   '邂逅花坊鲜花(花艺空间店)': 368.0,
#   '邂逅花坊鲜花(八姐店)': 405.0,
#   '千姿花艺': 89.0,
#   '邂逅花坊鲜花(甜蜜花艺店)': 176.0,
#   '邂逅花坊鲜花(芳汀鲜花)': 69.0,
#   '花好月圆花艺': 1032.0,
#   '邂逅花坊鲜花(鱼小姐店)': 418.0,
#   '邂逅花坊鲜花(童花品牌集合店)': 406.0,
#   '邂逅花坊鲜花(大花轿婚庆)': 252.0,
#   '邂逅花坊鲜花(青青花行)': 782.0,
#   '邂逅花坊鲜花(豆豆花卉)': 1019.0,
#   '邂逅花坊鲜花(紫涵花兿)': 1340.0,
#   '邂逅花坊鲜花(时光花里店)': 89.0,
#   '邂逅花坊(永香花店)': 407.0,
#   '邂逅花坊鲜花(漪花园店)': 149.0,
#   '邂逅花坊鲜花(悦禧鲜花店)': 239.0,
#   '邂逅花坊鲜花(永红花艺馆)': 1026.0,
#   '邂逅花坊(喜来得鲜花店)': 725.0,
#   '邂逅花坊鲜花(米蘭花店)': 252.0,
#   '倾心花艺': 235.0,
#   '邂逅花坊鲜花(墨兰鲜花店)': 291.0,
#   '邂逅花坊鲜花(SaSa花艺生活馆)': 109.0,
#   '邂逅花坊鲜花(御花源)': 2466.0,
#   '邂逅花坊鲜花(良缘婚庆鲜花)': 1438.0,
#   '邂逅花坊鲜花(时尚策划店)': 696.0,
#   '花草当家鲜花店': 1459.0,
#   '花雨轩花艺': 3153.0,
#   '邂逅花坊鲜花(百合花艺坊)': 662.0,
#   '邂逅花坊鲜花(宝宝花店)': 198.0,
#   '邂逅花坊鲜花林東花鸟鱼': 2611.0,
#   '邂逅花坊鲜花(万卉源)': 1468.0,
#   '邂逅花坊鲜花(馨语花坊)': 635.0,
#   '迷思花店': 1547.0,
#   '邂逅花坊鲜花(燕子鲜花)': 259.0,
#   '邂逅花坊鲜花(四季花屋)': 2124.0,
#   '邂逅花坊鲜花(普罗旺斯婚庆)': 903.0,
#   '花开半夏花艺生活馆': 1159.0,
#   '邂逅花坊鲜花(原野花艺)': 293.0,
#   '花样年华(润和店)': 992.0,
#   '邂逅花坊鲜花(原色店)': 69.0,
#   '邂逅花坊鲜花(花之艺店)': 185.0,
#   '邂逅花坊鲜花(竞花园店)': 2707.0,
#   '邂逅花坊鲜花(百合花坊)': 1521.0,
#   '锦尚鲜花(雅韵鲜花店)': 1718.0,
#   '邂逅花坊鲜花(欣雨花店)': 1560.0,
#   '小城故事鲜花坊': 872.0,
#   '邂逅花坊鲜花(百合婚礼鲜花)': 207.0,
#   '邂逅花坊(小屋店)': 1109.0,
#   '邂逅花坊鲜花(花娇艳鲜花店)': 455.0,
#   '邂逅花坊鲜花(婷雅花坊店)': 6006.0,
#   '邂逅花坊鲜花(花世界)': 178.0,
#   '邂逅花坊鲜花(千艺鲜花)': 3903.0,
#   '邂逅花坊鲜花(花语店)': 476.0,
#   '邂逅花坊鲜花(温馨花都)': 748.0,
#   '印象IOO鲜花': 2516.0,
#   '邂逅花坊鲜花(艾诺鲜花)': 517.0,
#   '邂逅花坊鲜花(雅琳花艺店)': 645.0,
#   '邂逅花坊鲜花(花花世界店)': 980.0,
#   '鲜花小站': 295.0,
#   '邂逅花坊鲜花(浪漫满屋店)': 507.0,
#   '邂逅花坊鲜花(君悦鲜花)': 1261.0,
#   '佳佳花艺': 2081.0,
#   '邂逅花坊鲜花(雅景花坊)': 1325.0,
#   '邂逅花坊鲜花(百花派店)': 3943.2,
#   '邂逅花坊鲜花(季盛店)': 4993.0,
#   '邂逅花坊鲜花(乙甲花艺)': 1596.0,
#   '邂逅花坊鲜花(百花苑婚庆)': 427.0,
#   '邂逅花坊鲜花(时尚花坊)': 665.0,
#   '爱慕花艺': 288.0,
#   '缤纷花艺': 734.0,
#   '邂逅花坊鲜花(贵人花坊店)': 268.0,
#   '蝶恋花坊': 515.0,
#   '邂逅花坊鲜花(美好鲜花)': 2090.0,
#   '邂逅花坊鲜花(绿岛花苑)': 208.0,
#   '邂逅花坊鲜花爱尚花坊': 544.0,
#   '邂逅花坊鲜花(花之缘鲜花)': 28.0,
#   '花语鲜花': 9792.2,
#   '邂逅花坊鲜花(你洋鲜花店)': 177.0,
#   '邂逅花坊鲜花(同心鲜花店)': 1356.0,
#   '邂逅花坊鲜花(知音婚庆鲜花店)': 5888.0,
#   '邂逅花坊鲜花(鑫美花卉)': 4459.2,
#   '小立鲜花店(小立鲜花店（三河店）)': 1160.0,
#   '邂逅花坊鲜花(雪莲花艺)': 2631.2,
#   '邂逅花坊鲜花(馨馨花艺店)': 2141.0,
#   '邂逅花坊鲜花(七彩鲜花)': 1935.0,
#   '邂逅花坊鲜花(遇见花坊)': 403.0,
#   '邂逅花坊鲜花(百合花艺)': 1557.0},
#  {}]

# %%
dice_ = dice[1]
dice__ = dice[2]
dice_.update(dice__)

# %%
dice_
# Out:
# {'邂逅花坊鲜花(枫荷鲜花庆典)': 128.0,
#  '邂逅花坊鲜花(花仙子花店)': 118.0,
#  '邂逅花坊鲜花(花艺轩花艺)': 88.0,
#  '美洋有约鲜花': 88.0,
#  '邂逅花坊鲜花(芳汀花店)': 88.0,
#  '邂逅花坊鲜花(可美鲜花)': 149.0,
#  '邂逅花坊鲜花(百草卉花店)': 78.0,
#  '邂逅花坊鲜花(爱的花坊)': 605.0,
#  '邂逅花坊鲜花(百花园店)': 269.0,
#  '邂逅花坊鲜花(花无缺)': 28.0,
#  '邂逅花坊鲜花(浪漫花都店)': 179.0,
#  '邂逅花坊鲜花(友馨花坊)': 56.0,
#  '邂逅花坊鲜花(花海花店)': 405.0,
#  '邂逅花坊鲜花(花语嫣然店)': 129.0,
#  '邂逅花坊鲜花(怡尚花缘)': 360.2,
#  '邂逅花坊鲜花(飘香鲜花婚典)': 209.0,
#  '邂逅花坊鲜花(唯尚鲜花店)': 368.0,
#  '邂逅花坊鲜花(千百艺鲜花店)': 1275.0,
#  '邂逅花坊鲜花(喜来登花卉礼品)': 28.0,
#  '邂逅花坊鲜花(朝花夕拾)': 84.0,
#  '邂逅花坊鲜花(金喜缘鲜花)': 28.0,
#  '邂逅花坊鲜花(情太子花坊)': 149.0,
#  '恋尚花邂逅花坊': 209.0,
#  '邂逅花坊鲜花(欢庆鲜花店)': 119.0,
#  '邂逅花坊鲜花(爱尚店)': 326.0,
#  '邂逅花坊鲜花(情和缘鲜花)': 84.0,
#  '邂逅花坊鲜花(紫晶花坊)': 179.0,
#  '邂逅花坊(麦琪花艺)': 28.0,
#  '邂逅花坊鲜花(唯一鲜花礼品)': 217.0,
#  '邂逅花坊鲜花(爱花行)': 28.0,
#  '邂逅花坊鲜花(爱花鲜花)': 168.0,
#  '邂逅花坊鲜花(八姐鲜花店)': 176.0,
#  '邂逅花坊鲜花(一花一匠)': 28.0,
#  '邂逅花坊鲜花(唯爱鲜花坊)': 112.0,
#  '邂逅花坊鲜花(香都鲜花大庙店)': 368.0,
#  '邂逅花坊鲜花(抚远伊甸园)': 84.0,
#  '窃窃花语': 112.0,
#  '邂逅花坊鲜花(佳美鲜花店)': 99.0,
#  '邂逅花坊(髙邮市春城花店)': 138.0,
#  '邂逅花坊鲜花(绮彩花果坊店)': 348.0,
#  '邂逅花坊鲜花(如夏花艺)': 28.0,
#  '阳光鲜花店': 119.0,
#  '邂逅花坊鲜花(福地花苑店)': 505.0,
#  '花花世界花艺': 358.0,
#  '邂逅花坊鲜花(家太爱太)': 666.2,
#  '花样年华花店': 227.0,
#  '邂逅花坊鲜花(紫金花坊店)': 88.0,
#  '邂逅花坊(逍遥花店)': 680.0,
#  '邂逅花坊鲜花(花瓣里)': 28.0,
#  '邂逅花坊鲜花(花沁阁花坊)': 457.0,
#  '邂逅花坊鲜花·花开时节': 88.0,
#  '邂逅花坊鲜花(天工花艺)': 189.0,
#  '邂逅花坊鲜花(九月花舍)': 583.0,
#  '邂逅花坊': 725.0,
#  '邂逅花坊鲜花(花语鲜花)': 119.0,
#  '邂逅花坊鲜花(田园花坊店)': 760.0,
#  '邂逅花坊鲜花(花样年华店)': 138.0,
#  '邂逅花坊鲜花(最美时光花艺店)': 497.0,
#  '邂逅花坊鲜花(花趣花艺)': 106.0,
#  '邂逅花坊鲜花(BEWITHYOU早安花艺)': 437.0,
#  '花语鲜花店': 268.0,
#  '邂逅花坊鲜花(花艺空间店)': 368.0,
#  '邂逅花坊鲜花(八姐店)': 405.0,
#  '千姿花艺': 89.0,
#  '邂逅花坊鲜花(甜蜜花艺店)': 176.0,
#  '邂逅花坊鲜花(芳汀鲜花)': 69.0,
#  '花好月圆花艺': 1032.0,
#  '邂逅花坊鲜花(鱼小姐店)': 418.0,
#  '邂逅花坊鲜花(童花品牌集合店)': 406.0,
#  '邂逅花坊鲜花(大花轿婚庆)': 252.0,
#  '邂逅花坊鲜花(青青花行)': 782.0,
#  '邂逅花坊鲜花(豆豆花卉)': 1019.0,
#  '邂逅花坊鲜花(紫涵花兿)': 1340.0,
#  '邂逅花坊鲜花(时光花里店)': 89.0,
#  '邂逅花坊(永香花店)': 407.0,
#  '邂逅花坊鲜花(漪花园店)': 149.0,
#  '邂逅花坊鲜花(悦禧鲜花店)': 239.0,
#  '邂逅花坊鲜花(永红花艺馆)': 1026.0,
#  '邂逅花坊(喜来得鲜花店)': 725.0,
#  '邂逅花坊鲜花(米蘭花店)': 252.0,
#  '倾心花艺': 235.0,
#  '邂逅花坊鲜花(墨兰鲜花店)': 291.0,
#  '邂逅花坊鲜花(SaSa花艺生活馆)': 109.0,
#  '邂逅花坊鲜花(御花源)': 2466.0,
#  '邂逅花坊鲜花(良缘婚庆鲜花)': 1438.0,
#  '邂逅花坊鲜花(时尚策划店)': 696.0,
#  '花草当家鲜花店': 1459.0,
#  '花雨轩花艺': 3153.0,
#  '邂逅花坊鲜花(百合花艺坊)': 662.0,
#  '邂逅花坊鲜花(宝宝花店)': 198.0,
#  '邂逅花坊鲜花林東花鸟鱼': 2611.0,
#  '邂逅花坊鲜花(万卉源)': 1468.0,
#  '邂逅花坊鲜花(馨语花坊)': 635.0,
#  '迷思花店': 1547.0,
#  '邂逅花坊鲜花(燕子鲜花)': 259.0,
#  '邂逅花坊鲜花(四季花屋)': 2124.0,
#  '邂逅花坊鲜花(普罗旺斯婚庆)': 903.0,
#  '花开半夏花艺生活馆': 1159.0,
#  '邂逅花坊鲜花(原野花艺)': 293.0,
#  '花样年华(润和店)': 992.0,
#  '邂逅花坊鲜花(原色店)': 69.0,
#  '邂逅花坊鲜花(花之艺店)': 185.0,
#  '邂逅花坊鲜花(竞花园店)': 2707.0,
#  '邂逅花坊鲜花(百合花坊)': 1521.0,
#  '锦尚鲜花(雅韵鲜花店)': 1718.0,
#  '邂逅花坊鲜花(欣雨花店)': 1560.0,
#  '小城故事鲜花坊': 872.0,
#  '邂逅花坊鲜花(百合婚礼鲜花)': 207.0,
#  '邂逅花坊(小屋店)': 1109.0,
#  '邂逅花坊鲜花(花娇艳鲜花店)': 455.0,
#  '邂逅花坊鲜花(婷雅花坊店)': 6006.0,
#  '邂逅花坊鲜花(花世界)': 178.0,
#  '邂逅花坊鲜花(千艺鲜花)': 3903.0,
#  '邂逅花坊鲜花(花语店)': 476.0,
#  '邂逅花坊鲜花(温馨花都)': 748.0,
#  '印象IOO鲜花': 2516.0,
#  '邂逅花坊鲜花(艾诺鲜花)': 517.0,
#  '邂逅花坊鲜花(雅琳花艺店)': 645.0,
#  '邂逅花坊鲜花(花花世界店)': 980.0,
#  '鲜花小站': 295.0,
#  '邂逅花坊鲜花(浪漫满屋店)': 507.0,
#  '邂逅花坊鲜花(君悦鲜花)': 1261.0,
#  '佳佳花艺': 2081.0,
#  '邂逅花坊鲜花(雅景花坊)': 1325.0,
#  '邂逅花坊鲜花(百花派店)': 3943.2,
#  '邂逅花坊鲜花(季盛店)': 4993.0,
#  '邂逅花坊鲜花(乙甲花艺)': 1596.0,
#  '邂逅花坊鲜花(百花苑婚庆)': 427.0,
#  '邂逅花坊鲜花(时尚花坊)': 665.0,
#  '爱慕花艺': 288.0,
#  '缤纷花艺': 734.0,
#  '邂逅花坊鲜花(贵人花坊店)': 268.0,
#  '蝶恋花坊': 515.0,
#  '邂逅花坊鲜花(美好鲜花)': 2090.0,
#  '邂逅花坊鲜花(绿岛花苑)': 208.0,
#  '邂逅花坊鲜花爱尚花坊': 544.0,
#  '邂逅花坊鲜花(花之缘鲜花)': 28.0,
#  '花语鲜花': 9792.2,
#  '邂逅花坊鲜花(你洋鲜花店)': 177.0,
#  '邂逅花坊鲜花(同心鲜花店)': 1356.0,
#  '邂逅花坊鲜花(知音婚庆鲜花店)': 5888.0,
#  '邂逅花坊鲜花(鑫美花卉)': 4459.2,
#  '小立鲜花店(小立鲜花店（三河店）)': 1160.0,
#  '邂逅花坊鲜花(雪莲花艺)': 2631.2,
#  '邂逅花坊鲜花(馨馨花艺店)': 2141.0,
#  '邂逅花坊鲜花(七彩鲜花)': 1935.0,
#  '邂逅花坊鲜花(遇见花坊)': 403.0,
#  '邂逅花坊鲜花(百合花艺)': 1557.0}

# %%
dice_sum = pd.DataFrame(pd.Series(dice_), columns=['count'])
dice_sum = dice_sum.reset_index().rename(columns={'name':'count_'})
dice_sum = dice_sum.sort_values(by='count',ascending=False)

# %%
# dice_excel = pd.DataFrame(pd.Series(dice_), columns=['count'])
# dice_excel = dice_excel.reset_index().rename(columns={'name':'count_'})
# dice_excel = dice_excel.sort_values(by='count',ascending=False)

# %%
data = pd.merge(dice_excel,dice_sum,on = 'index')

# %%
# dice_excel.to_excel('门店订单数明细.xlsx')

# %%
data.to_excel('门店订单营收明细.xlsx')
