# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns',None)
from sklearn.feature_extraction.text import CountVectorizer
import jieba # 导入关键字提取库
import pandas as pd  # 导入pandas
# import newspaper

# %%
def improt_data(lujing,code):
    data = pd.read_excel(lujing,encoding =code)
    return data

def wenzi(list_1,z):
    list_2 = []
    i = 0
    for x in list_1:
        y = x
        tr = y.find(z)
        if tr > -1 :
            i = i+1
            list_2.append(x)
   

    print('关于' + '“' + zi + '”' + '的订单数量是：',i)  
    return list_2

def jiebe(data):    
    text_list = []
    for line in data:
        hou = ",".join(jieba.cut(line))
        strlist = hou.split(',') 
        text_list.append(strlist)
    return text_list

def clean(list_name_,stopwords_):    
    clean_line = []
    for line in list_name_:
        haha = []
        for word in line:
            if word in stopwords_:
                continue
            haha.append(word)
        haha = ','.join(haha)
        clean_line.append(haha)

    return clean_line

def drop_du(data,a):
    df = data.drop_duplicates(subset=a,inplace=False,keep = 'last')
    list_ = list(df[a])
    list_sum = []
    list_sum_ = []
    list__ = []
    for i in range(len(list_)):
        b = list_[i]
        sum_ = data[data[a] == b ]['订单编号'].count()
        dict_ = {}
    
        if sum_ > 1 :
            list__.append(b)
            dict_ = {b:sum_}
            list_sum.append(dict_)
        else:
            list__.append(b)
            dict_ = {b:sum_}
            list_sum_.append(dict_)
        i = i + 1  
    k = [list_sum,list_sum_,list__]
    return k

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/八月团购/星级门店1.xls'
code = 'utf8'
df_dengji1 = improt_data(lujing,code)

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/八月团购/星级门店2.xlsx'
code = 'utf8'
df_dengji2 = improt_data(lujing,code)

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/八月团购/详情.xlsx'
code = 'utf8'
df_xiangqing = improt_data(lujing,code)

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/八月团购/日详情.xlsx'
code = 'utf8'
df_xiangqing_ri = improt_data(lujing,code)

# %%
# data1 = df_xiangqing.drop_duplicates(subset='门店名称',keep=False)
# data2 = df_xiangqing.drop_duplicates(subset='门店名称',keep='first')
# data2.append(data1).drop_duplicates(keep=False)

# %%
# df_xiangqing[df_xiangqing['门店名称'] == '邂逅花坊鲜花(四季花屋)']

# %%
# df_xiangqing['地址名称'] = df_xiangqing['城市'] + df_xiangqing['门店名称']

# %%
df_xd = pd.merge(df_xiangqing,df_dengji1,on='门店名称')

# %%
df_xd
# Out:
#           日期   城市               门店名称   曝光人数 曝光人数环比  访问人数 访问人数环比 曝光访问转化率  \
# 0    2020-08   万宁       邂逅花坊鲜花(雅景花坊)   1693  +226%   390  +207%  23.04%
# 1    2020-08  万州区       邂逅花坊鲜花(竞花园店)   2626  +137%   602  +210%  22.92%
# 2    2020-08  万州区      邂逅花坊鲜花(花艺空间店)    660  +102%    95  +157%  14.39%
# 3    2020-08  三河市  小立鲜花店(小立鲜花店（三河店）)    976  +263%   203  +372%  20.80%
# 4    2020-08  三河市       邂逅花坊鲜花(百合花坊)   1937  +153%   519  +185%  26.79%
# ..       ...  ...                ...    ...    ...   ...    ...     ...
# 150  2020-08  马鞍山      邂逅花坊鲜花(婷雅花坊店)  34528    -2%  1388   +58%   4.02%
# 151  2020-08   鹰潭        邂逅花坊鲜花·花开时节    816  +149%   105  +338%  12.87%
# 152  2020-08   鹰潭       邂逅花坊鲜花(鑫美花卉)   2546   +81%   631   +92%  24.78%
# 153  2020-08   黄山      邂逅花坊鲜花(百花苑婚庆)    873  +109%   110  +175%  12.60%
# 154  2020-08  龙口市       邂逅花坊鲜花(苔米花艺)    182      0    17      0   9.34%
#
#     曝光访问转化率环比  意向转化人数 意向转化人数环比  意向转化率 意向转化率环比        门店ID  美团星级 美团星级变化  \
# 0         -6%      29    +867%  7.44%   +215%   121560030  3.9星     持平
# 1        +31%      53    +489%  8.80%    +90%   111559299  4.5星  +0.3星
# 2        +27%       6        0  6.32%       0   132842379    0星     持平
# 3        +30%      17        0  8.37%       0   111603568  3.5星     持平
# 4        +13%      19    +375%  3.66%    +66%   132843573  4.3星     持平
# ..        ...     ...      ...    ...     ...         ...   ...    ...
# 150      +61%      79     -86%  5.69%    -91%   127544279    5星     持平
# 151      +76%       4    +100%  3.81%    -54%   112226224  4.4星     持平
# 152       +6%      49    +513%  7.77%   +220%   127736099    5星     持平
# 153      +31%       7    +600%  6.36%   +154%   127655453  4.3星     持平
# 154         0       0        0  0.00%       0  1091325132    0星     持平
#
#     大众点评点评星级 大众点评星级变化
# 0      0.00星       持平
# 1      3.97星   +3.97星
# 2      0.00星       持平
# 3      4.08星   +0.19星
# 4      4.07星   -0.01星
# ..       ...      ...
# 150    4.05星   -0.02星
# 151    0.00星       持平
# 152    0.00星       持平
# 153    0.00星       持平
# 154    0.00星       持平
#
# [155 rows x 18 columns]

# %%
df_xd['美团星级'] = df_xd['美团星级'].str.split('星',expand=True)[0]
df_xd['大众点评点评星级'] = df_xd['大众点评点评星级'].str.split('星',expand=True)[0]

# %%
df_xd = df_xd[['门店ID','日期','城市','门店名称','曝光人数','访问人数','意向转化人数','曝光访问转化率','意向转化率','美团星级','美团星级变化','大众点评点评星级','大众点评星级变化']]

# %%
lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/xd.xlsx'
code = 'utf8'
xd = improt_data(lujing,code)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-836f637da345> in <module>
#       1 lujing = r'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/xd.xlsx'
#       2 code = 'utf8'
# ----> 3 xd = improt_data(lujing,code)
#
# <ipython-input-2-f4596ec99e03> in improt_data(lujing, code)
#       1 def improt_data(lujing,code):
# ----> 2     data = pd.read_excel(lujing,encoding =code)
#       3     return data
#       4
#       5 def wenzi(list_1,z):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Administrator/datas/Airsng/1训练模型/美团团购/xd.xlsx'

# %%
xd = xd.sort_values(by='美团星级',ascending=False)
xd
# Out:
#      Unnamed: 0        门店ID       日期   城市             门店名称   曝光人数  访问人数  \
# 97           97   127588998  2020-08   泸州      邂逅花坊鲜花(花语店)    926   143
# 11           11   130648305  2020-08   东阳  邂逅花坊鲜花(知音婚庆鲜花店)  59162  2417
# 25           25   127546074  2020-08   北京     邂逅花坊鲜花(雪莲花艺)   8329   445
# 141         141    66237179  2020-08   长治      锦尚鲜花(雅韵鲜花店)   7076   379
# 116         116   112179102  2020-08   绵阳   邂逅花坊鲜花(绮彩花果坊店)   1598   156
# ..          ...         ...      ...  ...              ...    ...   ...
# 5             5   887542976  2020-08   上海     邂逅花坊鲜花(友馨花坊)    103    34
# 2             2   132842379  2020-08  万州区    邂逅花坊鲜花(花艺空间店)    660    95
# 51           51   127616762  2020-08  安乡县     邂逅花坊鲜花(花之艺店)    214    69
# 54           54    92274198  2020-08   安阳             艺博花艺    598    37
# 154         154  1091325132  2020-08  龙口市     邂逅花坊鲜花(苔米花艺)    182    17
#
#      意向转化人数 曝光访问转化率   意向转化率  美团星级 美团星级变化  大众点评点评星级 大众点评星级变化
# 97        5  15.44%   3.50%   5.0     持平      3.79   -0.03星
# 11      104   4.09%   4.30%   5.0     持平      3.97   +3.97星
# 25       48   5.34%  10.79%   5.0  +0.1星      4.45   +0.05星
# 141      19   5.36%   5.01%   5.0  +0.5星      3.00       持平
# 116       9   9.76%   5.77%   5.0     持平      0.00       持平
# ..      ...     ...     ...   ...    ...       ...      ...
# 5         5  33.01%  14.71%   0.0     持平      0.00       持平
# 2         6  14.39%   6.32%   0.0     持平      0.00       持平
# 51        6  32.24%   8.70%   0.0     持平      0.00       持平
# 54        2   6.19%   5.41%   0.0     持平      0.00       持平
# 154       0   9.34%   0.00%   0.0     持平      0.00       持平
#
# [155 rows x 14 columns]

# %%
xd_one = xd[xd['美团星级'] >= 4.5]
xd_two =xd[(xd['美团星级'] >3.5)  & (xd['美团星级'] <=4.5)]
xd_three = xd[(xd['美团星级'] >0)  & (xd['美团星级'] <=3.5)]
xd_four = xd[xd['美团星级'] == 0]

# %%
xd_one_list = list(xd_two['门店名称'])
xd_two_list = list(xd_two['门店名称'])
xd_three_list = list(xd_three['门店名称'])
xd_four_list = list(xd_four['门店名称'])

# %%
xd_d = []

# %%
xd_d.append(xd_one_list)
xd_d.append(xd_two_list)
xd_d.append(xd_three_list)
xd_d.append(xd_four_list)

# %%
xd_one = xd_one.sort_values(by='曝光人数',ascending=False)
xd_two = xd_two.sort_values(by='曝光人数',ascending=False)
xd_three = xd_three.sort_values(by='曝光人数',ascending=False)
xd_four = xd_four.sort_values(by='曝光人数',ascending=False)

# %%
xd.boxplot('曝光人数')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Q1 = np.percentile(xd['曝光人数'], 25)
Q3 = np.percentile(xd['曝光人数'], 75)
Q2 = np.percentile(xd['曝光人数'], 50)
IQ = Q3 - Q1

# %%
xd.corr()
# Out:
#             Unnamed: 0      门店ID      曝光人数      访问人数    意向转化人数      美团星级  \
# Unnamed: 0    1.000000 -0.040221  0.019067  0.064027 -0.005598  0.166875
# 门店ID         -0.040221  1.000000 -0.116195 -0.246158 -0.182702 -0.506261
# 曝光人数          0.019067 -0.116195  1.000000  0.847726  0.476231  0.222780
# 访问人数          0.064027 -0.246158  0.847726  1.000000  0.612120  0.392955
# 意向转化人数       -0.005598 -0.182702  0.476231  0.612120  1.000000  0.301601
# 美团星级          0.166875 -0.506261  0.222780  0.392955  0.301601  1.000000
# 大众点评点评星级     -0.016129 -0.386620  0.235568  0.343111  0.334025  0.559722
#
#             大众点评点评星级
# Unnamed: 0 -0.016129
# 门店ID       -0.386620
# 曝光人数        0.235568
# 访问人数        0.343111
# 意向转化人数      0.334025
# 美团星级        0.559722
# 大众点评点评星级    1.000000

# %%
from pylab  import mpl
import seaborn as sns; sns.set()
# %matplotlib inline
mpl.rcParams['font.sans-serif'] = ['SimHei']   # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False    
xd_one.plot.scatter(x='曝光人数', y='访问人数')
sns.set(font='SimHei',font_scale=1)
sns.lmplot(x='曝光人数', y='访问人数', data=xd_one)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 35775 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 38382 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 35775 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 38382 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
xd_two.plot.scatter(x='曝光人数', y='访问人数')
sns.set(font='SimHei',font_scale=1)
sns.lmplot(x='曝光人数', y='访问人数', data=xd_two)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
xd_three.plot.scatter(x='曝光人数', y='访问人数')
sns.set(font='SimHei',font_scale=1)
sns.lmplot(x='曝光人数', y='访问人数', data=xd_three)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
xd_four.plot.scatter(x='曝光人数', y='访问人数')
sns.set(font='SimHei',font_scale=1)
sns.lmplot(x='曝光人数', y='访问人数', data=xd_four)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
xd_one
# Out:
#      Unnamed: 0        门店ID       日期    城市               门店名称   曝光人数  访问人数  \
# 11           11   130648305  2020-08    东阳    邂逅花坊鲜花(知音婚庆鲜花店)  59162  2417
# 124         124     9026049  2020-08    资阳               花语鲜花  36829  1858
# 150         150   127544279  2020-08   马鞍山      邂逅花坊鲜花(婷雅花坊店)  34528  1388
# 70           70   126427126  2020-08   德惠市              花雨轩花艺   8345   690
# 25           25   127546074  2020-08    北京       邂逅花坊鲜花(雪莲花艺)   8329   445
# 141         141    66237179  2020-08    长治        锦尚鲜花(雅韵鲜花店)   7076   379
# 57           57    40598484  2020-08   密山市        邂逅花坊鲜花林東花鸟鱼   6302   611
# 137         137    67764314  2020-08    镇江               心语花苑   5491   265
# 63           63   503495836  2020-08  峨眉山市     邂逅花坊鲜花(良缘婚庆鲜花)   5147   537
# 126         126   112144286  2020-08   迁安市        邂逅花坊鲜花(季盛店)   4714  1231
# 148         148   127755450  2020-08   顺德区       邂逅花坊鲜花(紫涵花兿)   4304   267
# 139         139   127616578  2020-08   长垣市       邂逅花坊鲜花(千艺鲜花)   4119   833
# 45           45   112085234  2020-08    唐山            印象IOO鲜花   3674   552
# 136         136   110655152  2020-08   铜梁区               佳佳花艺   2978   433
# 132         132   110752444  2020-08   邳州市      邂逅花坊鲜花(福地花苑店)   2897   287
# 127         127   112179742  2020-08    运城          邂逅花坊(小屋店)   2878   276
# 21           21   127760656  2020-08   兖州区       邂逅花坊鲜花(百合花艺)   2682   419
# 108         108  1830337749  2020-08    烟台      邂逅花坊鲜花(墨兰鲜花店)   2646   202
# 1             1   111559299  2020-08   万州区       邂逅花坊鲜花(竞花园店)   2626   602
# 152         152   127736099  2020-08    鹰潭       邂逅花坊鲜花(鑫美花卉)   2546   631
# 131         131   127589137  2020-08   邛崃市       邂逅花坊鲜花(百花派店)   2391   512
# 88           88   122875748  2020-08   榆次区      邂逅花坊鲜花(浪漫花都店)   2339   188
# 117         117   127972698  2020-08   舒城县      邂逅花坊鲜花(馨馨花艺店)   2259   499
# 71           71   111587570  2020-08   怀柔区        邂逅花坊鲜花(万卉源)   2226   376
# 120         120   127739746  2020-08   蓝田县       邂逅花坊鲜花(七彩鲜花)   2208   697
# 149         149   911021319  2020-08   顺德区      邂逅花坊鲜花(雅琳花艺店)   2110   171
# 49           49   128046029  2020-08    宁海       邂逅花坊鲜花(四季花屋)   1849   316
# 87           87   127926139  2020-08    榆林       邂逅花坊鲜花(花语鲜花)   1805   355
# 69           69   127595260  2020-08   庐江县       邂逅花坊鲜花(爱的花坊)   1654   276
# 116         116   112179102  2020-08    绵阳     邂逅花坊鲜花(绮彩花果坊店)   1598   156
# 110         110   122146353  2020-08    白山       邂逅花坊鲜花(青青花行)   1488   235
# 73           73    38136049  2020-08    惠阳     邂逅花坊鲜花(花娇艳鲜花店)   1462   139
# 79           79   127973025  2020-08    晋江      邂逅花坊鲜花(百合花艺坊)   1398   186
# 34           34  1889709085  2020-08   南康区       邂逅花坊鲜花(遇见花坊)   1210   175
# 20           20    27261537  2020-08    保定  玫瑰鲜花香(四季馨鲜花裕华东路店)   1195   145
# 16           16   127760575  2020-08   乐昌市       邂逅花坊鲜花(美好鲜花)   1184   230
# 97           97   127588998  2020-08    泸州        邂逅花坊鲜花(花语店)    926   143
# 146         146   127757325  2020-08    鞍山       邂逅花坊鲜花(金卉花房)    874    74
# 37           37    92627300  2020-08   双阳区             花花世界花艺    835   164
# 112         112    24943649  2020-08   秦皇岛              阳光鲜花店    542    45
# 102         102   127591521  2020-08    淮安     邂逅花坊鲜花(百合婚礼鲜花)    508    74
# 85           85    69459323  2020-08    柳州               蜜蜂花堆    480    19
#
#      意向转化人数 曝光访问转化率   意向转化率  美团星级 美团星级变化  大众点评点评星级 大众点评星级变化
# 11      104   4.09%   4.30%   5.0     持平      3.97   +3.97星
# 124     109   5.04%   5.87%   5.0  +0.1星      4.55   -0.01星
# 150      79   4.02%   5.69%   5.0     持平      4.05   -0.02星
# 70       37   8.27%   5.36%   5.0     持平      3.83   -0.01星
# 25       48   5.34%  10.79%   5.0  +0.1星      4.45   +0.05星
# 141      19   5.36%   5.01%   5.0  +0.5星      3.00       持平
# 57       28   9.70%   4.58%   5.0     持平      0.00       持平
# 137       7   4.83%   2.64%   4.5     持平      3.83       持平
# 63       18  10.43%   3.35%   4.5  +4.5星      0.00       持平
# 126      62  26.11%   5.04%   4.5  -0.1星      3.83   +0.01星
# 148      21   6.20%   7.87%   5.0     持平      3.58   -0.02星
# 139      45  20.22%   5.40%   4.9  +0.2星      0.00       持平
# 45       36  15.02%   6.52%   5.0     持平      3.43   -0.01星
# 136      32  14.54%   7.39%   5.0     持平      3.75   -0.05星
# 132      15   9.91%   5.23%   5.0     持平      3.56       持平
# 127      16   9.59%   5.80%   5.0     持平      0.00       持平
# 21       20  15.62%   4.77%   4.8  +0.5星      3.70   -0.02星
# 108       9   7.63%   4.46%   4.6  +4.6星      0.00       持平
# 1        53  22.92%   8.80%   4.5  +0.3星      3.97   +3.97星
# 152      49  24.78%   7.77%   5.0     持平      0.00       持平
# 131      41  21.41%   8.01%   5.0  +0.6星      4.01       持平
# 88        6   8.04%   3.19%   5.0     持平      0.00       持平
# 117      27  22.09%   5.41%   5.0     持平      3.98   -0.12星
# 71       16  16.89%   4.26%   5.0     持平      3.99   +0.16星
# 120      46  31.57%   6.60%   4.7     持平      4.12   -0.15星
# 149       9   8.10%   5.26%   4.7  -0.1星      0.00       持平
# 49       24  17.09%   7.59%   5.0     持平      0.00       持平
# 87       10  19.67%   2.82%   4.9     持平      3.30   +0.01星
# 69       15  16.69%   5.43%   4.6     持平      3.18   -0.02星
# 116       9   9.76%   5.77%   5.0     持平      0.00       持平
# 110      12  15.79%   5.11%   5.0     持平      3.67       持平
# 73       12   9.51%   8.63%   4.5  -0.1星      3.72       持平
# 79       10  13.30%   5.38%   4.9  +0.1星      3.82   -0.05星
# 34       16  14.46%   9.14%   4.6  +0.3星      0.00       持平
# 20        5  12.13%   3.45%   4.6  -0.1星      3.92       持平
# 16       24  19.43%  10.43%   5.0     持平      0.00       持平
# 97        5  15.44%   3.50%   5.0     持平      3.79   -0.03星
# 146       2   8.47%   2.70%   4.7  +0.2星      4.01   -0.03星
# 37        4  19.64%   2.44%   4.5     持平      0.00       持平
# 112       1   8.30%   2.22%   4.7     持平      3.00       持平
# 102       5  14.57%   6.76%   5.0  +0.7星      3.67       持平
# 85        0   3.96%   0.00%   4.5     持平      0.00       持平

# %%
xd.plot.scatter(x='意向转化人数', y='美团星级')
sns.set(font='SimHei',font_scale=1)
sns.lmplot(x='意向转化人数', y='美团星级', data=xd)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
def linear(x,y):
    from sklearn import metrics
    import numpy as np
    from sklearn.model_selection import train_test_split
    from sklearn import linear_model
    X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=1)
    print('数据分集查看')
    print ('X训练',X_train.shape)
    print ('y训练',y_train.shape)
    print ('X测试',X_test.shape)
    print ('y测试',y_test.shape)
    print('-------------')
    linear =  linear_model.LinearRegression()
    linear.fit(X_train,y_train)
    print('线性结截距:', linear.intercept_)
    print ('回归系数',linear.coef_)
    y_pred = linear.predict(X_test)
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

def line_bg_rd(data):   
    baoguang = data['曝光人数'].values.reshape(-1,1)
    jindian = data['访问人数'].values.reshape(-1, 1)
    linear(baoguang,jindian)

# %%
line_bg_rd(xd_one)
line_bg_rd(xd_two)
line_bg_rd(xd_three)
line_bg_rd(xd_four)
# Out:
# 数据分集查看
# X训练 (31, 1)
# y训练 (31, 1)
# X测试 (11, 1)
# y测试 (11, 1)
# -------------
# 线性结截距: [255.01051313]
# 回归系数 [[0.03912908]]
# RMSE: 171.97784443106437
# 数据分集查看
# X训练 (41, 1)
# y训练 (41, 1)
# X测试 (14, 1)
# y测试 (14, 1)
# -------------
# 线性结截距: [169.99757539]
# 回归系数 [[0.03836625]]
# RMSE: 136.5579666509596
# 数据分集查看
# X训练 (11, 1)
# y训练 (11, 1)
# X测试 (4, 1)
# y测试 (4, 1)
# -------------
# 线性结截距: [-25.89568555]
# 回归系数 [[0.18262673]]
# RMSE: 53.78736604855279
# 数据分集查看
# X训练 (37, 1)
# y训练 (37, 1)
# X测试 (13, 1)
# y测试 (13, 1)
# -------------
# 线性结截距: [42.71915255]
# 回归系数 [[0.04586301]]
# RMSE: 43.33659945684031

# %%
a = xd_one['意向转化人数'].sum()
b = xd_one['门店ID'].count()

print(a)
print(b)
print(a/b)
c = xd_one['意向转化人数'].std()
print(c)
# Out:
# 1106
# 42
# 26.333333333333332
# 25.663551706240153

# %%
a = xd_two['意向转化人数'].sum()
b = xd_two['门店ID'].count()
print(a)
print(b)
print(a/b)
c = xd_two['意向转化人数'].std()
print(c)
# Out:
# 929
# 55
# 16.89090909090909
# 36.994330259925924

# %%
a = xd_three['意向转化人数'].sum()
b = xd_three['门店ID'].count()
print(a)
print(b)
print(a/b)
c = xd_three['意向转化人数'].std()
print(c)
# Out:
# 144
# 15
# 9.6
# 10.041343108796323

# %%
a = xd_four['意向转化人数'].sum()
b = xd_four['门店ID'].count()
print(a)
print(b)
print(a/b)
c = xd_four['意向转化人数'].std()
print(c)
# Out:
# 210
# 50
# 4.2
# 3.3502969713024493

# %%
df_xiangqing_ri
# Out:
#               日期   城市          门店名称  曝光人数  访问人数 曝光访问转化率  意向转化人数   意向转化率
# 0     2020-08-01   万宁  邂逅花坊鲜花(雅景花坊)    20     9  45.00%       1  11.11%
# 1     2020-08-02   万宁  邂逅花坊鲜花(雅景花坊)    23     9  39.13%       0   0.00%
# 2     2020-08-03   万宁  邂逅花坊鲜花(雅景花坊)    21     8  38.10%       1  12.50%
# 3     2020-08-04   万宁  邂逅花坊鲜花(雅景花坊)    15     9  60.00%       1  11.11%
# 4     2020-08-05   万宁  邂逅花坊鲜花(雅景花坊)    13     2  15.38%       0   0.00%
# ...          ...  ...           ...   ...   ...     ...     ...     ...
# 4800  2020-08-27  龙口市  邂逅花坊鲜花(苔米花艺)     6     0   0.00%       0       0
# 4801  2020-08-28  龙口市  邂逅花坊鲜花(苔米花艺)     7     2  28.57%       0   0.00%
# 4802  2020-08-29  龙口市  邂逅花坊鲜花(苔米花艺)     9     1  11.11%       0   0.00%
# 4803  2020-08-30  龙口市  邂逅花坊鲜花(苔米花艺)     4     1  25.00%       0   0.00%
# 4804  2020-08-31  龙口市  邂逅花坊鲜花(苔米花艺)     3     0   0.00%       0       0
#
# [4805 rows x 8 columns]
