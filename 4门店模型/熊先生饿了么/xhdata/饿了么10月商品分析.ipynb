# %%
import pandas as pd 
import numpy as np 
pd.set_option('display.max_rows',None)

# %%
data= pd.read_excel('1.xlsx')
data = data[['饿佰id','名称']]
data
# Out:
#              饿佰id                    名称
# 0    100000072256            铭相花缘（月罗路店）
# 1    100000047299        邂逅花坊（爱尚鲜花青浦区店）
# 2    100000050172            邂逅花坊（百合花坊）
# 3     32267816029           厚木花坊（红旗东路店）
# 4     32267816026            寻花集（元一名城店）
# 5     32267816014            花之物语（叙永镇店）
# 6     32267815935          红枫叶鲜花坊（中原路店）
# 7     32267815913          醉花樱鲜花苑（龙川镇店）
# 8     32267787278          金双喜鲜花（棣新三路店）
# 9     32267787231           名花有主（新凤中路店）
# 10    32267787209           勿忘你花坊（八一路店）
# 11    32267787175            向阳花阁（西夏区店）
# 12    32267787174             花嫁（秀水大道店）
# 13    32267787141           陆芳鲜花店（昌黎县店）
# 14    32267787110          爱尚花坊（桃园西四路店）
# 15    32267787078           朵朵鲜花店（沙河路店）
# 16    32267667738          邂逅花坊（花园派对鲜花店
# 17    32267667671      邂逅花坊（钰铭鲜花婚庆东大街店）
# 18    32267621883        邂逅花坊（香梅花坊光仁街店）
# 19    32267621863     邂逅花坊（爱馨主题花艺万泉河路店）
# 20    32267603399             花苁里（菜艺街店）
# 21    32267603397       洛施花艺（婕拉花艺宣府大街店）
# ...

# %%
data = pd.read_excel(r'饿了么10月商品分析.xlsx',encoding='gbk')

# %%
data['商品价格'] = data['实际销售额'] / data['销量']
data['销量订单差'] = data['销量'] - data['带来订单量']

# %%
data
# Out:
#      一级分类  二级分类     三级分类                            商品名称              商品条码  \
# 0    鲜花绿植  礼品鲜花    玫瑰类主打                     到店自取款-单支粉玫瑰  wm36497880297963
# 1    鲜花绿植  礼品鲜花    玩偶类主打   慢慢喜欢你-11枝香槟玫瑰花鲜花花束送爱人-朋友-生日鲜花     qx20200825002
# 2    鲜花绿植  礼品鲜花    玫瑰类主打     少女心-11枝红玫瑰满天星鲜花礼盒送朋友-闺蜜-生日花  wm74635158934730
# 3    鲜花绿植  礼品鲜花    玫瑰类主打        珍贵-19枝香槟玫瑰鲜花花束送恋人-生日-表白花     qx20200825001
# 4    鲜花绿植  礼品鲜花   康乃馨类主打   喜欢一种花-19枝粉色康乃馨鲜花花束送父母-恩师-长辈花礼  wm95975277450047
# 5    鲜花绿植  礼品鲜花    玫瑰类主打         拥抱-11枝红玫瑰鲜花花束送恋人-生日-表白花  wm91011085073407
# 6    鲜花绿植  礼品鲜花    玫瑰类主打      心存温柔-11枝粉玫瑰花鲜花礼盒送爱人-朋友-网红款     qx20200825003
# 7    鲜花绿植  鲜切花材      相思梅     蓝色挚爱-11枝蓝色妖姬搭配相思梅绿叶礼盒送爱人-朋友  wm12424389033131
# 8    鲜花绿植   永生花       玫瑰    众所周知的欢喜-11枝蓝色妖姬花束送朋友-闺蜜-爱人花礼  wm18712889175238
# 9    鲜花绿植  礼品鲜花    玫瑰类主打       繁花-向日葵粉玫瑰百合鲜花花束送朋友-闺蜜-祝福花     qx20200825009
# 10   鲜花绿植  礼品鲜花    玫瑰类主打      水中花-11枝混搭玫瑰枝鲜花礼盒送朋友-闺蜜-生日花  wm82007275920021
# ...
